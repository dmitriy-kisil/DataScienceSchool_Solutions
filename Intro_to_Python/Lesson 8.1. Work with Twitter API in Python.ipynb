# %% [markdown]
# ---
# <center><h1> Lesson 8.1 - Work with Twitter API in Python</center></h1>
#
# ---

# %% [markdown]
# A Web API is an *application programming interface* (**API**). It helps easely to entaract with program programs and web services.
#
# Today many services provide its API for developers (such as Facebook, Google, Twitter, etc). API helps to en to interact with their services and to access data in a programmatic way. With help of API, you can create your own application.
#
# API is a set of subroutine definitions, protocols, and tools for building application software. In general terms, it is a set of clearly defined methods of communication between various software components. A good API makes it easier to develop a computer program by providing all the building blocks, which are then put together by the programmer. An API may be for a web-based system, operating system, database system, computer hardware or software library.
#
# The current lesson is devoted to Twitter API. We will consider both approaches of getting access to Twitter API - main Python tools such as `request` library and specific Python libraries such as `tweepy`.

# %% [markdown]
# <img src="images/Python_Twitter.jpg" width="512px" height="288px">
#
# One of the reasons that Twitter is so popular, and become what it is today, is due to the huge number of developers who have built apps over the years. Why so many developers? Basically because Twitter has been very easy to work with. Twitter uses the OAuth protocol for secure application development.
#
# In this lesson, you will create an application integrated with Twitter. Registering the application is the first step in developing an application that is integrated into its users' social graph.

# %% [markdown]
# ## Register a new application
# All Twitter users are potentially Twitter application developers. Visit https://apps.twitter.com and and press "Create New App".
#
# <img src="images/twitter_01.jpg">
#
# After that fill Aplication Detals (Name, Description and Website), read and agree to the Twitter Developer Agreement. Press "Create your Twitter application".
# (Note that you must add your mobile phone to your Twitter profile before creating an application. Please read [here](https://support.twitter.com/articles/110250-adding-your-mobile-number-to-your-account-via-web) for more information.)
#
# <img src="images/twitter_02.jpg">
# After Captcha challenge click "Create your Twitter application" to complete the form and go to the application settings page.
#
# We now need to authorise the Twitter app for your Twitter account. To do this you should select "Key and Access Tokens" menu button and create your access token. This **access token** will allow your Twitter application to read Twitter information. You’ll be able to get data of your tweets, mentions, lists and more.
#
# <img src="images/twitter_03.jpg">
#
# In the opened window you’ll then be presented with lots of information. The main fields to note are **_Consumer key_** and **_Consumer secret_**. These values are your application’s credentials for Twitter. You need them to do almost anything with Twitter, including going through the OAuth authorization flow and working with Twitter’s REST API. But we’re not quite done yet.
#
# As a result you will see the window with consumer and token keys for your application
#
# <img src="images/twitter_04.jpg">
#
# Above the four fields are highlighted. You will need these long horrible strings of characters for your Twitter app.

# %% [markdown]
# ---
# ## 1. Getting access to Twitter APIs using main Python tools
# ---

# %% [markdown]
# Many web services including Twitter require authentication, and there are many different types.
#
# Python library `requests` provides a pythonic way to make complex HTTP requests, and handles difficult tasks like authentication.
#
# A common form of authentication for several web APIs is OAuth. The `requests-oauthlib` library allows `requests`'s users to easily make OAuth authenticated requests.

# %%
import requests
from requests_oauthlib import OAuth1
import os
import json
from dotenv import load_dotenv, find_dotenv
load_dotenv()

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
consumer_key = os.environ['consumer_key']
consumer_secret = os.environ['consumer_secret']

access_token = os.environ['access_token']
access_secret = os.environ['access_secret']

# You will authenticate yourself using OAuth1 object
auth = OAuth1(consumer_key, consumer_secret, access_token, access_secret)
print (auth)
# Out:
# <requests_oauthlib.oauth1_auth.OAuth1 object at 0x7f957da0c748>

# %%
# If the authentication was successful, you should see the name of the account print out
url_0 = 'https://api.twitter.com/1.1/account/verify_credentials.json'
res = requests.get(url_0, auth=auth)

print ("My name is", res.json()['name'])
# Out:
# My name is Dmitriy Kisil

# %% [markdown]
# ### 1.1: Read Tweets from Your Homepage
#
# The list of all available Twitter API you can find here https://developer.twitter.com/en/docs/api-reference-index. Let's use `home_timeline` that returns a collection of the most recent tweets and retweets posted by the authenticating user and the users they follow.

# %%
url_1 = 'https://api.twitter.com/1.1/statuses/home_timeline.json'
res = requests.get(url_1, auth=auth, params={"count": 3})

# The res object encapsulates the "response" of the server. Notice the status code that is displayed. 
# Code 200 means that things went fine
# Code 403 means that the server understood the request, but is refusing to fulfill it
# Code 404 means that the URL was not found
# Codes 5xx mean that something went wrong

print (res, "Status code:", res.status_code)
# Let's see how looks the url
print (res.url)
print ("Content type:", res.headers['content-type'], '\n')

tweets = res.json()
if res.status_code == 200:
    for tweet in tweets:
        print (tweet['text'])
else:   # You have no tweets
    print (tweets)
# Out:
# <Response [200]> Status code: 200
# https://api.twitter.com/1.1/statuses/home_timeline.json?count=3
# Content type: application/json;charset=utf-8
#
# Закликаю українських громадян на окупованих Росією територіях не приймати російські паспорти. Росія позбавила вас с… https://t.co/MMmFo5kAAN
# Рішення РФ щодо видачі 🇷🇺паспортів на окупованих українських територіях - це продовження агресії і втручання у наші… https://t.co/tgbCADMSP7
# Hacking Neural Networks by @mrdragonbear https://t.co/FQPYx17VfX

# %% [markdown]
# ### 1.2: Search tweets by key words
#
# Twitter employs a special query language.  For example, the query _"luck?"_ will return tweets that contain the word "luck" and are phrased as a question OR the query _"winter"_ will return the word "winter" with a positive attitude. [Check out more examples here](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets).
#
# We can mine tweets using either **_search_** or **_stream_**.
#
# >The key difference between **_stream_** and **_search_** is that **_stream_** provides new data as it comes in, while **_search_** can be used to query old data. The **_search_** API is more powerful for queries, and provides faster access to a wide-range of data.
#
# Let's search for a single tweet about "luck?", phrased as a question. Note if request phrase contains URI characters you should [encode](https://en.wikipedia.org/wiki/Percent-encoding) these queries before making the request, because these characters can play role of keys in an URL. Particularly, the question mark "?" is encoded as "%3F".

# %%
url_2 = 'https://api.twitter.com/1.1/search/tweets.json?q=luck%3F'
res = requests.get(url_2, auth=auth)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

tweets = res.json()
tweets
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=luck%3F
# {'statuses': [{'created_at': 'Wed Apr 24 13:20:39 +0000 2019',
#    'id': 1121041263636176897,
#    'id_str': '1121041263636176897',
#    'text': 'RT @OfficialMazzuma: Hello there,\n\nWe are looking for a marketing associate. Think you have what it takes to join our team?\n\nThen check out…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'OfficialMazzuma',
#       'name': 'Mazzuma',
#       'id': 3165440693,
#       'id_str': '3165440693',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1004774059291312129,
#     'id_str': '1004774059291312129',
#     'name': 'sami_danso',
#     'screen_name': 'SamiDanso',
#     'location': 'Accra, Ghana',
#     'description': 'No regrets. Just lessons.👑\nStay humble but hungry💯',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 783,
#     'friends_count': 797,
#     'listed_count': 0,
#     'created_at': 'Thu Jun 07 17:16:18 +0000 2018',
#     'favourites_count': 1578,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 680,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1109012723562631168/8j2qBXvl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109012723562631168/8j2qBXvl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004774059291312129/1533370528',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Apr 24 11:46:52 +0000 2019',
#     'id': 1121017662086307840,
#     'id_str': '1121017662086307840',
#     'text': 'Hello there,\n\nWe are looking for a marketing associate. Think you have what it takes to join our team?\n\nThen check… https://t.co/GOuEYcT4mz',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/GOuEYcT4mz',
#        'expanded_url': 'https://twitter.com/i/web/status/1121017662086307840',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3165440693,
#      'id_str': '3165440693',
#      'name': 'Mazzuma',
#      'screen_name': 'OfficialMazzuma',
#      'location': 'Download now!',
#      'description': 'We are a mobile money payment system that utilizes distributed secure infrastructure to enable seamless payments. 📱 #yourmoneyyourfreedom',
#      'url': 'https://t.co/JWZVlG2Nnz',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JWZVlG2Nnz',
#          'expanded_url': 'https://mazzuma.com',
#          'display_url': 'mazzuma.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2901,
#      'friends_count': 737,
#      'listed_count': 13,
#      'created_at': 'Mon Apr 13 22:47:30 +0000 2015',
#      'favourites_count': 732,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1526,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/635040603429031936/1PUH8b9N_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/635040603429031936/1PUH8b9N_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3165440693/1526110951',
#      'profile_link_color': '9266CC',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 18,
#     'favorite_count': 12,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 18,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:38 +0000 2019',
#    'id': 1121041256933728256,
#    'id_str': '1121041256933728256',
#    'text': 'RT @HJCRecruitment: Have you entered our #FreebieFriday #Competition yet folks? 👏🏼\n\nJust FOLLOW US &amp; RETWEET to enter our £20 Amazon vouche…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'FreebieFriday', 'indices': [41, 55]},
#      {'text': 'Competition', 'indices': [56, 68]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'HJCRecruitment',
#       'name': 'Handley James',
#       'id': 4860994426,
#       'id_str': '4860994426',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1095266004857442304,
#     'id_str': '1095266004857442304',
#     'name': 'Elisa123',
#     'screen_name': 'IrenaMeiers',
#     'location': 'London',
#     'description': 'Happy Londoner',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 58,
#     'friends_count': 455,
#     'listed_count': 0,
#     'created_at': 'Tue Feb 12 10:18:59 +0000 2019',
#     'favourites_count': 970,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1232,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1095268193030098944/jkiu5OPU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1095268193030098944/jkiu5OPU_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 23 09:35:08 +0000 2019',
#     'id': 1120622120856358912,
#     'id_str': '1120622120856358912',
#     'text': 'Have you entered our #FreebieFriday #Competition yet folks? 👏🏼\n\nJust FOLLOW US &amp; RETWEET to enter our £20 Amazon vo… https://t.co/4Pml7Afc4U',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'FreebieFriday', 'indices': [21, 35]},
#       {'text': 'Competition', 'indices': [36, 48]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4Pml7Afc4U',
#        'expanded_url': 'https://twitter.com/i/web/status/1120622120856358912',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4860994426,
#      'id_str': '4860994426',
#      'name': 'Handley James',
#      'screen_name': 'HJCRecruitment',
#      'location': 'Wigan',
#      'description': 'We’re The Manufacturing Recruitment Specialists. 📞 01695 589 232 📧 info@handleyjames.co.uk',
#      'url': 'https://t.co/aA60V8Akj4',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aA60V8Akj4',
#          'expanded_url': 'http://www.handleyjames.co.uk',
#          'display_url': 'handleyjames.co.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3332,
#      'friends_count': 888,
#      'listed_count': 119,
#      'created_at': 'Fri Jan 29 17:23:26 +0000 2016',
#      'favourites_count': 6860,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 7584,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/948281658779820033/7hwbsv2j_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948281658779820033/7hwbsv2j_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4860994426/1554453687',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 296,
#     'favorite_count': 165,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 296,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:31 +0000 2019',
#    'id': 1121041229720903680,
#    'id_str': '1121041229720903680',
#    'text': '@cyrillejowin \n🌻: Mataray hahaha\n💛: 4? Hehe\n💌: Kataray mo kasi san bata ka pa hahaha. Unta maging close kit para wa… https://t.co/r2KaNhic2d',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'cyrillejowin',
#       'name': 'kleng',
#       'id': 4519950208,
#       'id_str': '4519950208',
#       'indices': [0, 13]}],
#     'urls': [{'url': 'https://t.co/r2KaNhic2d',
#       'expanded_url': 'https://twitter.com/i/web/status/1121041229720903680',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1121027675361951744,
#    'in_reply_to_status_id_str': '1121027675361951744',
#    'in_reply_to_user_id': 774771740387840000,
#    'in_reply_to_user_id_str': '774771740387840000',
#    'in_reply_to_screen_name': 'chinabonguet',
#    'user': {'id': 774771740387840000,
#     'id_str': '774771740387840000',
#     'name': 'Queen Dragon',
#     'screen_name': 'chinabonguet',
#     'location': 'kung san ka don ako',
#     'description': 'Margaret Mondragon Bartolome',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 560,
#     'friends_count': 473,
#     'listed_count': 0,
#     'created_at': 'Sun Sep 11 00:49:12 +0000 2016',
#     'favourites_count': 4187,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3903,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1119808979331244037/9LaRGgFF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119808979331244037/9LaRGgFF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/774771740387840000/1555380538',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tl'},
#   {'created_at': 'Wed Apr 24 13:20:27 +0000 2019',
#    'id': 1121041210322239489,
#    'id_str': '1121041210322239489',
#    'text': '@cyberneuraI Worry not, i am sending you my tons of luck and i really hope everything works out for you tomorrow an… https://t.co/ljQspPaDxa',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'cyberneuraI',
#       'name': 'Ethan Wu.',
#       'id': 1120991583002750976,
#       'id_str': '1120991583002750976',
#       'indices': [0, 12]}],
#     'urls': [{'url': 'https://t.co/ljQspPaDxa',
#       'expanded_url': 'https://twitter.com/i/web/status/1121041210322239489',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1121036614501670913,
#    'in_reply_to_status_id_str': '1121036614501670913',
#    'in_reply_to_user_id': 1120991583002750976,
#    'in_reply_to_user_id_str': '1120991583002750976',
#    'in_reply_to_screen_name': 'cyberneuraI',
#    'user': {'id': 1120670684915462144,
#     'id_str': '1120670684915462144',
#     'name': 'Anastasia.',
#     'screen_name': 'unspokenmeIody',
#     'location': 'ENG ✧ OCRP.',
#     'description': 'A princess in disguise as a medical student; is currently deeply in love with roses and art.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4,
#     'friends_count': 8,
#     'listed_count': 0,
#     'created_at': 'Tue Apr 23 12:48:07 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1120990641503133696/tzjHGRBd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120990641503133696/tzjHGRBd_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1120670684915462144/1556103533',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:25 +0000 2019',
#    'id': 1121041205503123456,
#    'id_str': '1121041205503123456',
#    'text': "RT @earthygirl01: If you're a Green &amp; you're contemplating switching to #ChangeUK well good luck with their energy spokesperson Angela Smit…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ChangeUK', 'indices': [76, 85]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'earthygirl01',
#       'name': 'Mojito Gee',
#       'id': 2242044623,
#       'id_str': '2242044623',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 520734620,
#     'id_str': '520734620',
#     'name': 'Czarny kapturek',
#     'screen_name': 'KapturekCzarny',
#     'location': 'Wrocław',
#     'description': 'Anti-fascism, anti-racism, anti-anti-semitism and anti-homphobia in Poland.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 591,
#     'friends_count': 871,
#     'listed_count': 20,
#     'created_at': 'Sat Mar 10 21:04:31 +0000 2012',
#     'favourites_count': 14371,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 13494,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1114965353786826752/xj6JcGiP_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1114965353786826752/xj6JcGiP_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/520734620/1517439759',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 23 18:27:52 +0000 2019',
#     'id': 1120756188801576968,
#     'id_str': '1120756188801576968',
#     'text': "If you're a Green &amp; you're contemplating switching to #ChangeUK well good luck with their energy spokesperson Angel… https://t.co/uuLu5uUiCg",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ChangeUK', 'indices': [58, 67]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/uuLu5uUiCg',
#        'expanded_url': 'https://twitter.com/i/web/status/1120756188801576968',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2242044623,
#      'id_str': '2242044623',
#      'name': 'Mojito Gee',
#      'screen_name': 'earthygirl01',
#      'location': 'E Yorkshire #GTTO',
#      'description': 'Come writers and critics\nWho prophesize with your pen\nAnd keep your eyes wide\nThe chance won’t come again\nAnd don’t speak too soon\nFor the wheel’s still in spin',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 8543,
#      'friends_count': 6733,
#      'listed_count': 138,
#      'created_at': 'Tue Dec 24 18:42:48 +0000 2013',
#      'favourites_count': 65874,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 184696,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/818476978894413824/MrIL9RhD_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818476978894413824/MrIL9RhD_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2242044623/1552259277',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 376,
#     'favorite_count': 761,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 376,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:21 +0000 2019',
#    'id': 1121041185513123840,
#    'id_str': '1121041185513123840',
#    'text': '@sjharley ....good luck trying to get people to understand those simple facts...?',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sjharley',
#       'name': 'Stephen Harley',
#       'id': 23485208,
#       'id_str': '23485208',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1121040789017116673,
#    'in_reply_to_status_id_str': '1121040789017116673',
#    'in_reply_to_user_id': 23485208,
#    'in_reply_to_user_id_str': '23485208',
#    'in_reply_to_screen_name': 'sjharley',
#    'user': {'id': 838231195,
#     'id_str': '838231195',
#     'name': 'stephen blanchard',
#     'screen_name': 'stephenblanchar',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 363,
#     'friends_count': 723,
#     'listed_count': 0,
#     'created_at': 'Fri Sep 21 17:14:32 +0000 2012',
#     'favourites_count': 72054,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12518,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:14 +0000 2019',
#    'id': 1121041158539546624,
#    'id_str': '1121041158539546624',
#    'text': '@Macazette7 Swear? Good luck g',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Macazette7',
#       'name': 'Màca',
#       'id': 831989054,
#       'id_str': '831989054',
#       'indices': [0, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1121041009587175425,
#    'in_reply_to_status_id_str': '1121041009587175425',
#    'in_reply_to_user_id': 831989054,
#    'in_reply_to_user_id_str': '831989054',
#    'in_reply_to_screen_name': 'Macazette7',
#    'user': {'id': 716048890743627776,
#     'id_str': '716048890743627776',
#     'name': 'ᴇʟᴍᴢ',
#     'screen_name': 'AubaSZN',
#     'location': 'Emirates stadium',
#     'description': '🔙🔛🔝',
#     'url': 'https://t.co/6dpRIYDiK9',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/6dpRIYDiK9',
#         'expanded_url': 'https://curiouscat.me/AubaSZN',
#         'display_url': 'curiouscat.me/AubaSZN',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1935,
#     'friends_count': 1255,
#     'listed_count': 10,
#     'created_at': 'Fri Apr 01 23:45:34 +0000 2016',
#     'favourites_count': 13469,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4673,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1110919187319476224/lByeUvmJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110919187319476224/lByeUvmJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/716048890743627776/1555581666',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Apr 24 13:20:13 +0000 2019',
#    'id': 1121041154735259650,
#    'id_str': '1121041154735259650',
#    'text': 'RT @Dzexolfanbase: » DAILY CHALLENGE«\n\nAℓgerian EXOℓs ARE YOU READY ?\n\nأجيبوا تحت هذه التغريدة لساعتين متواصلتين دون توقف ، لنرى كم بامكانن…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Dzexolfanbase',
#       'name': 'ALGERIAN EXO FANBASE',
#       'id': 865203342934462464,
#       'id_str': '865203342934462464',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1076152792832753664,
#     'id_str': '1076152792832753664',
#     'name': 'Exo Baek',
#     'screen_name': 'jehun9494',
#     'location': 'Algérie',
#     'description': 'Algerian Ëxø-l 👑',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 144,
#     'friends_count': 0,
#     'listed_count': 0,
#     'created_at': 'Fri Dec 21 16:29:54 +0000 2018',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 144,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1119260038713966592/C2Ci3MgY_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119260038713966592/C2Ci3MgY_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076152792832753664/1555687361',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 23 19:00:00 +0000 2019',
#     'id': 1120764273653948417,
#     'id_str': '1120764273653948417',
#     'text': '» DAILY CHALLENGE«\n\nAℓgerian EXOℓs ARE YOU READY ?\n\nأجيبوا تحت هذه التغريدة لساعتين متواصلتين دون توقف ، لنرى كم با… https://t.co/I99MKFDxOn',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/I99MKFDxOn',
#        'expanded_url': 'https://twitter.com/i/web/status/1120764273653948417',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'ar', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 865203342934462464,
#      'id_str': '865203342934462464',
#      'name': 'ALGERIAN EXO FANBASE',
#      'screen_name': 'Dzexolfanbase',
#      'location': 'Algeria',
#      'description': 'EXO OFFICIAL ALGERIAN FANBASE | member of @wwexol  |\nالقاعدة الخاصة بالاكسوال الجزائري \u2066🇩🇿\u2069\n•  inquiries : dzexols@gmail.com',
#      'url': 'https://t.co/hXDjMeTdkn',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/hXDjMeTdkn',
#          'expanded_url': 'https://instagram.com/dzexolfanbase?utm_source=ig_profile_share&igshid=184qc70y8tdcl',
#          'display_url': 'instagram.com/dzexolfanbase?…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11424,
#      'friends_count': 85,
#      'listed_count': 13,
#      'created_at': 'Thu May 18 13:52:06 +0000 2017',
#      'favourites_count': 5080,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10984,
#      'lang': 'fr',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1115669322821771265/uJ8DK-N1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115669322821771265/uJ8DK-N1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/865203342934462464/1554142069',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 961,
#     'favorite_count': 241,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ar'},
#    'is_quote_status': False,
#    'retweet_count': 961,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ar'}],
#  'search_metadata': {'completed_in': 0.058,
#   'max_id': 1121041263636176897,
#   'max_id_str': '1121041263636176897',
#   'next_results': '?max_id=1121041154735259649&q=luck%3F&include_entities=1',
#   'query': 'luck%3F',
#   'refresh_url': '?since_id=1121041263636176897&q=luck%3F&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Let's find 5 tweets that contains the word "python" or "IPython" near London. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language). Additional parameters allows build very complicated search requests.

# %%
url_2_2 = 'https://api.twitter.com/1.1/search/tweets.json?'

params = {
    "q": 'python OR IPython',
    "count": 5, 
    "show_user": False,
    "geocode": '51.509865,-0.118092,20mi',
    "lang": 'en'
}

res = requests.get(url_2_2, auth=auth, params=params)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

tweets = res.json()
for num, tweet in enumerate(tweets['statuses']):
    print ('Tweet #{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8")))
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=python+OR+IPython&count=5&show_user=False&geocode=51.509865%2C-0.118092%2C20mi&lang=en
# Tweet #1	Wed Apr 24 13:05:01 +0000 2019
# b'@Needlefact OCRd that, cleaned it up and made a quick python 2 liner: https://t.co/geOC0cNBy9 insults all day long.'
#
# Tweet #2	Wed Apr 24 13:01:13 +0000 2019
# b"RT @miekg: Wrote a tool that takes in (small) yaml and barfs out Grafana json, Like https://t.co/LZuncmgO7z but written in Go and doesn't f\xe2\x80\xa6"
#
# Tweet #3	Wed Apr 24 12:44:43 +0000 2019
# b'RT @RyoIndie: The calm before the storm...     -Follow me for updates on my upcoming game #OperationValderon #python #towerdefense #towerde\xe2\x80\xa6'
#
# Tweet #4	Wed Apr 24 12:39:58 +0000 2019
# b'RT @paoloardoino: Amazing H(M)oney Framework tutorial, now in Python too!  https://t.co/FkxwAVYjXt'
#
# Tweet #5	Wed Apr 24 12:30:05 +0000 2019
# b"Get started with data science (including statistical / numerical methods &amp; Python) courtesy of @bsletten's 3-day wo\xe2\x80\xa6 https://t.co/URCZRBUFpi"

# %% [markdown]
# ### 1.3: Get a list of all your followers
#
# Twitter GET request `friends/list` returns a cursored collection of user objects for every user the specified user is following (otherwise known as their “friends”).

# %%
url_3 = 'https://api.twitter.com/1.1/friends/list.json'
res = requests.get(url_3, auth=auth)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

friends = res.json()
friends
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/friends/list.json
# {'users': [{'id': 2433533072,
#    'id_str': '2433533072',
#    'name': 'Sudhakar Verma',
#    'screen_name': '_sudhackar',
#    'location': 'India',
#    'description': 'playing with pointers and numbers @payatulabs CTFs with @BanditsByte Chapter lead @nullpune',
#    'url': 'https://t.co/EwLbNLj0ir',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/EwLbNLj0ir',
#        'expanded_url': 'https://reverseengineering.stackexchange.com/users/14622/sudhackar',
#        'display_url': 'reverseengineering.stackexchange.com/users/14622/su…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 438,
#    'friends_count': 69,
#    'listed_count': 1,
#    'created_at': 'Tue Apr 08 12:22:16 +0000 2014',
#    'favourites_count': 229,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 126,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 05:06:46 +0000 2019',
#     'id': 1120916971112009728,
#     'id_str': '1120916971112009728',
#     'text': "@TikonaTIL I can't DM you. Twitter doesn't allow to DM",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TikonaTIL',
#        'name': 'Tikona',
#        'id': 370038433,
#        'id_str': '370038433',
#        'indices': [0, 10]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1120907617679945728,
#     'in_reply_to_status_id_str': '1120907617679945728',
#     'in_reply_to_user_id': 370038433,
#     'in_reply_to_user_id_str': '370038433',
#     'in_reply_to_screen_name': 'TikonaTIL',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/962639404295598081/2F6IAfTM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962639404295598081/2F6IAfTM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2433533072/1512815755',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1683654350,
#    'id_str': '1683654350',
#    'name': 'Nikhil Joshi',
#    'screen_name': 'nikhilj_73',
#    'location': '',
#    'description': 'Deep Learning Researcher, Maths and Infosec enthusiast and a Coffee lover!!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 94,
#    'friends_count': 57,
#    'listed_count': 0,
#    'created_at': 'Mon Aug 19 16:24:57 +0000 2013',
#    'favourites_count': 28,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 40,
#    'lang': 'en',
#    'status': {'created_at': 'Mon Apr 22 12:54:11 +0000 2019',
#     'id': 1120309826037460992,
#     'id_str': '1120309826037460992',
#     'text': "RT @hardmaru: We're living in a cyberpunk future:\n\n“Fooling automated surveillance cameras: adversarial patches to attack person detection”…",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'hardmaru',
#        'name': 'hardmaru',
#        'id': 2895499182,
#        'id_str': '2895499182',
#        'indices': [3, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Apr 22 01:09:06 +0000 2019',
#      'id': 1120132384026808326,
#      'id_str': '1120132384026808326',
#      'text': "We're living in a cyberpunk future:\n\n“Fooling automated surveillance cameras: adversarial patches to attack person… https://t.co/kz9p2q0ojH",
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/kz9p2q0ojH',
#         'expanded_url': 'https://twitter.com/i/web/status/1120132384026808326',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [116, 139]}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': {'id': 'f7c22e0cf7b3af2b',
#       'url': 'https://api.twitter.com/1.1/geo/id/f7c22e0cf7b3af2b.json',
#       'place_type': 'city',
#       'name': '渋谷区',
#       'full_name': '東京 渋谷区',
#       'country_code': 'JP',
#       'country': 'Япония',
#       'contained_within': [],
#       'bounding_box': {'type': 'Polygon',
#        'coordinates': [[[139.661368, 35.641564],
#          [139.723884, 35.641564],
#          [139.723884, 35.692138],
#          [139.661368, 35.692138]]]},
#       'attributes': {}},
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2038,
#      'favorite_count': 4267,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 2038,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1106498816524603393/ljt0aA9u_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1106498816524603393/ljt0aA9u_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1683654350/1552893909',
#    'profile_link_color': '111111',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 740605983840440320,
#    'id_str': '740605983840440320',
#    'name': 'Iniquitous',
#    'screen_name': '1n1qu170us',
#    'location': '',
#    'description': 'Infosec Noobie | OSCP | Security Researcher',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 362,
#    'friends_count': 980,
#    'listed_count': 5,
#    'created_at': 'Wed Jun 08 18:06:41 +0000 2016',
#    'favourites_count': 3869,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1096,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 17 12:29:20 +0000 2019',
#     'id': 1118491633635323905,
#     'id_str': '1118491633635323905',
#     'text': 'RT @TechBrunchFR: Scan a whole CIDR using Nmap &amp; aquatone - #bugbountytips https://t.co/Y7oLs314iT',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'bugbountytips', 'indices': [64, 78]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'TechBrunchFR',
#        'name': 'Aloïs Thévenot',
#        'id': 231532644,
#        'id_str': '231532644',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1117808240111292416,
#        'id_str': '1117808240111292416',
#        'indices': [79, 102],
#        'media_url': 'http://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#        'url': 'https://t.co/Y7oLs314iT',
#        'display_url': 'pic.twitter.com/Y7oLs314iT',
#        'expanded_url': 'https://twitter.com/TechBrunchFR/status/1117808431782662144/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 316, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 179, 'resize': 'fit'},
#         'large': {'w': 1566, 'h': 412, 'resize': 'fit'}},
#        'source_status_id': 1117808431782662144,
#        'source_status_id_str': '1117808431782662144',
#        'source_user_id': 231532644,
#        'source_user_id_str': '231532644'}]},
#     'extended_entities': {'media': [{'id': 1117808240111292416,
#        'id_str': '1117808240111292416',
#        'indices': [79, 102],
#        'media_url': 'http://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#        'url': 'https://t.co/Y7oLs314iT',
#        'display_url': 'pic.twitter.com/Y7oLs314iT',
#        'expanded_url': 'https://twitter.com/TechBrunchFR/status/1117808431782662144/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 316, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 179, 'resize': 'fit'},
#         'large': {'w': 1566, 'h': 412, 'resize': 'fit'}},
#        'source_status_id': 1117808431782662144,
#        'source_status_id_str': '1117808431782662144',
#        'source_user_id': 231532644,
#        'source_user_id_str': '231532644'}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Apr 15 15:14:32 +0000 2019',
#      'id': 1117808431782662144,
#      'id_str': '1117808431782662144',
#      'text': 'Scan a whole CIDR using Nmap &amp; aquatone - #bugbountytips https://t.co/Y7oLs314iT',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'bugbountytips', 'indices': [46, 60]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1117808240111292416,
#         'id_str': '1117808240111292416',
#         'indices': [61, 84],
#         'media_url': 'http://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#         'url': 'https://t.co/Y7oLs314iT',
#         'display_url': 'pic.twitter.com/Y7oLs314iT',
#         'expanded_url': 'https://twitter.com/TechBrunchFR/status/1117808431782662144/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 316, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 179, 'resize': 'fit'},
#          'large': {'w': 1566, 'h': 412, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1117808240111292416,
#         'id_str': '1117808240111292416',
#         'indices': [61, 84],
#         'media_url': 'http://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/D4NArAbWkAAsq_T.jpg',
#         'url': 'https://t.co/Y7oLs314iT',
#         'display_url': 'pic.twitter.com/Y7oLs314iT',
#         'expanded_url': 'https://twitter.com/TechBrunchFR/status/1117808431782662144/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 316, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 179, 'resize': 'fit'},
#          'large': {'w': 1566, 'h': 412, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 62,
#      'favorite_count': 159,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 62,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/947196900335165440/SzkHDICj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/947196900335165440/SzkHDICj_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/740605983840440320/1472409136',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 881898710963150848,
#    'id_str': '881898710963150848',
#    'name': 'Hrushikesh',
#    'screen_name': 'hkh4cks',
#    'location': 'root@localhost',
#    'description': 'Aspiring cyber-security researcher | OSCP | Synack Red Team',
#    'url': 'https://t.co/22BhT5QzdJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/22BhT5QzdJ',
#        'expanded_url': 'http://hkh4cks.com',
#        'display_url': 'hkh4cks.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 281,
#    'friends_count': 705,
#    'listed_count': 2,
#    'created_at': 'Mon Jul 03 15:33:32 +0000 2017',
#    'favourites_count': 981,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 444,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 12:54:53 +0000 2019',
#     'id': 1121034779393019904,
#     'id_str': '1121034779393019904',
#     'text': "@Expl0itabl3 @SecurityTube @nikhil_mitt That's a really good progress!",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Expl0itabl3',
#        'name': 'Expl0itabl3',
#        'id': 893221121637720069,
#        'id_str': '893221121637720069',
#        'indices': [0, 12]},
#       {'screen_name': 'SecurityTube',
#        'name': 'Pentester Academy',
#        'id': 20525891,
#        'id_str': '20525891',
#        'indices': [13, 26]},
#       {'screen_name': 'nikhil_mitt',
#        'name': 'Nikhil Mittal',
#        'id': 141590744,
#        'id_str': '141590744',
#        'indices': [27, 39]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1121033814787219456,
#     'in_reply_to_status_id_str': '1121033814787219456',
#     'in_reply_to_user_id': 893221121637720069,
#     'in_reply_to_user_id_str': '893221121637720069',
#     'in_reply_to_screen_name': 'Expl0itabl3',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1098953584899575809/7n7gk_Vx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098953584899575809/7n7gk_Vx_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/881898710963150848/1548598997',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1011536488272498689,
#    'id_str': '1011536488272498689',
#    'name': 'Code Bullet',
#    'screen_name': 'code_bullet',
#    'location': '',
#    'description': "Hey :D Evan's my name and code bulleting is my game. I do youtube and coding and stuff, just check out my youtube channel and you will figure it out.",
#    'url': 'https://t.co/yIaiqqN7be',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/yIaiqqN7be',
#        'expanded_url': 'https://www.youtube.com/CodeBullet',
#        'display_url': 'youtube.com/CodeBullet',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 11275,
#    'friends_count': 39,
#    'listed_count': 22,
#    'created_at': 'Tue Jun 26 09:07:47 +0000 2018',
#    'favourites_count': 24,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 140,
#    'lang': 'en',
#    'status': {'created_at': 'Sat Apr 20 02:13:56 +0000 2019',
#     'id': 1119423927892135937,
#     'id_str': '1119423927892135937',
#     'text': "I know its been like 2 months since my last coding video\nBUT I'M BACK BABY\nhttps://t.co/7PX6rK9ZZ1",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/7PX6rK9ZZ1',
#        'expanded_url': 'https://www.youtube.com/watch?v=K-wIZuAA3EY',
#        'display_url': 'youtube.com/watch?v=K-wIZu…',
#        'indices': [75, 98]}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 28,
#     'favorite_count': 456,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1011538355140476928/KyRWVTGJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1011538355140476928/KyRWVTGJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1011536488272498689/1553240999',
#    'profile_link_color': '269900',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 951237270044069888,
#    'id_str': '951237270044069888',
#    'name': 'AI Memes for Artificially Intelligent Teens',
#    'screen_name': 'ai_memes',
#    'location': '',
#    'description': 'Democratizing AI, one meme at the time! OC unless specified otherwise. Ran by @Aleksa_C_',
#    'url': 'https://t.co/OdUkErt5Tf',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/OdUkErt5Tf',
#        'expanded_url': 'https://www.facebook.com/artificialintelligencememes/',
#        'display_url': 'facebook.com/artificialinte…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 8866,
#    'friends_count': 24,
#    'listed_count': 55,
#    'created_at': 'Wed Jan 10 23:40:13 +0000 2018',
#    'favourites_count': 336,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 303,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 05:32:50 +0000 2019',
#     'id': 1120923533788549120,
#     'id_str': '1120923533788549120',
#     'text': 'RT @deadprogrammer: AWS is not about paying for what you use, it’s about paying for what you forgot to turn off.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'deadprogrammer',
#        'name': 'Deadprogrammer',
#        'id': 1520431,
#        'id_str': '1520431',
#        'indices': [3, 18]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Apr 24 04:26:17 +0000 2019',
#      'id': 1120906784544296961,
#      'id_str': '1120906784544296961',
#      'text': 'AWS is not about paying for what you use, it’s about paying for what you forgot to turn off.',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': []},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 673,
#      'favorite_count': 2719,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 673,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/951238874570870784/1DdUfmqr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951238874570870784/1DdUfmqr_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 14660297,
#    'id_str': '14660297',
#    'name': 'John Papa',
#    'screen_name': 'John_Papa',
#    'location': 'Orlando, FL',
#    'description': 'Husband, father, & Catholic enjoying life with my family. Working @ Microsoft. Disney fanatic, web and mobile developer, speaker, & author. Siena College grad',
#    'url': 'https://t.co/5WYl881ol0',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5WYl881ol0',
#        'expanded_url': 'http://johnpapa.net',
#        'display_url': 'johnpapa.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 83226,
#    'friends_count': 1088,
#    'listed_count': 2309,
#    'created_at': 'Mon May 05 15:00:00 +0000 2008',
#    'favourites_count': 4188,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 42609,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 01:33:16 +0000 2019',
#     'id': 1120863243998777344,
#     'id_str': '1120863243998777344',
#     'text': 'Do you @Twitch ? \n\nGive this a try! Allows your viewers to Change the color of the streamer’s @code workspace ! https://t.co/nZGGumQQql',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Twitch',
#        'name': 'Twitch',
#        'id': 309366491,
#        'id_str': '309366491',
#        'indices': [7, 14]},
#       {'screen_name': 'code',
#        'name': 'Visual Studio Code',
#        'id': 3167734591,
#        'id_str': '3167734591',
#        'indices': [94, 99]}],
#      'urls': [{'url': 'https://t.co/nZGGumQQql',
#        'expanded_url': 'https://twitter.com/ksivamuthu/status/1120862504815661056',
#        'display_url': 'twitter.com/ksivamuthu/sta…',
#        'indices': [112, 135]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1120862504815661056,
#     'quoted_status_id_str': '1120862504815661056',
#     'retweet_count': 2,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '3B94D9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/888397702391902208/CupdIngs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/888397702391902208/CupdIngs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14660297/1354078568',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'E76240',
#    'profile_sidebar_fill_color': 'F57C38',
#    'profile_text_color': 'F6DD03',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 783214,
#    'id_str': '783214',
#    'name': 'Twitter',
#    'screen_name': 'Twitter',
#    'location': 'Everywhere',
#    'description': 'What’s happening?!',
#    'url': 'https://t.co/TAXQpsHa5X',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/TAXQpsHa5X',
#        'expanded_url': 'https://about.twitter.com/',
#        'display_url': 'about.twitter.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 56108661,
#    'friends_count': 140,
#    'listed_count': 91379,
#    'created_at': 'Tue Feb 20 14:35:54 +0000 2007',
#    'favourites_count': 5869,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 9940,
#    'lang': 'en',
#    'status': {'created_at': 'Tue Apr 23 16:07:08 +0000 2019',
#     'id': 1120720772723552256,
#     'id_str': '1120720772723552256',
#     'text': '@cjoylaurel A subtweet, literally https://t.co/uxBWdede2n',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'cjoylaurel',
#        'name': 'cjlaurel',
#        'id': 999499702633615362,
#        'id_str': '999499702633615362',
#        'indices': [0, 11]}],
#      'urls': [{'url': 'https://t.co/uxBWdede2n',
#        'expanded_url': 'https://twitter.com/Twitter/status/1062497073096871936?s=20',
#        'display_url': 'twitter.com/Twitter/status…',
#        'indices': [34, 57]}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': 1120659099354451968,
#     'in_reply_to_status_id_str': '1120659099354451968',
#     'in_reply_to_user_id': 999499702633615362,
#     'in_reply_to_user_id_str': '999499702633615362',
#     'in_reply_to_screen_name': 'cjoylaurel',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1062497073096871936,
#     'quoted_status_id_str': '1062497073096871936',
#     'retweet_count': 0,
#     'favorite_count': 10,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'ACDED6',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1111729635610382336/_65QFl7B_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1111729635610382336/_65QFl7B_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/783214/1554147948',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'regular'},
#   {'id': 705253482,
#    'id_str': '705253482',
#    'name': 'Rasmus Bååth',
#    'screen_name': 'rabaath',
#    'location': 'Lund, Sweden',
#    'description': 'Data science (AKA statistics). Likes conditioning on the data (AKA Bayes). Works at King entertainment (of Candy Crush fame).',
#    'url': 'https://t.co/8xZq66xDEA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8xZq66xDEA',
#        'expanded_url': 'http://sumsar.net',
#        'display_url': 'sumsar.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4451,
#    'friends_count': 329,
#    'listed_count': 181,
#    'created_at': 'Thu Jul 19 15:20:15 +0000 2012',
#    'favourites_count': 2125,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1540,
#    'lang': 'en',
#    'status': {'created_at': 'Tue Apr 23 20:06:25 +0000 2019',
#     'id': 1120780987741495298,
#     'id_str': '1120780987741495298',
#     'text': '@noamross Since it’s ”just” a probability density, maybe just ”probability of X” whatever X might be?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'noamross',
#        'name': 'Noam Ross',
#        'id': 97582853,
#        'id_str': '97582853',
#        'indices': [0, 9]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1120779869422596103,
#     'in_reply_to_status_id_str': '1120779869422596103',
#     'in_reply_to_user_id': 97582853,
#     'in_reply_to_user_id_str': '97582853',
#     'in_reply_to_screen_name': 'noamross',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/690549092100018176/2XVFSqwi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/690549092100018176/2XVFSqwi_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/705253482/1409777734',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 791766138539610116,
#    'id_str': '791766138539610116',
#    'name': 'The Lazy Goldmaker',
#    'screen_name': 'lazygoldmaker',
#    'location': '',
#    'description': 'Azeroth Millionaire | Trade Prince Extraordinaire | https://t.co/OI4yOJRBLh | https://t.co/zCPGzMSMys',
#    'url': 'https://t.co/EQKNM83LzU',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/EQKNM83LzU',
#        'expanded_url': 'http://www.thelazygoldmaker.com',
#        'display_url': 'thelazygoldmaker.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/OI4yOJRBLh',
#        'expanded_url': 'http://twitch.tv/lazygoldmaker',
#        'display_url': 'twitch.tv/lazygoldmaker',
#        'indices': [52, 75]},
#       {'url': 'https://t.co/zCPGzMSMys',
#        'expanded_url': 'http://www.patreon.com/thelazygoldmaker',
#        'display_url': 'patreon.com/thelazygoldmak…',
#        'indices': [78, 101]}]}},
#    'protected': False,
#    'followers_count': 2698,
#    'friends_count': 155,
#    'listed_count': 21,
#    'created_at': 'Thu Oct 27 22:18:52 +0000 2016',
#    'favourites_count': 2543,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2206,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 12:22:18 +0000 2019',
#     'id': 1121026577972723712,
#     'id_str': '1121026577972723712',
#     'text': '@GumdropsEU 3 reborn sales? I havent sold a single one in WAY too long!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'GumdropsEU',
#        'name': 'Gumdrops',
#        'id': 3157689291,
#        'id_str': '3157689291',
#        'indices': [0, 11]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1120971904242860032,
#     'in_reply_to_status_id_str': '1120971904242860032',
#     'in_reply_to_user_id': 3157689291,
#     'in_reply_to_user_id_str': '3157689291',
#     'in_reply_to_screen_name': 'GumdropsEU',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/919977513211891714/VsT9_hMp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/919977513211891714/VsT9_hMp_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/791766138539610116/1508174879',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 633859328,
#    'id_str': '633859328',
#    'name': 'Scott McMillan',
#    'screen_name': 'Methodsco',
#    'location': 'Scotland',
#    'description': 'Twitch Partner, Founder and Co-owner @Methodgg | sco@method.gg for business inquiries',
#    'url': 'https://t.co/J1UhuHpCGl',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/J1UhuHpCGl',
#        'expanded_url': 'http://www.twitch.tv/sco',
#        'display_url': 'twitch.tv/sco',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 76082,
#    'friends_count': 1419,
#    'listed_count': 162,
#    'created_at': 'Thu Jul 12 16:29:43 +0000 2012',
#    'favourites_count': 14410,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 13812,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 10:11:22 +0000 2019',
#     'id': 1120993627675746306,
#     'id_str': '1120993627675746306',
#     'text': '@Djari328 @tiktok_us :)',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Djari328',
#        'name': 'djarii',
#        'id': 2232073207,
#        'id_str': '2232073207',
#        'indices': [0, 9]},
#       {'screen_name': 'tiktok_us',
#        'name': 'TikTok',
#        'id': 2401980110,
#        'id_str': '2401980110',
#        'indices': [10, 20]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': 1120991705409495040,
#     'in_reply_to_status_id_str': '1120991705409495040',
#     'in_reply_to_user_id': 2232073207,
#     'in_reply_to_user_id_str': '2232073207',
#     'in_reply_to_screen_name': 'Djari328',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1001870222738051073/kXadVvBb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001870222738051073/kXadVvBb_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/633859328/1554670696',
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 477213534,
#    'id_str': '477213534',
#    'name': 'Method',
#    'screen_name': 'Methodgg',
#    'location': 'United Kingdom',
#    'description': 'The official Twitter account of esports organization Method. #MethodWay   Business Inquires: management@method.gg',
#    'url': 'https://t.co/irYoZKwx3I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/irYoZKwx3I',
#        'expanded_url': 'http://www.method.gg',
#        'display_url': 'method.gg',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 127797,
#    'friends_count': 612,
#    'listed_count': 329,
#    'created_at': 'Sat Jan 28 23:33:37 +0000 2012',
#    'favourites_count': 12368,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 12435,
#    'lang': 'en',
#    'status': {'created_at': 'Wed Apr 24 09:30:45 +0000 2019',
#     'id': 1120983404084781056,
#     'id_str': '1120983404084781056',
#     'text': 'With 8 Cores, 9th Gen Intel® Core™ i9 processor provides better performance. Dare to challenge your previous gaming… https://t.co/nSPyluIEHZ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/nSPyluIEHZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1120983404084781056',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 27,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1005438934191656961/AOeHvdP7_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1005438934191656961/AOeHvdP7_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/477213534/1554221753',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 16273417,
#    'id_str': '16273417',
#    'name': 'Ned Batchelder',
#    'screen_name': 'nedbat',
#    'location': 'Boston',
#    'description': "Python, software, typography, juggling, Boston, sometimes autism. Laughing at the world doesn't mean I don't take it seriously. He/him.",
#    'url': 'http://t.co/j9QcJdtRnb',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/j9QcJdtRnb',
#        'expanded_url': 'http://nedbatchelder.com',
#        'display_url': 'nedbatchelder.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 8939,
#    'friends_count': 135,
#    'listed_count': 410,
#    'created_at': 'Sat Sep 13 16:56:32 +0000 2008',
#    'favourites_count': 469,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6688,
#    'lang': 'en',
#    'status': {'created_at': 'Tue Apr 23 15:03:43 +0000 2019',
#     'id': 1120704812553789440,
#     'id_str': '1120704812553789440',
#     'text': 'RT @henryseg: Cannon-Thurston maps for veering triangulations, joint work with @bachmandesign and @SaulSchleimer. https://t.co/jNlg75cFak',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'henryseg',
#        'name': 'Henry Segerman',
#        'id': 14118089,
#        'id_str': '14118089',
#        'indices': [3, 12]},
#       {'screen_name': 'bachmandesign',
#        'name': 'David Bachman',
#        'id': 749092506730582016,
#        'id_str': '749092506730582016',
#        'indices': [79, 93]},
#       {'screen_name': 'SaulSchleimer',
#        'name': 'Saul Schleimer',
#        'id': 975427037455355904,
#        'id_str': '975427037455355904',
#        'indices': [98, 112]}],
#      'urls': [],
#      'media': [{'id': 1120680379344654337,
#        'id_str': '1120680379344654337',
#        'indices': [114, 137],
#        'media_url': 'http://pbs.twimg.com/media/D4103g2WkAEZIH8.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D4103g2WkAEZIH8.jpg',
#        'url': 'https://t.co/jNlg75cFak',
#        'display_url': 'pic.twitter.com/jNlg75cFak',
#        'expanded_url': 'https://twitter.com/henryseg/status/1120680492553076737/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 2000, 'h': 2000, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}},
#        'source_status_id': 1120680492553076737,
#        'source_status_id_str': '1120680492553076737',
#        'source_user_id': 14118089,
#        'source_user_id_str': '14118089'}]},
#     'extended_entities': {'media': [{'id': 1120680379344654337,
#        'id_str': '1120680379344654337',
#        'indices': [114, 137],
#        'media_url': 'http://pbs.twimg.com/media/D4103g2WkAEZIH8.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D4103g2WkAEZIH8.jpg',
#        'url': 'https://t.co/jNlg75cFak',
#        'display_url': 'pic.twitter.com/jNlg75cFak',
#        'expanded_url': 'https://twitter.com/henryseg/status/1120680492553076737/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 2000, 'h': 2000, 'resize': 'fit'},
# ...
#        'expanded_url': 'http://softy-shop.com',
#        'display_url': 'softy-shop.com',
#        'indices': [73, 96]}]}},
#    'protected': False,
#    'followers_count': 13137,
#    'friends_count': 101,
#    'listed_count': 112,
#    'created_at': 'Sat Dec 27 17:12:00 +0000 2014',
#    'favourites_count': 1439,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 734,
#    'lang': 'en',
#    'status': {'created_at': 'Fri Apr 19 21:36:17 +0000 2019',
#     'id': 1119354054805577728,
#     'id_str': '1119354054805577728',
#     'text': '@colebemis Depends, it _is_ annoying when you need to make frequent deletions, however important they may be (e.g. deleting in cPanel)',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'colebemis',
#        'name': 'Cole Bemis',
#        'id': 185964385,
#        'id_str': '185964385',
#        'indices': [0, 10]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': 1119318525477183488,
#     'in_reply_to_status_id_str': '1119318525477183488',
#     'in_reply_to_user_id': 185964385,
#     'in_reply_to_user_id_str': '185964385',
#     'in_reply_to_screen_name': 'colebemis',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/979423607796334593/pTpjJ2LM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/979423607796334593/pTpjJ2LM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2944066131/1505032713',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 357134227,
#    'id_str': '357134227',
#    'name': 'Mikel Bober-Irizar',
#    'screen_name': 'mikb0b',
#    'location': 'Guildford, England',
#    'description': "17yo Machine Learning Engineer // Kaggle Top 50, tech enthusiast, BTC trader and gamer. When I'm not doing homework I'm building servers or playing overwatch.",
#    'url': 'https://t.co/auc3Do7wAM',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/auc3Do7wAM',
#        'expanded_url': 'http://mxbi.net',
#        'display_url': 'mxbi.net',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5045,
#    'friends_count': 475,
#    'listed_count': 93,
#    'created_at': 'Wed Aug 17 22:14:13 +0000 2011',
#    'favourites_count': 2005,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 599,
#    'lang': 'en',
#    'status': {'created_at': 'Mon Apr 01 14:34:39 +0000 2019',
#     'id': 1112724965642698753,
#     'id_str': '1112724965642698753',
#     'text': 'RT @kaggle: Announcing exciting new changes to the Kaggle progression system. Read all the details then let us know what you think! 👉 https…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kaggle',
#        'name': 'Kaggle',
#        'id': 80422885,
#        'id_str': '80422885',
#        'indices': [3, 10]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Apr 01 14:10:10 +0000 2019',
#      'id': 1112718800951103488,
#      'id_str': '1112718800951103488',
#      'text': 'Announcing exciting new changes to the Kaggle progression system. Read all the details then let us know what you th… https://t.co/QCtiBx9ukZ',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/QCtiBx9ukZ',
#         'expanded_url': 'https://twitter.com/i/web/status/1112718800951103488',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 52,
#      'favorite_count': 186,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 52,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835951192207339521/ZSO1KktW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835951192207339521/ZSO1KktW_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/357134227/1429730506',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1220791675,
#    'id_str': '1220791675',
#    'name': 'Ben Brode',
#    'screen_name': 'bbrode',
#    'location': 'Orange County, CA',
#    'description': 'Chief Creative Officer at @SecondDinner.\nPreviously Hearthstone Game Director @ Blizzard.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 167544,
#    'friends_count': 137,
#    'listed_count': 995,
#    'created_at': 'Tue Feb 26 07:50:26 +0000 2013',
#    'favourites_count': 12106,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 11068,
#    'lang': 'en',
#    'status': {'created_at': 'Tue Apr 23 16:37:51 +0000 2019',
#     'id': 1120728499969335296,
#     'id_str': '1120728499969335296',
#     'text': '@Toxiclaw666 @IksarHS holy shit yeah that was awesome',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Toxiclaw666',
#        'name': 'Toxiclow',
#        'id': 4722534912,
#        'id_str': '4722534912',
#        'indices': [0, 12]},
#       {'screen_name': 'IksarHS',
#        'name': 'August Dean Ayala',
#        'id': 1034268901,
#        'id_str': '1034268901',
#        'indices': [13, 21]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': 1119559678436864001,
#     'in_reply_to_status_id_str': '1119559678436864001',
#     'in_reply_to_user_id': 4722534912,
#     'in_reply_to_user_id_str': '4722534912',
#     'in_reply_to_screen_name': 'Toxiclaw666',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 9,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757311850174308352/_exUGkqs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/757311850174308352/_exUGkqs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1220791675/1534355423',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 866416973739175937,
#    'id_str': '866416973739175937',
#    'name': '+380991741601',
#    'screen_name': 'nikolaysto2',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 0,
#    'listed_count': 0,
#    'created_at': 'Sun May 21 22:14:38 +0000 2017',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2,
#    'lang': 'ru',
#    'status': {'created_at': 'Mon Jan 29 20:28:12 +0000 2018',
#     'id': 958074319573323776,
#     'id_str': '958074319573323776',
#     'text': "Аудио: Elvis Presley — Can't help falling in love https://t.co/UsvgcGc3S2",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/UsvgcGc3S2',
#        'expanded_url': 'https://lingualeo.com/ru/jungle/elvis-presley-cant-help-falling-in-love-63008',
#        'display_url': 'lingualeo.com/ru/jungle/elvi…',
#        'indices': [50, 73]}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': True,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 503636053,
#    'id_str': '503636053',
#    'name': 'WACKO',
#    'screen_name': 'WACKOFPS',
#    'location': 'Manchester, England',
#    'description': 'Apex player for @PENTA_Sports. \n\n@qteaa_ ☕️❤️',
#    'url': 'https://t.co/fOaT0MySS9',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fOaT0MySS9',
#        'expanded_url': 'https://www.youtube.com/FPSWacko',
#        'display_url': 'youtube.com/FPSWacko',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4279,
#    'friends_count': 398,
#    'listed_count': 17,
#    'created_at': 'Sat Feb 25 22:24:55 +0000 2012',
#    'favourites_count': 9111,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 1695,
#    'lang': 'en',
#    'status': {'created_at': 'Tue Apr 23 12:25:22 +0000 2019',
#     'id': 1120664960080785411,
#     'id_str': '1120664960080785411',
#     'text': "@FRESHY_GG @TSM_THump The EU and NA committee are separate. The vote he's talking about was discussed only in the NA discord.",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'FRESHY_GG',
#        'name': 'FRESHY',
#        'id': 2752907264,
#        'id_str': '2752907264',
#        'indices': [0, 10]},
#       {'screen_name': 'TSM_THump',
#        'name': 'THump',
#        'id': 1053127695851237376,
#        'id_str': '1053127695851237376',
#        'indices': [11, 21]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1120660290381799424,
#     'in_reply_to_status_id_str': '1120660290381799424',
#     'in_reply_to_user_id': 2752907264,
#     'in_reply_to_user_id_str': '2752907264',
#     'in_reply_to_screen_name': 'FRESHY_GG',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1080882461696016384/N9tMl6NN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080882461696016384/N9tMl6NN_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/503636053/1551724224',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1597747546500080087,
#  'next_cursor_str': '1597747546500080087',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
# And let's see only friends' name
for num, friends in enumerate(friends['users']):
    print ('My friend #{0}\t{1}'.format(num+1, friends['name'].encode("utf-8")))
# Out:
# My friend #1	b'Sudhakar Verma'
# My friend #2	b'Nikhil Joshi'
# My friend #3	b'Iniquitous'
# My friend #4	b'Hrushikesh'
# My friend #5	b'Code Bullet'
# My friend #6	b'AI Memes for Artificially Intelligent Teens'
# My friend #7	b'John Papa'
# My friend #8	b'Twitter'
# My friend #9	b'Rasmus B\xc3\xa5\xc3\xa5th'
# My friend #10	b'The Lazy Goldmaker'
# My friend #11	b'Scott McMillan'
# My friend #12	b'Method'
# My friend #13	b'Ned Batchelder'
# My friend #14	b'Patrick Shyu'
# My friend #15	b'Kent Davis'
# My friend #16	b'angela he'
# My friend #17	b'Mikel Bober-Irizar'
# My friend #18	b'Ben Brode'
# My friend #19	b'+380991741601'
# My friend #20	b'WACKO'

# %% [markdown]
# ### 1.4:  Finding what are in the trend somewhere
#
# We can return the top 50 trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, London has a `WOEID` of 44418. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in London

# %%
url_4 = 'https://api.twitter.com/1.1/trends/place.json?id=44418'
res = requests.get(url_4, auth=auth)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

top50_trends = res.json()
top50_trends
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/trends/place.json?id=44418
# [{'trends': [{'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 92146},
#    {'name': '#WeStandWithLyra',
#     'url': 'http://twitter.com/search?q=%23WeStandWithLyra',
#     'promoted_content': None,
#     'query': '%23WeStandWithLyra',
#     'tweet_volume': None},
#    {'name': '#WednesdayWisdom',
#     'url': 'http://twitter.com/search?q=%23WednesdayWisdom',
#     'promoted_content': None,
#     'query': '%23WednesdayWisdom',
#     'tweet_volume': 48085},
#    {'name': '#PMQs',
#     'url': 'http://twitter.com/search?q=%23PMQs',
#     'promoted_content': None,
#     'query': '%23PMQs',
#     'tweet_volume': None},
#    {'name': '#StopFoodWasteDay',
#     'url': 'http://twitter.com/search?q=%23StopFoodWasteDay',
#     'promoted_content': None,
#     'query': '%23StopFoodWasteDay',
#     'tweet_volume': None},
#    {'name': '#ManchesterDerby',
#     'url': 'http://twitter.com/search?q=%23ManchesterDerby',
#     'promoted_content': None,
#     'query': '%23ManchesterDerby',
#     'tweet_volume': 12867},
#    {'name': 'Eric Cantona',
#     'url': 'http://twitter.com/search?q=%22Eric+Cantona%22',
#     'promoted_content': None,
#     'query': '%22Eric+Cantona%22',
#     'tweet_volume': None},
#    {'name': 'Toby Young',
#     'url': 'http://twitter.com/search?q=%22Toby+Young%22',
#     'promoted_content': None,
#     'query': '%22Toby+Young%22',
#     'tweet_volume': None},
#    {'name': 'Nicola Sturgeon',
#     'url': 'http://twitter.com/search?q=%22Nicola+Sturgeon%22',
#     'promoted_content': None,
#     'query': '%22Nicola+Sturgeon%22',
#     'tweet_volume': None},
#    {'name': 'Ann Widdecombe',
#     'url': 'http://twitter.com/search?q=%22Ann+Widdecombe%22',
#     'promoted_content': None,
#     'query': '%22Ann+Widdecombe%22',
#     'tweet_volume': 31485},
#    {'name': 'Huawei',
#     'url': 'http://twitter.com/search?q=Huawei',
#     'promoted_content': None,
#     'query': 'Huawei',
#     'tweet_volume': 51744},
#    {'name': 'Jackson Carlaw',
#     'url': 'http://twitter.com/search?q=%22Jackson+Carlaw%22',
#     'promoted_content': None,
#     'query': '%22Jackson+Carlaw%22',
#     'tweet_volume': None},
#    {'name': 'Scottish Parliament',
#     'url': 'http://twitter.com/search?q=%22Scottish+Parliament%22',
#     'promoted_content': None,
#     'query': '%22Scottish+Parliament%22',
#     'tweet_volume': None},
#    {'name': "St Anne's Cathedral",
#     'url': 'http://twitter.com/search?q=%22St+Anne%27s+Cathedral%22',
#     'promoted_content': None,
#     'query': '%22St+Anne%27s+Cathedral%22',
#     'tweet_volume': None},
#    {'name': 'David Lidington',
#     'url': 'http://twitter.com/search?q=%22David+Lidington%22',
#     'promoted_content': None,
#     'query': '%22David+Lidington%22',
#     'tweet_volume': None},
#    {'name': 'Richard Leonard',
#     'url': 'http://twitter.com/search?q=%22Richard+Leonard%22',
#     'promoted_content': None,
#     'query': '%22Richard+Leonard%22',
#     'tweet_volume': None},
#    {'name': 'Judd Trump',
#     'url': 'http://twitter.com/search?q=%22Judd+Trump%22',
#     'promoted_content': None,
#     'query': '%22Judd+Trump%22',
#     'tweet_volume': None},
#    {'name': 'Stephen Lusty',
#     'url': 'http://twitter.com/search?q=%22Stephen+Lusty%22',
#     'promoted_content': None,
#     'query': '%22Stephen+Lusty%22',
#     'tweet_volume': None},
#    {'name': 'Citizens Assembly',
#     'url': 'http://twitter.com/search?q=%22Citizens+Assembly%22',
#     'promoted_content': None,
#     'query': '%22Citizens+Assembly%22',
#     'tweet_volume': None},
#    {'name': 'planet zoo',
#     'url': 'http://twitter.com/search?q=%22planet+zoo%22',
#     'promoted_content': None,
#     'query': '%22planet+zoo%22',
#     'tweet_volume': None},
#    {'name': 'The Westminster',
#     'url': 'http://twitter.com/search?q=%22The+Westminster%22',
#     'promoted_content': None,
#     'query': '%22The+Westminster%22',
#     'tweet_volume': None},
#    {'name': 'The Cliff',
#     'url': 'http://twitter.com/search?q=%22The+Cliff%22',
#     'promoted_content': None,
#     'query': '%22The+Cliff%22',
#     'tweet_volume': None},
#    {'name': 'Baron',
#     'url': 'http://twitter.com/search?q=Baron',
#     'promoted_content': None,
#     'query': 'Baron',
#     'tweet_volume': 11794},
#    {'name': 'Section 30',
#     'url': 'http://twitter.com/search?q=%22Section+30%22',
#     'promoted_content': None,
#     'query': '%22Section+30%22',
#     'tweet_volume': None},
#    {'name': 'Thepchaiya Un-Nooh',
#     'url': 'http://twitter.com/search?q=%22Thepchaiya+Un-Nooh%22',
#     'promoted_content': None,
#     'query': '%22Thepchaiya+Un-Nooh%22',
#     'tweet_volume': None},
#    {'name': 'Emily Thornberry',
#     'url': 'http://twitter.com/search?q=%22Emily+Thornberry%22',
#     'promoted_content': None,
#     'query': '%22Emily+Thornberry%22',
#     'tweet_volume': None},
#    {'name': '5 Jobs',
#     'url': 'http://twitter.com/search?q=%225+Jobs%22',
#     'promoted_content': None,
#     'query': '%225+Jobs%22',
#     'tweet_volume': 20620},
#    {'name': 'Willie Rennie',
#     'url': 'http://twitter.com/search?q=%22Willie+Rennie%22',
#     'promoted_content': None,
#     'query': '%22Willie+Rennie%22',
#     'tweet_volume': None},
#    {'name': 'Planet Coaster',
#     'url': 'http://twitter.com/search?q=%22Planet+Coaster%22',
#     'promoted_content': None,
#     'query': '%22Planet+Coaster%22',
#     'tweet_volume': None},
#    {'name': 'Brent',
#     'url': 'http://twitter.com/search?q=Brent',
#     'promoted_content': None,
#     'query': 'Brent',
#     'tweet_volume': 12115},
#    {'name': 'Frontier',
#     'url': 'http://twitter.com/search?q=Frontier',
#     'promoted_content': None,
#     'query': 'Frontier',
#     'tweet_volume': None},
#    {'name': 'Crumlin - Sign the Petition',
#     'url': 'http://twitter.com/search?q=%22Crumlin+-+Sign+the+Petition%22',
#     'promoted_content': None,
#     'query': '%22Crumlin+-+Sign+the+Petition%22',
#     'tweet_volume': None},
#    {'name': 'atp finals',
#     'url': 'http://twitter.com/search?q=%22atp+finals%22',
#     'promoted_content': None,
#     'query': '%22atp+finals%22',
#     'tweet_volume': None},
#    {'name': '#MUNMCI',
#     'url': 'http://twitter.com/search?q=%23MUNMCI',
#     'promoted_content': None,
#     'query': '%23MUNMCI',
#     'tweet_volume': 18834},
#    {'name': '#WednesdayMotivation',
#     'url': 'http://twitter.com/search?q=%23WednesdayMotivation',
#     'promoted_content': None,
#     'query': '%23WednesdayMotivation',
#     'tweet_volume': 23012},
#    {'name': '#5jobsivehad',
#     'url': 'http://twitter.com/search?q=%235jobsivehad',
#     'promoted_content': None,
#     'query': '%235jobsivehad',
#     'tweet_volume': None},
#    {'name': '#BOND25',
#     'url': 'http://twitter.com/search?q=%23BOND25',
#     'promoted_content': None,
#     'query': '%23BOND25',
#     'tweet_volume': None},
#    {'name': '#PoliticsLive',
#     'url': 'http://twitter.com/search?q=%23PoliticsLive',
#     'promoted_content': None,
#     'query': '%23PoliticsLive',
#     'tweet_volume': None},
#    {'name': '#AvangersEndgame',
#     'url': 'http://twitter.com/search?q=%23AvangersEndgame',
#     'promoted_content': None,
#     'query': '%23AvangersEndgame',
#     'tweet_volume': 54263},
#    {'name': '#CYBERUK19',
#     'url': 'http://twitter.com/search?q=%23CYBERUK19',
#     'promoted_content': None,
#     'query': '%23CYBERUK19',
#     'tweet_volume': None},
#    {'name': '#OPPOReno',
#     'url': 'http://twitter.com/search?q=%23OPPOReno',
#     'promoted_content': None,
#     'query': '%23OPPOReno',
#     'tweet_volume': None},
#    {'name': '#WorldMeningitisDay',
#     'url': 'http://twitter.com/search?q=%23WorldMeningitisDay',
#     'promoted_content': None,
#     'query': '%23WorldMeningitisDay',
#     'tweet_volume': None},
#    {'name': '#lilac19',
#     'url': 'http://twitter.com/search?q=%23lilac19',
#     'promoted_content': None,
#     'query': '%23lilac19',
#     'tweet_volume': None},
#    {'name': '#CIfA2019',
#     'url': 'http://twitter.com/search?q=%23CIfA2019',
#     'promoted_content': None,
#     'query': '%23CIfA2019',
#     'tweet_volume': None},
#    {'name': '#EIE19',
#     'url': 'http://twitter.com/search?q=%23EIE19',
#     'promoted_content': None,
#     'query': '%23EIE19',
#     'tweet_volume': None},
#    {'name': '#ValuingHarmony',
#     'url': 'http://twitter.com/search?q=%23ValuingHarmony',
#     'promoted_content': None,
#     'query': '%23ValuingHarmony',
#     'tweet_volume': None},
#    {'name': '#fiveJobsIveHad',
#     'url': 'http://twitter.com/search?q=%23fiveJobsIveHad',
#     'promoted_content': None,
#     'query': '%23fiveJobsIveHad',
#     'tweet_volume': None},
#    {'name': '#wednesdaythoughts',
#     'url': 'http://twitter.com/search?q=%23wednesdaythoughts',
#     'promoted_content': None,
#     'query': '%23wednesdaythoughts',
#     'tweet_volume': 10443},
#    {'name': '#LYRA',
#     'url': 'http://twitter.com/search?q=%23LYRA',
#     'promoted_content': None,
#     'query': '%23LYRA',
#     'tweet_volume': None},
#    {'name': '#foodwaste',
#     'url': 'http://twitter.com/search?q=%23foodwaste',
#     'promoted_content': None,
#     'query': '%23foodwaste',
#     'tweet_volume': None}],
#   'as_of': '2019-04-24T13:24:44Z',
#   'created_at': '2019-04-24T13:20:08Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# And let's see only the first 10 trends names and the respective URL
for i, trend in enumerate(top50_trends[0]['trends'][:10]):
    print ('{0} - {1} - URL: {2}'.format(i+1, trend['name'], trend['url']))
# Out:
# 1 - Liverpool - URL: http://twitter.com/search?q=Liverpool
# 2 - #WeStandWithLyra - URL: http://twitter.com/search?q=%23WeStandWithLyra
# 3 - #WednesdayWisdom - URL: http://twitter.com/search?q=%23WednesdayWisdom
# 4 - #PMQs - URL: http://twitter.com/search?q=%23PMQs
# 5 - #StopFoodWasteDay - URL: http://twitter.com/search?q=%23StopFoodWasteDay
# 6 - #ManchesterDerby - URL: http://twitter.com/search?q=%23ManchesterDerby
# 7 - Eric Cantona - URL: http://twitter.com/search?q=%22Eric+Cantona%22
# 8 - Toby Young - URL: http://twitter.com/search?q=%22Toby+Young%22
# 9 - Nicola Sturgeon - URL: http://twitter.com/search?q=%22Nicola+Sturgeon%22
# 10 - Ann Widdecombe - URL: http://twitter.com/search?q=%22Ann+Widdecombe%22

# %%
url_5 = 'https://api.twitter.com/1.1/trends/place.json?id=922137'
res = requests.get(url_5, auth=auth)

top50_trends = res.json()
list2 = top50_trends[0]['trends']
print(len(list2))
name = [i['name'] for i in list2 if i['tweet_volume'] is not None]
tweet_volume = [i['tweet_volume'] for i in list2 if i['tweet_volume'] is not None]
dict2 = dict(zip(name, tweet_volume))
dict2 = sorted(dict2.items(), key=lambda x: x[1], reverse=True)
# top50_trends
# And let's see only the first 10 trends names and the respective URL
c = 0
for name, tweet_volume in dict2:
    print ('{0} - {1} - Vol: {2}'.format(c+1, name, tweet_volume))
    c += 1
# Out:
# 47
# 1 - #BBMAsTopSocial - Vol: 8558406
# 2 - president - Vol: 1150367
# 3 - #AvengersEndgame - Vol: 809795
# 4 - #GameofThrones - Vol: 384889
# 5 - Absolutely - Vol: 349292
# 6 - Brexit - Vol: 222130
# 7 - iPhone - Vol: 161598
# 8 - europe - Vol: 149803
# 9 - Putin - Vol: 126881
# 10 - президента - Vol: 17233
# 11 - Думаю - Vol: 12849
# 12 - В России - Vol: 12333

# %% [markdown]
# ### 1.5: Streaming
#
# Twitter offers a [Streaming API](https://dev.twitter.com/streaming/overview) to make it easier to query streams of tweets.  The Stream API encapsulates some pain points of REST access to ensure that Stream calls don't exceed the rate limit. These tool allows to get tweet data when it appears in real time. There are three stream types:
#
# - `Public Streams:` Streams of public data flowthing through Twitter. Suitable for followign specific users, topics or for data mining.
# - `User Streams:` Single-user streams. Containing roughly all of the data corresponding with a single user's view of Twitter.
# - `Site Streams:` The multi-user version of user streams.
#
# >Connecting to the streaming API requires keeping a persistent HTTP connection open. In many cases this involves thinking about your application differently than if you were interacting with the REST API. An app which connects to the Streaming APIs will not be able to establish a connection in response to a user request. Instead, the code for maintaining the Streaming connection is typically run in a process separate from the process which handles HTTP requests. The streaming process gets the input tweets and performs any parsing, filtering, and/or aggregation needed before storing the result to a data store. The HTTP handling process queries the data store for results in response to user requests. While this model is more complex than the first example, the benefits from having a realtime stream of tweet data make the integration worthwhile for many types of apps.
#
# With `requests.Response.iter_lines()` you can easily iterate over streaming APIs including the **Twitter Streaming API**. Simply set `stream` parameter to `True` and iterate over the response with `iter_lines()`.
#
# Depending on the search term/terms, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#android_ hashtag:

# %%
#This cell doesn't have limits and doesn't stop automatically. You need to interrupt it by yourself.
import time

url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=android'
res = requests.get(url_5, auth=auth, stream=True)

print (res, res.status_code, res.headers['content-type'])
print (res.url, "\n")

# Let's measure the time elapsed after the start of streaming 
start = time.time()
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line)
        print ("Elapsed:", time.time()-start, "sec", parsed_line["created_at"], "\n", parsed_line['text'].encode("utf-8"), "\n")
# Out:
# <Response [200]> 200 application/json
# https://stream.twitter.com/1.1/statuses/filter.json?track=android
#
# Elapsed: 1.0023562908172607 sec Wed Apr 24 13:47:03 +0000 2019
#  b'RT @gamecast_blog: \xe5\xa4\xa2\xe3\x81\xaf\xe7\xab\x8b\xe6\xb4\xbe\xe3\x81\xaa\xe8\x87\x93\xe7\x89\xa9\xe6\xa0\xbd\xe5\x9f\xb9\xe5\xae\xb6! iOS/Android\xe3\x81\xab\xe7\x99\xbb\xe5\xa0\xb4\xe3\x80\x82\n\nhttps://t.co/2e61wduwp8 ht\xe2\x80\xa6'
#
# Elapsed: 1.1659486293792725 sec Wed Apr 24 13:47:03 +0000 2019
#  b'SKDKDJDJDJ'
#
# Elapsed: 1.1676244735717773 sec Wed Apr 24 13:47:03 +0000 2019
#  b'RT @CDMagu_: If you tweet from an iPhone or Android you got nothing on me LOOOL'
#
# Elapsed: 1.67985200881958 sec Wed Apr 24 13:47:04 +0000 2019
#  b'RT @CDMagu_: If you tweet from an iPhone or Android you got nothing on me LOOOL'
#
# Elapsed:

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-79d8a9d93680> in <module>
#      10 # Let's measure the time elapsed after the start of streaming
#      11 start = time.time()
# ---> 12 for line in res.iter_lines():
#      13     # filter out keep-alive new lines
#      14     if line:
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     792         pending = None
#     793
# --> 794         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     795
#     796             if pending is not None:
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/.local/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %% [markdown]
# > ### Exercise 1.1:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display the list of all your friends (first 200) and sort them by its followers amounts in descending order. Record a sorted list of names in the `friends` dictionaries containing keys "name" and "followers_count" with respective data.
#
# > #### HINT: `GET friends/list`  will be helpfull for you here.

# %%
# type your code here
url = 'https://api.twitter.com/1.1/friends/list.json'
params = {
    # "q": 'python OR IPython',
    "q": '#BBMAsTopSocial',
    "count": 5, 
    "show_user": False,
    "geocode": '51.509865,-0.118092,20mi',
    "lang": 'en'
}
res = requests.get(url_3, auth=auth)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

friends = res.json()
# print(friends)
keys = []
values = []
for num, friends in enumerate(friends['users']):
    print ('My friend #{0}\t{1}'.format(num+1, friends['name'].encode("utf-8")))
    keys.append(friends['name'].encode("utf-8"))
    values.append(friends['followers_count'])

params = 0

friends = dict(zip(keys, values))
friends = sorted(friends.items(), key=lambda x: x[1], reverse=True)
friends

# url = ...
# params = ...

# friends = ...
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/friends/list.json
# My friend #1	b'Sudhakar Verma'
# My friend #2	b'Nikhil Joshi'
# My friend #3	b'Iniquitous'
# My friend #4	b'Hrushikesh'
# My friend #5	b'Code Bullet'
# My friend #6	b'AI Memes for Artificially Intelligent Teens'
# My friend #7	b'John Papa'
# My friend #8	b'Twitter'
# My friend #9	b'Rasmus B\xc3\xa5\xc3\xa5th'
# My friend #10	b'The Lazy Goldmaker'
# My friend #11	b'Scott McMillan'
# My friend #12	b'Method'
# My friend #13	b'Ned Batchelder'
# My friend #14	b'Patrick Shyu'
# My friend #15	b'Kent Davis'
# My friend #16	b'angela he'
# My friend #17	b'Mikel Bober-Irizar'
# My friend #18	b'Ben Brode'
# My friend #19	b'+380991741601'
# My friend #20	b'WACKO'
# [(b'Twitter', 56108749),
#  (b'Ben Brode', 167540),
#  (b'Method', 127805),
#  (b'John Papa', 83227),
#  (b'Scott McMillan', 76096),
#  (b'angela he', 13138),
#  (b'Code Bullet', 11277),
#  (b'Kent Davis', 11135),
#  (b'Ned Batchelder', 8939),
#  (b'AI Memes for Artificially Intelligent Teens', 8866),
#  (b'Patrick Shyu', 8864),
#  (b'Mikel Bober-Irizar', 5045),
#  (b'Rasmus B\xc3\xa5\xc3\xa5th', 4451),
#  (b'WACKO', 4278),
#  (b'The Lazy Goldmaker', 2698),
#  (b'Sudhakar Verma', 438),
#  (b'Iniquitous', 362),
#  (b'Hrushikesh', 281),
#  (b'Nikhil Joshi', 94),
#  (b'+380991741601', 1)]

# %%
from test_helper import Test

Test.twitterFriendsList(friends, url, auth, params, 'Incorrect query', "Exercise 1.1 is successful")
# Out:
# 1 test failed. Incorrect query

# %% [markdown]
# > ### Exercise 1.2:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display the list of 5 (or less if there is not so much) most recent tweets liked by you, which were also retweeted (`retweet_count` is not equal to zero). You shoud save the date of creation, author of the tweet, its text and retweets amount to the list `result` contains dictionaries with keys `"created_at"`, `"author"` and `"text"`, `"retweet_count"`.
#
# > #### HINT: `GET favorites/list` will be helpfull for you here

# %%
# type your code here
url = 'https://api.twitter.com/1.1/favorites/list.json'
res = requests.get(url, auth=auth)

print (res, res.status_code, res.headers['content-type'])
print (res.url)

friends = res.json()
keys = []
values = []
keys1 = []
values1 = []
for num, friends in enumerate(friends):
    #print 'My likes #{0}\t{1}'.format(num+1, friends)
    keys.append(friends['created_at'].encode("utf-8"))
    values.append(friends['retweet_count'])
    keys1.append(friends['user']['screen_name'])
    values1.append(friends['text'].encode("utf-8"))
import pandas as pd
params = pd.DataFrame({"created_at":keys,
         "author":keys1,
         "text":values1,
         "retweet_count":values})
result = params[:5]
result.head(5)
# url = ...
# params = ...

# result = ...
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/favorites/list.json
#                           created_at          author  \
# 0  b'Fri Apr 12 13:47:55 +0000 2019'      _sudhackar
# 1  b'Thu Mar 21 21:02:03 +0000 2019'            jack
# 2  b'Sun Feb 17 06:50:20 +0000 2019'        karpathy
# 3  b'Wed Nov 14 17:04:31 +0000 2018'  TheRealStanLee
# 4  b'Tue Nov 13 08:01:00 +0000 2018'        Methodgg
#
#                                                 text  retweet_count
# 0  b'Enjoyed my easy-shell and peasy-shell for @n...              5
# 1  b'Happy 13th, @Twitter! \xe2\x9d\xa4\xef\xb8\x...           2537
# 2  b'Loved seeing Alita - really well done CGI, c...             16
# 3  b'So many wonderful moments with Stan came spo...         112547
# 4  b'Where were you when Arthas unleashed the Sco...            139

# %%
Test.twitterRecentTweets(result, url, auth, params, 'Incorrect query', "Exercise 1.2 is successful")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e5f33755cf3f> in <module>()
# ----> 1 Test.twitterRecentTweets(result, url, auth, params, 'Incorrect query', "Exercise 1.2 is successful")
#
# /usr/local/lib/python2.7/dist-packages/test_helper/test_helper.pyc in twitterRecentTweets(cls, tweets, url, auth, params, msg, msg_success)
#     398     @classmethod
#     399     def twitterRecentTweets(cls, tweets, url, auth, params, msg="", msg_success=""):
# --> 400         res = requests.get(url, auth=auth, params=params)
#     401         data = res.json()
#     402         result = []
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /usr/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     444             data = data or {},
#     445             json = json,
# --> 446             params = params or {},
#     447             auth = auth,
#     448             cookies = cookies,
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __nonzero__(self)
#     885         raise ValueError("The truth value of a {0} is ambiguous. "
#     886                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 887                          .format(self.__class__.__name__))
#     888
#     889     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# > ### Exercise 1.3:
#
# > Using [Twitter Streaming API](https://dev.twitter.com/streaming/overview) and `requests` Python library collect to the `last_tweets` Python list all tweets with hashtags _#twitter_, _#tweet_ and _#world_ that where appearing over 5 minutes (after that you ran a stream). `last_tweets` should contain 5 nested list each of which corresponds to tweets appeard over one minute along these 5 minutes (i.e. `last_tweets` should have form `[["tweets", "per", "the", "first", "minute"], ["tweets", "per", "the", "second", "minute"], ... ]`. Count also how many tweets written on English or written by user who has over 1000 follower were appearing each minute and write these 5 numbers to the `count5` Python tuple.
#
# > #### HINT: `POST statuses/filter` will be helpfull for you here

# %%
# type your code here
import time

url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=q'
params = {
    "q": 'twitter OR tweet OR world',
    #"count": 5, 
    #"show_user": False,
    #"geocode": '51.509865,-0.118092,20mi',
    #"lang": 'en'
}
res = requests.get(url_5, auth=auth, stream=True)

print (res, res.status_code, res.headers['content-type'])
print (res.url, "\n")

# Let's measure the time elapsed after the start of streaming 
start = time.time()
l1,l2,l3,l4,l5 = [],[],[],[],[]
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line)
        print ("Elapsed:", time.time()-start, "sec", parsed_line["created_at"], "\n", parsed_line['text'].encode("utf-8"), "\n")
        cap = int(time.time()-start)
        print (cap)
        if cap<60:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>60:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap<120:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>180:
            l1.append(parsed_line['text'].encode("utf-8")) 
        if cap>240:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>10:
            break
last_tweets=[]
last_tweets.append(l1)
last_tweets.append(l2)
last_tweets.append(l3)
last_tweets.append(l4)
last_tweets.append(l5)
last_tweets

# url = ...

# last_tweets = ...

# count5 = ...
# Out:
# <Response [200]> 200 application/json
# https://stream.twitter.com/1.1/statuses/filter.json?track=q
#
# Elapsed: 0.033820152282714844 sec Wed Apr 24 13:54:30 +0000 2019
#  b'sqt q bntok'
#
# 0
# Elapsed: 0.4313082695007324 sec Wed Apr 24 13:54:31 +0000 2019
#  b'@thaynasnf eu tb desde q falaram que podiam pegar meu cel e ver "m\xc3\xa3e" e ligar pra ela falando q eu fui sequestrada e ser mentira jasdh'
#
# 0
# Elapsed: 0.45993471145629883 sec Wed Apr 24 13:54:31 +0000 2019
#  b'@julianacbrall Queria q a moda de andar com o cel numa corda no pesco\xc3\xa7o voltasse... seria mais f\xc3\xa1cil kkkkk'
#
# 0
# Elapsed: 0.48282623291015625 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @craiskc: gente pq q com o passa dos ano parece q o ensino m\xc3\xa9dio vai virando uma creche\n\nqnd eu tava no fundamental olhava os pessoal do\xe2\x80\xa6'
#
# 0
# Elapsed: 0.5646800994873047 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @tisgopjl: \xf0\x9f\x87\xba\xf0\x9f\x87\xb8good morning \n\n\xf0\x9f\x87\xa6\xf0\x9f\x87\xb7buen dia\n\n\xf0\x9f\x87\xab\xf0\x9f\x87\xb7Bonjour\n\n\xf0\x9f\x87\xa7\xf0\x9f\x87\xb7chora agora e ri dps, mais um dia d batalha\nf\xc3\xa9 no pai q o inimigo cai, bom dia'
#
# 0
# Elapsed: 0.5801470279693604 sec Wed Apr 24 13:54:31 +0000 2019
#  b'@jpkcasla Coincido totalmente, lo q creo es q en San Lorenzo ese siempre fue un puesto "figureti" y q jamas tuviero\xe2\x80\xa6 https://t.co/7RQp4SH4Nd'
#
# 0
# Elapsed: 0.6546189785003662 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @lacerda: eu quando penso \xe2\x80\x9cagora vai\xe2\x80\x9d e na verdade eh isso q acontece https://t.co/AYvSO9YQ8E'
#
# 0
# Elapsed: 0.6637711524963379 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @xnvjxlvx: ai q susto pensei q ia virar nugget https://t.co/YP56YmbIVK'
#
# 0
# Elapsed: 0.6645128726959229 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 0
# Elapsed: 0.6675517559051514 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT @Klausitox: QUE VIDEOZAO, o cara foi agredir a mulher e brotou gente de todos os lados pra ajuda-la e pra esmurrar esse agressor! \n\nEste\xe2\x80\xa6'
#
# 0
# Elapsed: 0.7230982780456543 sec Wed Apr 24 13:54:31 +0000 2019
#  b"RT @gtek: FLIP YOUR PHONE UPSIDE DOWN \n\n\xcb\x99\xca\x8dou s\xca\x87\xc9\xb9\xc9\x90\xca\x87s \xca\x9e\xc7\x9d\xc7\x9d\xca\x8d \xca\x87s\xc9\xb9o\xca\x8d \xc9\xb9no\xca\x8e 's\xc4\xb1\xc9\xa5\xca\x87 \xca\x87\xc7\x9d\xc7\x9d\xca\x8d\xca\x87\xc7\x9d\xc9\xb9 \xca\x87,uop no\xca\x8e \xc9\x9fI \xcb\x99\xca\x87\xc9\xa5\xc9\x93\xc4\xb1uo\xca\x87 s\xca\x8d\xc7\x9du poo\xc9\x93 plo\xca\x87 \xc7\x9dq ll\xc4\xb1\xca\x8d no\xca\x8e 's\xc4\xb1\xc9\xa5\xca\x87 p\xc9\x90\xe2\x80\xa6"
#
# 0
# Elapsed: 0.7547574043273926 sec Wed Apr 24 13:54:31 +0000 2019
#  b'RT
#  b'RT @Ann4Castro: ficar insistindo em relacionamento falido \xc3\xa9 a mesma coisa q acreditar que voc\xc3\xaa n\xc3\xa3o merece coisa melhor. se liberte!!!!! voc\xe2\x80\xa6'
#
# 1
# Elapsed: 1.547286033630371 sec Wed Apr 24 13:54:32 +0000 2019
#  b'How does your configurable system deal with #Safety? #cybersecurity? Performance? Usability? Energy consumption? Ot\xe2\x80\xa6 https://t.co/Uoj5IpUEKM'
#
# 1
# Elapsed: 1.556297779083252 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @sequeira_r: @NaranjaRA Pana naranja q opinas de las declaraciones de @jguaido sera q esos seguidores q te insultaron se retractaran jaj\xe2\x80\xa6'
#
# 1
# Elapsed: 1.5575604438781738 sec Wed Apr 24 13:54:32 +0000 2019
#  b'@yolaconica de los minios tampoco hay mucha referencia... es q gr\xc3\xba es muy alto\xf0\x9f\x99\x84'
#
# 1
# Elapsed: 1.5838186740875244 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @Camileston_: Se imaginan q alguien te ame tal y cual como sos y te conozca tanto al punto de saber describirte detalladamente??? estoy\xe2\x80\xa6'
#
# 1
# Elapsed: 1.6232869625091553 sec Wed Apr 24 13:54:32 +0000 2019
#  b'\xf0\x9f\x99\x8f\xf0\x9f\x8f\xbc'
#
# 1
# Elapsed: 1.6721806526184082 sec Wed Apr 24 13:54:32 +0000 2019
#  b'Le gusto mas q si novioo'
#
# 1
# Elapsed: 1.6737704277038574 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @borissawczuk: Creo q uno de los peores sentimientos del mundo es darte cuenta q no significabas tanto para alguien como pensabas y te s\xe2\x80\xa6'
#
# 1
# Elapsed: 1.6951417922973633 sec Wed Apr 24 13:54:32 +0000 2019
#  b'mas so de pensar q ficarei mais 7 anos estudando ... ai'
#
# 1
# Elapsed: 1.7196216583251953 sec Wed Apr 24 13:54:32 +0000 2019
#  b'@Mateus_Lipeh13 @Junnior_crvg21 Com\xc3\xa9 q \xc3\xa9 ?'
#
# 1
# Elapsed: 1.740717887878418 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @juvasques1: primeiro video no tik tok q fez eu esbo\xc3\xa7ar kkkkkkkkkkk https://t.co/lNm2xQyiQG'
#
# 1
# Elapsed: 1.741894245147705 sec Wed Apr 24 13:54:32 +0000 2019
#  b'@aintafr4idtodie Si pq mor\xc3\xad con Infinity World. No imagino q pasara en esta...'
#
# 1
# Elapsed: 1.7527790069580078 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @ALE_JAN_DRO_SOY: Mi hijo Alejandro\nDentro de Espectro Autista el tiene ASPERGER\nTrabaja en el JP Morgan aqui en BS AS  \nLo eligieron pa\xe2\x80\xa6'
#
# 1
# Elapsed: 1.9194271564483643 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @jgouveia_: sera q \xc3\xa9 crime te matar   de beijo?'
#
# 1
# Elapsed: 1.9344162940979004 sec Wed Apr 24 13:54:32 +0000 2019
#  b'RT @CARLOSFMEJIA: La #JEP no ha sido capaz de decir si los cr\xc3\xadmenes del mafioso Santrich fueron antes o despues de la firma,y vienen a esti\xe2\x80\xa6'
#
# 1
# Elapsed: 2.0112967491149902 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @oibrenox: bom dia\nbeba \xc3\xa1gua\nfuja da escola\nse apaixone no \xc3\xb4nibus\ngaste seu dinheiro todo com comida \nfinja q t\xc3\xa1 tudo bem\nse declare p p\xe2\x80\xa6'
#
# 2
# Elapsed: 2.040761947631836 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @YanisftAgus: sinceramente que me haga lo q quiera https://t.co/3Qfu1mwebl'
#
# 2
# Elapsed: 2.041884183883667 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @Rafa_Hernando: Este tipo no tiene verg\xc3\xbcenza. \xc2\xbfC\xc3\xb3mo se atreve a decir q han parado la inmigraci\xc3\xb3n ilegal cuando su efecto llamada con el\xe2\x80\xa6'
#
# 2
# Elapsed: 2.0467417240142822 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @_eumsmkeke: Q \xc3\xb3dio encomendei 2 ovos de colher com duas pessoas diferentes e as duas cancelaram, t\xc3\xb4 s\xc3\xb3 o \xc3\xb3dio'
#
# 2
# Elapsed: 2.0761377811431885 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @cniuton: #CarrioAIndagatoriaYa\n\n-Lilita tendr\xc3\xadas q decir algo sobre el fallecimiento de De la Sota\n- Ok, ahi voy https://t.co/40ZeB4n5bA'
#
# 2
# Elapsed: 2.0811567306518555 sec Wed Apr 24 13:54:33 +0000 2019
#  b'@deivindocorte1 Pensei q fosse tu mn kkkkkkkk'
#
# 2
# Elapsed: 2.199169397354126 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @eunalds: [24/4 10:26] Nalds \xe2\x99\xbf: Eu sou o \xc3\xbanico q n quero namorar?\n[24/4 10:27] BF \xf0\x9f\x92\x9c\xf0\x9f\x92\x9b: Vc se contenta em ser amante\n\nInimigo pra que ne?'
#
# 2
# Elapsed: 2.208742141723633 sec Wed Apr 24 13:54:33 +0000 2019
#  b'Y si no se hab\xc3\xada "ido con Dios", estar\xc3\xada candidate\xc3\xa1ndose a presidente!\xe2\x98\x9d\xef\xb8\x8f Nooooo. \nOtro gobierno s\xc3\xadmil k. No si cuan\xe2\x80\xa6 https://t.co/ZHqo9Ui5XK'
#
# 2
# Elapsed: 2.2347333431243896 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @__ars_8: \xe8\xb3\xaa\xe5\x95\x8f\xe3\x82\xb3\xe3\x83\xbc\xe3\x83\x8a\xe3\x83\xbc\xe3\x81\xab\xe3\x81\xa6\n\nQ.\xe3\x80\x8cJK\xe3\x81\xaf\xe5\xa5\xbd\xe3\x81\x8d\xe3\x81\xa7\xe3\x81\x99\xe3\x81\x8b\xef\xbc\x9f\xe3\x80\x8d\n\n\xf0\x9f\x8d\xb1\xe3\x80\x8c\xe3\x81\x93\xe3\x81\xae\xe5\x85\x88\xe4\xbd\x95\
#
# 2
# Elapsed: 2.616734743118286 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @miamorhun: @EXOfanbase_Int @weareoneEXO Q #BBMAsTopSocial EXO @weareoneEXO'
#
# 2
# Elapsed: 2.6225297451019287 sec Wed Apr 24 13:54:33 +0000 2019
#  b'@PaulaBuosi E eu sou, e acho q vc n\xc3\xa3o sabe de nada pra falar q \xc3\xa9 de barriga cheia. At\xc3\xa9 pq se me conhecesse de vdd s\xe2\x80\xa6 https://t.co/ygU7i7qWy7'
#
# 2
# Elapsed: 2.667872190475464 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @joaoppinheirom1: isto \xc3\xa9 mais q um meme, isto \xc3\xa9 um mood https://t.co/NNJkwFPkvZ'
#
# 2
# Elapsed: 2.6924633979797363 sec Wed Apr 24 13:54:33 +0000 2019
#  b"RT @kkunta__: I be having whole conversations, Q&amp;A's, winning arguments that will never happen, you name it https://t.co/ogrKoPZf0K"
#
# 2
# Elapsed: 2.6982216835021973 sec Wed Apr 24 13:54:33 +0000 2019
#  b'https://t.co/nUsiB3bT91'
#
# 2
# Elapsed: 2.7072362899780273 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @speccula: q pena q na epoca do orkut n teve uma comunidade chamada \xe2\x80\x9ceu odeio os homens\xe2\x80\x9d pq tenho certeza q essa seria a unica comunidad\xe2\x80\xa6'
#
# 2
# Elapsed: 2.725464344024658 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @essesusersai: quem consegue trabalhar numa empresa que muda de dire\xc3\xa7\xc3\xa3o a cada 6 meses? quem consegue confiar num chefe que fala que n\xc3\xa3o\xe2\x80\xa6'
#
# 2
# Elapsed: 2.736781120300293 sec Wed Apr 24 13:54:33 +0000 2019
#  b'@conradoruby JAJAJAJJ Q PROGERIA'
#
# 2
# Elapsed: 2.7763845920562744 sec Wed Apr 24 13:54:33 +0000 2019
#  b'RT @KiriBoludo: Miren este q prepar\xc3\xa9 de victor y makkachin(es mi fav hasta el momento)\xf0\x9f\xa4\xa7\xf0\x9f\x92\x9c https://t.co/yK27MFZU5X'
#
# 2
# Elapsed: 2.9161760807037354 sec Wed Apr 24 13:54:33 +0000 2019
#  b'HAHAHHAHAHAHAH WAG KA NA MAGSELOS KAU MGA MEMBERS Q ANG MGA MAIN HOES Q \xf0\x9f\x91\x8c\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8c\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8c\xf0\x9f\x8f\xbb'
#
# 2
# Elapsed: 3.0064120292663574 sec Wed Apr 24 13:54:34 +0000 2019
#  b'Com quem ser\xc3\xa1 q aquele menino t\xc3\xa1 tendo um caso pra fazer todos os filmes da netflix????'
#
# 3
# Elapsed: 3.0080854892730713 sec Wed Apr 24 13:54:33 +0000 2019
#  b'Ahora todos bardean a la empresa, bien que cuando tenian que viajar era la unica q te salvaba las papas si estaba l\xe2\x80\xa6 https://t.co/lzxy920m1f'
#
# 3
# Elapsed: 3.0114097595214844 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@XxMaconhaxX @vamoreira24 A vontade? Mas olha q te juro q vos obrigo mesmo e nao saiem ate reslver essa merda. Eu s\xe2\x80\xa6 https://t.co/Kogdc8bcNd'
#
# 3
# Elapsed: 3.0588345527648926 sec Wed Apr 24 13:54:34 +0000 2019
#  b'\n\nhttps://t.co/kTz48uxrPq'
#
# 3
# Elapsed: 3.120215654373169 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@abpnewshindi Or in logo ko modi ke khilaaf bolne ki or koi baat hoti he Kya modi or rafeal ke alawa. !? Q baate kh\xe2\x80\xa6 https://t.co/QSDmtkO6HQ'
#
# 3
# Elapsed: 3.1652934551239014 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @CarlosMaciasAl1: Cuando Florchu fu\xc3\xa9 a estudiar "Cine"?, a N.York y vivi\xc3\xb3 largamente en un Dpto.q le prest\xc3\xb3 D. Mu\xc3\xb1oz, el Secretario d Pa\xe2\x80\xa6'
#
# 3
# Elapsed: 3.194406032562256 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@PijudoMacho Rico. Q. Fuera. Yo. El. Q. Es tubiera ahy. En. Medio. De. Esas. Piernas. Con. Ese. Oso. Tan. Delicioso \xf0\x9f\x98\x8b'
#
# 3
# Elapsed: 3.195801258087158 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@Leticiando1 q isso, pra q'
#
# 3
# Elapsed: 3.205714464187622 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @Ignacio06760360: Mm que le pico? https://t.co/Y7bbGKwEfw'
#
# 3
# Elapsed: 3.2300665378570557 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@GyanMarao @tarungarg87 @Dawgindia @waglenikhil Abe bhosdivale pura desh Raj Thackeray ko aaj wah wahi de raha he.\xe2\x80\xa6 https://t.co/6232k5IVHB'
#
# 3
# Elapsed: 3.255005359649658 sec Wed Apr 24 13:54:34 +0000 2019
#  b'Seis\n\nAi mano q dia\nLET IT SHINE\n\n#BBMAsTopSocial BTS @BTS_twt'
#
# 3
# Elapsed: 3.268479347229004 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @siqueira_pk: Quando voc\xc3\xaa \xc3\xa9 o \xc3\xbanico q acompanha nba do seu tt.\n#feelz https://t.co/BDYsQ8bXCR'
#
# 3
# Elapsed: 3.3259007930755615 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @RayssaRR2: Minha dm\xf0\x9f\x99\x84 https://t.co/9LNfeN8gOR'
#
# 3
# Elapsed: 3.3273487091064453 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @___zxe: pablo iglesias: chicos :( no insultarse \xf0\x9f\x98\x94\xf0\x9f\x98\x94\xe2\x9d\xa4\xef\xb8\x8f porf\n\nalbert rivera: TU Q ERES EL ARBITRO '
#
# 3
# Elapsed: 3.4917283058166504 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @aninha_vixx: Prefiro um hamb\xc3\xbarguer, ou um dogao do q esse tanto de doce https://t.co/x2vWXHfEPw'
#
# 3
# Elapsed: 3.4925293922424316 sec Wed Apr 24 13:54:34 +0000 2019
#  b'jungkook se metio en la foto d una fansite d hyunjin, encima la cara q hizo parece q se bajo seis bolsas d merca, e\xe2\x80\xa6 https://t.co/YurKfPWbjC'
#
# 3
# Elapsed: 3.5591888427734375 sec Wed Apr 24 13:54:34 +0000 2019
#  b'Q.\xe3\x82\xaa\xe3\x83\x8a\xe3\x83\x8b\xe3\x83\xbc\xe3\x81\xa8\xe3\x81\x8b\xe3\x81\xa3\xe3\x81\xa6\xe3\x81\x84\xe3\x81\x86\xe3\x81\xae\xe3\x81\xaf\xef\xbc\x9f\nA.\xe3\x82\x84\xe3\x82\x8a\xe3\x81\xbe\xe3\x81\x99\xe3\x81\x8a\xe3\x81\x84\xe2\x80\xa6\xe3\x81\xa4\xe3\x81\x91\xe3\x81\x82\xe3\x81\x8c\xe3\x82\x8b\xe3\x81\xaa\xe3\x82\x88\xe5\xb0\x8f\xe5\x83\xa7\xe3\x83\x83\xef\xbc\x81\xef\xbc\x81'
#
# 3
# Elapsed: 3.5956969261169434 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @jupxt: ansiedade tira meu sono q eu j\xc3\xa1 n tenho'
#
# 3
# Elapsed: 3.6180596351623535 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @larissademattos: ser universit\xc3\xa1ria \xc3\xa9 realmente a sensa\xc3\xa7\xc3\xa3o constante de q deveria estar lendo algo nesse exato momento'
#
# 3
# Elapsed: 3.6416444778442383 sec Wed Apr 24 13:54:34 +0000 2019
#  b'n\xc3\xa3o to acreditando de j\xc3\xa1 vou me arrumar pra ir pra escola, q \xc3\xb3dio \xf0\x9f\x98\xa3'
#
# 3
# Elapsed: 3.6578269004821777 sec Wed Apr 24 13:54:34 +0000 2019
#  b'@cherabek "minha funcion\xc3\xa1ria" q porra de funcion\xc3\xa1ria mlk, c\xc3\xaa ia precisar de funcion\xc3\xa1ria pra q? Te dar pezinho pra vc subir na cama?'
#
# 3
# Elapsed: 3.6696102619171143 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @mtscndia: wacha yo soy ALIADO FEMINISTA sabes a todas las marchas q fui del feminismo sabes como APOYO el feminismo y cuantas marchas a\xe2\x80\xa6'
#
# 3
# Elapsed: 3.709606647491455 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 3
# Elapsed: 3.7142834663391113 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @MarieChagas8: Sdd do tempo q eu podia ver o dia todo greys'
#
# 3
# Elapsed: 3.7363979816436768 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @ayaka_5300: \xe3\x80\x90\xe4\xba\xa4\xe6\x8f\x9b\xe3\x80\x91S.Q.S \xe3\x82\xb9\xe3\x82\xb1\xe3\x82\xb9\xe3\x83\x86 ep3 \xe3\x83\xad\xe3\x83\x9f\xe3\x82\xaa\xe3\x83\x8d\xe3\x82\xb9 \xe3\x83\x88\xe3\x83\xac\xe3\x83\x96\xe3\x83\xad \n\n\xe8\xad\xb2)\xe7\x94\xbb\xe5\x83\x8f1\xe3\x80\x812\xe6\x9e\x9a\xe7\x9b\xae\n\n\xe6\xb1\x82)\xe7\x94\xbb\xe5\x83\x8f3\xe6\x9e\x9a\xe7\x9b\xae\xe2\xad\x95\xe5\x8d\xb0\n\n\n\xe4\xbc\x9a\xe5\xa0\xb4\xe3\x81\xab\xe3\x81\xa6\xe6\x89\x8b\xe6\xb8\xa1\xe3\x81\x97\xe4\xba\xa4\xe6\x8f\x9b\xe5\xb8\x8c\xe6\x9c\x9b\xe3\x81\xa7\xe3\x81\x99\xe3\x80\x82\n\xe6\xa4\x9c\xe7\xb4\xa2\xe3\x81\x8b\xe3\x82\x89\xe3\x81\xa7\xe3\x82\x82\xe3\x81\x8a\xe6\xb0\x97\xe8\xbb\xbd\xe3\x81\xab\xe3\x81\x8a\xe5\xa3\xb0\xe3\x81\x8c\xe3\x81\x91\xe3\x81\x8f\xe3\x81\xa0\xe3\x81\x95\xe3\x81\x84\xe3\x80\x82 http\xe2\x80\xa6'
#
# 3
# Elapsed: 3.762599468231201 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @sariita129: N o\nv a s\na\ns a n a r\nv o l v i e n d o\na\nl o\nq u e\nt e\nr o m p i \xc3\xb3 \n\n(gr\xc3\xa1batelo en la cabeza)'
#
# 3
# Elapsed: 3.8033106327056885 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @Exolusaglobal: [\xf0\x9f\x93\xa3 BBMA CHALLENGE]\n\nQ. What ice cream flavor do you like ?\n\nRT = 1 Vote \nReply = 1 Vote \n\nReply or Quote with the follow\xe2\x80\xa6'
#
# 3
# Elapsed: 3.8120522499084473 sec Wed Apr 24 13:54:34 +0000 2019
#  b'Aun q yo ya no t quiero dme que tu si'
#
# 3
# Elapsed: 3.8194363117218018 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @lazowi69: He estado pensando q tu no eres para mi alomejor soy demasiado calle demasiado g \xf0\x9f\xa4\xb7\xf0\x9f\x8f\xbd\xe2\x80\x8d\xe2\x99\x80\xef\xb8\x8f'
#
# 3
# Elapsed: 3.835803985595703 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 3
# Elapsed: 3.8521571159362793 sec Wed Apr 24 13:54:34 +0000 2019
#  b'RT @barneyzitito: Coisas pra n\xc3\xa3o fazer ao perceber q a pessoa com quem vc est\xc3\xa1 conversando \xc3\xa9 t\xc3\xadmida\n\n . . . THREAD!!'
#
# 3
# Elapsed: 3.8941802978515625 sec Wed Apr 24 13:54:34 +0000 2019
sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @iamddias: meninas q s\xc3\xb3 querem morrer mas tem medo de existir vida ap\xc3\xb3s a morte'
#
# 4
# Elapsed: 4.279521226882935 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @bboomhao: che a ustedes (las q no son vegetarianas o veganas) no les pasa q cuando est\xc3\xa1n comiendo carne y caen en q lo q realmente est\xc3\xa1\xe2\x80\xa6'
#
# 4
# Elapsed: 4.28028678894043 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Madrugadao____: Voltando pra casa depois da prova que eu sei q me ferrei https://t.co/bnsaemKVZ4'
#
# 4
# Elapsed: 4.29639196395874 sec Wed Apr 24 13:54:35 +0000 2019
#  b'KESAMBET APA INI ANAK ORANG'
#
# 4
# Elapsed: 4.297163724899292 sec Wed Apr 24 13:54:35 +0000 2019
#  b'Eu lembrando q sexta tem curso e a daiane n vai t\xc3\xa1 \xf0\x9f\xa4\xa6\xf0\x9f\x8f\xbb\xe2\x80\x8d\xe2\x99\x80\xef\xb8\x8f\xf0\x9f\x92\x94 chega a me d\xc3\xa1 um des\xc3\xa2nimo'
#
# 4
# Elapsed: 4.308100700378418 sec Wed Apr 24 13:54:35 +0000 2019
#  b"RT @OfficialShegs: FLIP YOUR PHONE UPSIDE DOWN \n\n\xcb\x99\xca\x8dou s\xca\x87\xc9\xb9\xc9\x90\xca\x87s \xca\x9e\xc7\x9d\xc7\x9d\xca\x8d \xca\x87s\xc9\xb9o\xca\x8d \xc9\xb9no\xca\x8e 's\xc4\xb1\xc9\xa5\xca\x87 \xca\x87\xc7\x9d\xc7\x9d\xca\x8d\xca\x87\xc7\x9d\xc9\xb9 \xca\x87,uop no\xca\x8e \xc9\x9fI \xcb\x99\xca\x87\xc9\xa5\xc9\x93\xc4\xb1uo\xca\x87 s\xca\x8d\xc7\x9du poo\xc9\x93 plo\xca\x87 \xc7\x9dq ll\xc4\xb1\xca\x8d no\xca\x8e\xe2\x80\xa6"
#
# 4
# Elapsed: 4.31421685218811 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Camileston_: Se imaginan q alguien te ame tal y cual como sos y te conozca tanto al punto de saber describirte detalladamente??? estoy\xe2\x80\xa6'
#
# 4
# Elapsed: 4.359137773513794 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 4
# Elapsed: 4.431801080703735 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @rafaellacava10: Q contento me siento porque nuestros esgrimistas recibieron un importante donativo en instrumentos y equipamiento para\xe2\x80\xa6'
#
# 4
# Elapsed: 4.432180404663086 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Cubs: Q-like reflexes. \n\n#EverybodyIn https://t.co/597KtNzPwu'
#
# 4
# Elapsed: 4.439807176589966 sec Wed Apr 24 13:54:35 +0000 2019
#  b'Y esa gente q me cae mal \xf0\x9f\x98\x92\xf0\x9f\x98\x92\xf0\x9f\x98\x92\xf0\x9f\x98\xa0'
#
# 4
# Elapsed: 4.453210353851318 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @estoyresad: q lindos (y necesarios) son esos ratitos d\xc3\xb3nde te olvidas d todo y sos feliz'
#
# 4
# Elapsed: 4.461955547332764 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @FilipeRet: Liberdade \xc3\xa9 pouco, o q eu quero n\xc3\xa3o tem nome'
#
# 4
# Elapsed: 4.480621337890625 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 4
# Elapsed: 4.496047019958496 sec Wed Apr 24 13:54:35 +0000 2019
#  b'minha conta de icons s\xc3\xb3 tem icons lindos por motivos de &gt; todos q quero usar posto l\xc3\xa1 pra salvar'
#
# 4
# Elapsed: 4.511144638061523 sec Wed Apr 24 13:54:35 +0000 2019
#  b'Tudo q me conforta \xc3\xa9 que amanh\xc3\xa3 vou ver vingadores'
#
# 4
# Elapsed: 4.513598680496216 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @zehdeabreu: Por favor divulguem o q um navio da MSC q despejou seu esgoto em frente \xc3\xa0 Cambori\xc3\xba. \n\nhttps://t.co/cUq4CwKSKp'
#
# 4
# Elapsed: 4.538222551345825 sec Wed Apr 24 13:54:35 +0000 2019
#  b'e minha m\xc3\xa3e que n\xc3\xa3o vai no m\xc3\xa9dico cmg pq o pai quer q ela v\xc3\xa1 junto com ele no m\xc3\xa9dico dele'
#
# 4
# Elapsed: 4.55137825012207 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Madrugadao____: Voltando pra casa depois da prova que eu sei q me ferrei https://t.co/bnsaemKVZ4'
#
# 4
# Elapsed: 4.567465543746948 sec Wed Apr 24 13:54:35 +0000 2019
#  b'Q \xe3\x82\xa2\xe3\x83\xb3\xe3\x82\xbf10\nA \xe3\x83\x9e\xe3\x82\xb8\xe3\x83\x87\xe3\x82\xb9'
#
# 4
# Elapsed: 4.721071004867554 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @uggolini: Mas vcs opinam sem conhecer??? \xc3\x89 a mm coisa q dizer que sexo \xc3\xa9 bom mas s\xc3\xa3o virgens\xf0\x9f\x92\x80 https://t.co/UhZUca7jNf'
#
# 4
# Elapsed: 4.736080169677734 sec Wed Apr 24 13:54:35 +0000 2019
#  b'T\xc3\xa3o morta e sem tempo q n\xc3\xa3o tweeto mais nada, s\xc3\xb3 dou rt'
#
# 4
# Elapsed: 4.75726842880249 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @ttomlinsondaily: Voting has kicked off! To vote use our tips below! \n\nGo through this search and RT every tweet to vote: https://t.co/R\xe2\x80\xa6'
#
# 4
# Elapsed: 4.854013681411743 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @GFiuza_Oficial: O Brasil deu mais um passo apesar dos parasitas de sempre e dos colunistas sociais do bolsonarismo - esse novo sindicat\xe2\x80\xa6'
#
# 4
# Elapsed: 4.8553876876831055 sec Wed Apr 24 13:54:35 +0000 2019
#  b"RT @Jaumeasens: Una met\xc3\xa0fora brutal de la passi\xc3\xb3 per la vida del Jordi i la Txell. No hi ha pres\xc3\xb3 q aturi tant d'amor. Lluitarem pk pugueu\xe2\x80\xa6"
#
# 4
# Elapsed: 4.861832618713379 sec Wed Apr 24 13:54:35 +0000 2019
#  b'jajsaksj siempre que me acuerdo q vulve kyu me acuerdo de minnie no puedo ser feliz un poco no m\xc3\xa1s'
#
# 4
# Elapsed: 4.864018678665161 sec Wed Apr 24 13:54:35 +0000 2019
#  b"RT @Jaumeasens: Una met\xc3\xa0fora brutal de la passi\xc3\xb3 per la vida del Jordi i la Txell. No hi ha pres\xc3\xb3 q aturi tant d'amor. Lluitarem pk pugueu\xe2\x80\xa6"
#
# 4
# Elapsed: 4.886886119842529 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Facuu00774697: Que penan dan esos q se hacen los vistimas jajja \xf0\x9f\xa4\x94\xf0\x9f\xa4\xa3'
#
# 4
# Elapsed: 4.888395071029663 sec Wed Apr 24 13:54:35 +0000 2019
#  b'@davigreis Dbz \xc3\xa9 mto foda mas eles focam mais em porradaria do q hist\xc3\xb3ria, pelo menos \xc3\xa9 oq eu acho tlgd'
#
# 4
# Elapsed: 4.911974668502808 sec Wed Apr 24 13:54:35 +0000 2019
#  b'n acredito q vou no show do djonga \xf0\x9f\x98\xad'
#
# 4
# Elapsed: 4.931166887283325 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @cniuton: #CarrioAIndagatoriaYa\n\n-Lilita tendr\xc3\xadas q decir algo sobre el fallecimiento de De la Sota\n- Ok, ahi voy https://t.co/40ZeB4n5bA'
#
# 4
# Elapsed: 4.932326555252075 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @Sucolean: trabalhar mto p n ter q morar perto de parente'
#
# 4
# Elapsed: 4.997556686401367 sec Wed Apr 24 13:54:35 +0000 2019
#  b'RT @mrcspatricio: gente parece aquele cara q falava ISSO \xc3\x89 UMA BICHOOONA https://t.co/dDoy4izzrm'
#
# 4
# Elapsed: 5.03311562538147 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @HernanSCastillo: Gallardo no le dijo no a newells. Les dijo q va a esperar a River. Se reuni\xc3\xb3 y les dijo q va a esperar el llamado y si\xe2\x80\xa6'
#
# 5
# Elapsed: 5.034878253936768 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 5
# Elapsed: 5.085415840148926 sec Wed Apr 24 13:54:36 +0000 2019
#  b'Portugu\xc3\xaas \xc3\xa9 a pior mat\xc3\xa9ria q existe'
#
# 5
# Elapsed: 5.164827108383179 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @HCAQUILMES: KIRCHNERISMO\nSEG\xc3\x9aN LA INFO D MANZANARES( CONTADOR D NESHTOR Y CFK)\nSE CHORIARON 1100 MILL USD. EN 12 A\xc3\x91OS\nSI LA DEVUELVEN B\xe2\x80\xa6'
#
# 5
# Elapsed: 5.196068525314331 sec Wed Apr 24 13:54:36 +0000 2019
#  b'@chhhamploni kkkkkkkkkkkkkkkkkkkkkkkkkkk vc eh engra\xc3\xa7ada, da fuga 12:30 q eu espero'
#
# 5
# Elapsed: 5.229947328567505 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @guerramtg: At\xc3\xa9 agora n\xc3\xa3o sei como q n\xc3\xa3o to ressaca dps de ter misturado todas as bebidas poss\xc3\xadveis'
#
# 5
# Elapsed: 5.296191930770874 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @Daiana_linss: S\xc3\xb3 me fizeram de boba uma vez, e nessa \xc3\xbanica vez eu virei de aluna a professora.. ent\xc3\xa3o j\xc3\xa1 sabem n\xc3\xa9? Vai achando q engana\xe2\x80\xa6'
#
# 5
# Elapsed: 5.306152820587158 sec Wed Apr 24 13:54:36 +0000 2019
#  b'@mardefuegos15 Este burro no es k. Todo lo contrario. Contrabandista, estafador del pueblo de Moron, destructor de\xe2\x80\xa6 https://t.co/kIP9uwp128'
#
# 5
# Elapsed: 5.309322834014893 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @LuisinJimenezc: Es muy dif\xc3\xadcil ser humilde en medio de la prosperidad. Solo los seres excepcionales se detienen en medio del \xc3\xa9xito para\xe2\x80\xa6'
#
# 5
# Elapsed: 5.3169403076171875 sec Wed Apr 24 13:54:36 +0000 2019
#  b'prof me deu uma bronquinha e falou q eu fiquei chateada pq fiz cara feia\n\na sala toda disse antes de eu falar \xe2\x80\x9ca ca\xe2\x80\xa6 https://t.co/Z6odMf3Gud'
#
# 5
# Elapsed: 5.33980917930603 sec Wed Apr 24 13:54:36 +0000 2019
#  b'foda ter sono e ansiedade da nem pra tomar um cafezinho q ja parece q vou morrer'
#
# 5
# Elapsed: 5.355448007583618 sec Wed Apr 24 13:54:36 +0000 2019
#  b'q linddddo nene'
#
# 5
# Elapsed: 5.4040608406066895 sec Wed Apr 24 13:54:36 +0000 2019
#  b'RT @jcanadellb: Dem\xc3\xa0 comen\xc3\xa7arem la campanya per les eleccions a les Cambres de Comer\xc3\xa7 amb la \xc3\xbanica candidatura independentista: @EinesdePai\xe2\x80\xa6'
#
# 5
# Elapsed: 5.413234710693359 sec Wed Apr 24 13:54:36 +0000 2019
#  b's\xc3\xb3 queria minha casa, mas tenho q aguentar essa sala'
#
# 5
# Elapsed: 5.427129030227661 sec Wed Apr 24 13:54:36 +0000 2019
#  b'altura \xe2\x80\x94 1.60? por ai eu acho, a \xc3\xbaltima vez q eu me medi eu tinha 1.57 e foi no ensino fundamental, acho q n mudei\xe2\x80\xa6 https://t.co/ixNE8EKz0y'
#
# 5
# Elapsed: 5.555710792541504 sec Wed Apr 24 13:54:36 +0000 2019
# ...
#
# 8
# Elapsed: 8.148566484451294 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @7borabora: Q \xeb\xb0\xa9\xed\x83\x84\xec\x86\x8c\xeb\x85\x84\xeb\x8b\xa8\xec\x9d\x98 \xec\xb5\x9c\xec\xa2\x85 \xea\xbf\x88\xec\x9d\x80? \nSUGA: \xeb\x9e\xa9\xec\x9d\x84 \xec\xa0\x95\xeb\xa7\x90 \xec\x9e\x98\xed\x95\xb4, \xeb\xa9\x9c\xeb\xa1\x9c\xeb\x94\x94\xea\xb0\x80 \xec\xa3\xbd\xec\x97\xac, \xec\x9d\xb4\xeb\x9f\xb0 \xea\xb2\x83\xeb\xb3\xb4\xeb\x8b\xa4\xeb\x8a\x94 \xec\x9a\xb0\xeb\xa6\xac \xec\x95\xa8\xeb\xb2\x94\xec\x9d\x98 \xed\x8a\xb8\xeb\x9e\x99\xec\x9d\x84 \xeb\x8f\x8c\xeb\xa0\xb8\xec\x9d\x84 \xeb\x95\x8c \xeb\xa9\x88\xec\xb6\x94\xec\xa7\x80 \xec\x95\x8a\xea\xb3\xa0 \xec\xa0\x84\xec\xb2\xb4\xeb\xa5\xbc \xed\x94\x8c\xeb\xa0\x88\xec\x9d\xb4\xed\x95\xa0 \xec\x88\x98 \xec\x9e\x88\xeb\x8a\x94 \xeb\xb0\xa9\xed\x83\x84\xec\x86\x8c\xeb\x85\x84\xeb\x8b\xa8\xec\x9d\xb4 \xeb\x90\x98\xea\xb3\xa0 \xec\x8b\xb6\xeb\x8b\xa4. \n\n#BBMAsTopSocial BTS\xe2\x80\xa6'
#
# 8
# Elapsed: 8.149479627609253 sec Wed Apr 24 13:54:39 +0000 2019
#  b'@hillarymch_ se for de portugu\xc3\xaas, eu acho q ele n vai'
#
# 8
# Elapsed: 8.176921844482422 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @stillvgly: Si os sent\xc3\xads mal por ser vagos no os preocup\xc3\xa9is q existo yo'
#
# 8
# Elapsed: 8.197316646575928 sec Wed Apr 24 13:54:39 +0000 2019
#  b'https://t.co/wEyOsoYnBE'
#
# 8
# Elapsed: 8.218389511108398 sec Wed Apr 24 13:54:39 +0000 2019
#  b'ambas as coisas s\xc3\xa3o dif\xc3\xadceis pra caramba de se fazer, real'
#
# 8
# Elapsed: 8.231093168258667 sec Wed Apr 24 13:54:39 +0000 2019
#  b'ja to ate vendo q eu vou sair derrotada da sala de cinema quando for ver os vingadores'
#
# 8
# Elapsed: 8.240525722503662 sec Wed Apr 24 13:54:39 +0000 2019
#  b'@suelen_kkk queria etc\n\nmas tenho q contentar com bermuda colorida e camisa do bart'
#
# 8
# Elapsed: 8.274423360824585 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @tunykollmann: El punto clave de Carri\xc3\xb3 no son las deplorables sobre la muerte de De la Sota sino acusar al cordob\xc3\xa9s y tambi\xc3\xa9n a Bonfatt\xe2\x80\xa6'
#
# 8
# Elapsed: 8.313616037368774 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @talingopty99: Eso decimos todos los talingos. Boom!! https://t.co/MbNUEiWxWe'
#
# 8
# Elapsed: 8.339905023574829 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @gaitifuji:  | OurPlanet-TV\xef\xbc\x9a\xe7\x89\xb9\xe5\xae\x9a\xe9\x9d\x9e\xe5\x96\xb6\xe5\x88\xa9\xe6\xb4\xbb\xe5\x8b\x95\xe6\xb3\x95\xe4\xba\xba \xe3\x82\xa2\xe3\x83\xaf\xe3\x83\xbc\xe3\x83\x97\xe3\x83\xa9\xe3\x83\x8d\xe3\x83\x83\xe3\x83\x88\xe3\x83\xbb\xe3\x83\x86\xe3\x82\xa3\xe3\x83\xbc\xe3\x83\x93\xe3\x83\xbc https://t.co/zciNAf9PdP'
#
# 8
# Elapsed: 8.36293911933899 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @joaoppinheirom1: mano sai dessa casa o mais r\xc3\xa1pido q poderes pqp https://t.co/IVhv6pBac5'
#
# 8
# Elapsed: 8.39307427406311 sec Wed Apr 24 13:54:39 +0000 2019
#  b'algu\xc3\xa9m surpreso?'
#
# 8
# Elapsed: 8.41277527809143 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @SYAJinsoul: miss q dito uwu'
#
# 8
# Elapsed: 8.454179048538208 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @festevez50: La \xc3\xbanica forma de vencer al comunismo es la q aplicaron Reagan, Thatcher y Juan Pablo II: negando de ra\xc3\xadz q tuviera nada de\xe2\x80\xa6'
#
# 8
# Elapsed: 8.455025911331177 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @Atiyulia: Seg\xc3\xban lo que se refleja el la Constituci\xc3\xb3n y en la Ley Electoral a cada provincia le pertenecen 4 Senadores, excepto islas y\xe2\x80\xa6'
#
# 8
# Elapsed: 8.52954912185669 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @xxxiblowurmind: mano kakakaka ele c bu\xc3\xa9 cuidado q fofinho https://t.co/RYQO7YVi9A'
#
# 8
# Elapsed: 8.531050443649292 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @caiio_mooreno: Vis\xc3\xa3o https://t.co/jrxdgzFxmz'
#
# 8
# Elapsed: 8.567238807678223 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 8
# Elapsed: 8.589375734329224 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @exohoelic: Q. Who is she ? \n\nReply using  #BBMAsTopSocial EXO @weareoneEXO https://t.co/NaqhTs49cZ'
#
# 8
# Elapsed: 8.593442678451538 sec Wed Apr 24 13:54:39 +0000 2019
#  b's\xc3\xb3 queria fazer propaganda rapid\xc3\xa3o aqui do evento da ABC em parceria com a cafeteria especial que vai acontecer nes\xe2\x80\xa6 https://t.co/kHdtyRY5tI'
#
# 8
# Elapsed: 8.596033811569214 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @maxcelle_: Demorei, mas aprendi que n\xc3\xa3o devo aceitar menos do q eu mere\xc3\xa7o \xf0\x9f\x98\x98'
#
# 8
# Elapsed: 8.642301082611084 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @LeonardoMilbra3: @mp_rs @PompeodeMattos @apsusepeof @EduardoLeite_ @Valdeci13rs @DelegadoRanolfo @Susepe @SSP_RS @AmapergsP @Assembleia\xe2\x80\xa6'
#
# 8
# Elapsed: 8.643311262130737 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @crisdantas_m: Melhor coisa eh ver as pessoas tirarem as conclus\xc3\xb5es erradas sobre vc e ver elas la achando q estao certas e abalando kkk\xe2\x80\xa6'
#
# 8
# Elapsed: 8.654832601547241 sec Wed Apr 24 13:54:39 +0000 2019
#  b'@renucollins95 sos lo mejor q me paso'
#
# 8
# Elapsed: 8.750468730926514 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @carlysemi: Taehyung, \xc3\xa9 o seguinte:\nVoc\xc3\xaa ja deve saber que tem f\xc3\xa3s aqui no BR, n\xc3\xa9?\nPois ent\xc3\xa3o, aq ainda s\xc3\xa3o 06:00 horas da manh\xc3\xa3, VC N\xc3\x83O\xe2\x80\xa6'
#
# 8
# Elapsed: 8.799598932266235 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @_VihCorreia: Eu gosto do q \xc3\xa9 simples e vem do cora\xc3\xa7\xc3\xa3o, o luxo q eu quero eu mesma conquisto!!! \xf0\x9f\x98\x99'
#
# 8
# Elapsed: 8.82868766784668 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @SoyyLaCone: La mam\xc3\xa1 d mi mejor amiga reaccionando a estas canciones fue lo mejor q me pas\xc3\xb3 jahsjajsjajaj https://t.co/yBYwX9Fk1h'
#
# 8
# Elapsed: 8.863493204116821 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @beasrtx: q no caiga en el olvido cuando le mande una foto d mi gata a cristina cifuentes y me contest\xc3\xb3 https://t.co/PUThEDiAEv'
#
# 8
# Elapsed: 8.867422819137573 sec Wed Apr 24 13:54:39 +0000 2019
#  b'@pedroferriz3 Si.. Nos hemos dado cuenta q hay gente m\xc3\xa1s pendeja q Pe\xc3\xb1a'
#
# 8
# Elapsed: 8.869660139083862 sec Wed Apr 24 13:54:39 +0000 2019
#  b'@allanrichie07 @2010MisterChip Champions ganadas con trampa, comprando \xc3\xa1rbitros q pitan un penal en el min 94. \xc2\xa1Por\xe2\x80\xa6 https://t.co/bLcjR2VGBf'
#
# 8
# Elapsed: 8.980293989181519 sec Wed Apr 24 13:54:39 +0000 2019
#  b'RT @xnvjxlvx: ai q susto pensei q ia virar nugget https://t.co/YP56YmbIVK'
#
# 8
# Elapsed: 8.99316692352295 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @Jumuller45: \xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f\xf0\x9f\x91\x8f https://t.co/ysD2JxOCH2'
#
# 8
# Elapsed: 9.012585163116455 sec Wed Apr 24 13:54:40 +0000 2019
#  b'oficialmente humor \xc3\xa9 a forma q eu uso pra mascarar meu nervosismo'
#
# 9
# Elapsed: 9.118053197860718 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @craiskc: a vida e uma eterna briga entre os acad\xc3\xaamicos pra ve qm sofre mais \n\nfundamental:\na pq baskhara t\xc3\xa1 dif\xc3\xadcil\n\na\xc3\xad vem o m\xc3\xa9dio:\nkk\xe2\x80\xa6'
#
# 9
# Elapsed: 9.143699407577515 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @fashionpressnet: Q-pot CAFE.\xe3\x81\xaeGW&amp;\xe3\x83\xa1\xe3\x83\xac\xe3\x83\xb3\xe3\x82\xb2\xe3\x81\xae\xe3\x81\x97\xe3\x81\xa3\xe3\x81\xbd - https://t.co/5i4NJjgRRR https://t.co/rXsMBiriwb'
#
# 9
# Elapsed: 9.145793437957764 sec Wed Apr 24 13:54:40 +0000 2019
#  b'\xc4\xb0stiyir\xc9\x99m rent a cardan ma\xc5\x9f\xc4\xb1n g\xc3\xb6t\xc3\xbcr\xc3\xbcb q\xc4\xb1z tutum\xf0\x9f\x98\xac'
#
# 9
# Elapsed: 9.25035309791565 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @taisptacularr: pq minhas amigas n pensam assim????????? https://t.co/3mdHGVHzxu'
#
# 9
# Elapsed: 9.28941011428833 sec Wed Apr 24 13:54:40 +0000 2019
#  b'acho q vou chegae atrasada hj'
#
# 9
# Elapsed: 9.293832540512085 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @JLouriana: Poderia acontecer isso em todos os casos https://t.co/Z29aiB9gNv'
#
# 9
# Elapsed: 9.342067003250122 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @solterissimas: nois eh timido mas depois q pegar intimidade fodeu'
#
# 9
# Elapsed: 9.343978643417358 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @larissaduttra17: Tem gente que pode passar o tempo q for mas n\xc3\xa3o amadurece, que fase!'
#
# 9
# Elapsed: 9.431779146194458 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @vxtakaki: se foi por isso q ele n trouxe meus chocolates \n\nta perdoado entao https://t.co/MXhPQIu9KK'
#
# 9
# Elapsed: 9.436833381652832 sec Wed Apr 24 13:54:40 +0000 2019
#  b'@Jacquelinehot9 Mmmmmmmm...q ricooo....no queres mejor meterte mi pija\xf0\x9f\x98\x88\xf0\x9f\x98\x88'
#
# 9
# Elapsed: 9.495731115341187 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT
sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @craiskc: gente pq q com o passa dos ano parece q o ensino m\xc3\xa9dio vai virando uma creche\n\nqnd eu tava no fundamental olhava os pessoal do\xe2\x80\xa6'
#
# 9
# Elapsed: 9.722780227661133 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @Nicollydebs: Luta pela bunda q tu quer dar tapa irm\xc3\xa3o'
#
# 9
# Elapsed: 9.797748804092407 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @FilipeRet: Antes q tudo isso acabe ame'
#
# 9
# Elapsed: 9.802924394607544 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @lacorrientek: Esto \xf0\x9f\x91\x87 https://t.co/jFMg1pUhdY'
#
# 9
# Elapsed: 9.803577184677124 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @anamoraesss_: q doideira, a gente se vai do nada... da nem p acreditar nessas coisas\xf0\x9f\x98\xab'
#
# 9
# Elapsed: 9.819987058639526 sec Wed Apr 24 13:54:40 +0000 2019
#  b'RT @Klausitox: QUE VIDEOZAO, o cara foi agredir a mulher e brotou gente de todos os lados pra ajuda-la e pra esmurrar esse agressor! \n\nEste\xe2\x80\xa6'
#
# 9
# Elapsed: 9.855124235153198 sec Wed Apr 24 13:54:40 +0000 2019
#  b'@Nathan_Batista @SF_Moro Tomara q um dia vc seja abordado por um PM corrupto, ele estoure seus miolos e depois seja\xe2\x80\xa6 https://t.co/tIO2IRX85k'
#
# 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-4fd47ed9a3de> in <module>
#      18 start = time.time()
#      19 l1,l2,l3,l4,l5 = [],[],[],[],[]
# ---> 20 for line in res.iter_lines():
#      21     # filter out keep-alive new lines
#      22     if line:
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     792         pending = None
#     793
# --> 794         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     795
#     796             if pending is not None:
#
# ~/.local/lib/python3.6/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/.local/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
Test.twitterHashtagsTweets(last_tweets, url, 'Incorrect content of "last_tweets" list', "Exercise 1.3.1 is successful")
Test.twitterHashtagsTweetsCount(count5, last_tweets, url, 'Incorrect content of "count5" list', "Exercise 1.3.2 is successful")
# Out:
# 1 test failed. Incorrect URL
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-eb039be16fc9> in <module>()
#       1 Test.twitterHashtagsTweets(last_tweets, url, 'Incorrect content of "last_tweets" list', "Exercise 1.3.1 is successful")
# ----> 2 Test.twitterHashtagsTweetsCount(count5, last_tweets, url, 'Incorrect content of "count5" list', "Exercise 1.3.2 is successful")
#
# NameError: name 'count5' is not defined

# %% [markdown]
# ---
# ## 2. Getting access to Twitter APIs using specific Python libraries
# ---

# %% [markdown]
# Today there are a few different Python specilized libraries which simplify our work with Twitter API - `tweepy`, `python-twitter`, `twython` ... (here we have called the most popular ones). Further we will consider one of them - `tweepy`.
#
# ### Installing `tweepy`
# Let's install `tweepy` specific Python library which we will use work with Twitter APIs.
# The most straightforward way is through the `pip` installation tool. `Python >= 2.7.9` should come installed with pip, but for earlier versions, [see this guide for installing pip](https://pip.pypa.io/en/latest/installing.html).
# This can be run from the command line using:
#
#     pip install tweepy
#
# Make sure you upgrade pip to the newest version:
#
#     pip install --upgrade pip

# %%
import tweepy

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
#consumer_key = '<YOUR CONSUMER KEY>'
#consumer_secret = '<YOUR CONSUMER SECRET CODE>'

#access_token = '<YOUR ACCESS TOKEN>'
#access_secret = '<YOUR ACCESS SECRET TOKEN>'

# Then you need authenticate yourself
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)
print (api)
# Out:
# <tweepy.api.API object at 0x7f957da0c7f0>

# %%
# If the authentication was successful, you should see the name of the account print out
print ("My name is", api.me().name)
# Out:
# My name is Dmitriy Kisil

# %% [markdown]
# ### 2.1: Read Tweets Appearing on Homepage

# %%
# Let's display first 3 tweets in your timeline (of course, if they are present there)
for (idx, tweet) in enumerate(tweepy.Cursor(api.home_timeline).items(3)):    
    print ('TWEET {0}:\n\t{1}\n'.format(idx, tweet.text.encode("utf-8")))
# Out:
# TWEET 0:
# 	b'RT @R_by_Ryo: new #rstats \xf0\x9f\x93\x9d: Roundup of the 77th #TokyoR User Meetup: A special session for beginneR useRs! \n\nI took notes in English &amp; wro\xe2\x80\xa6'
#
# TWEET 1:
# 	b'\xd0\x94\xd0\xbe \xd0\x94\xd0\xbd\xd1\x8f \xd0\xbc\xd1\x83\xd0\xbb\xd1\x8c\xd1\x82\xd0\xb8\xd0\xbb\xd0\xb0\xd1\x82\xd0\xb5\xd1\x80\xd0\xb0\xd0\xbb\xd1\x96\xd0\xb7\xd0\xbc\xd1\x83 \xd1\x96 \xd0\xb4\xd0\xb8\xd0\xbf\xd0\xbb\xd0\xbe\xd0\xbc\xd0\xb0\xd1\x82\xd1\x96\xd1\x97 \xd0\xb7\xd0\xb0\xd1\x80\xd0\xb0\xd0\xb4\xd0\xb8 \xd0\xbc\xd0\xb8\xd1\x80\xd1\x83: \xd0\xb1\xd0\xb0\xd0\xb3\xd0\xb0\xd1\x82\xd0\xbe\xd1\x81\xd1\x82\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbd\xd0\xbd\xd1\x8f \xd0\xb4\xd0\xb8\xd0\xbf\xd0\xbb\xd0\xbe\xd0\xbc\xd0\xb0\xd1\x82\xd1\x96\xd1\x8f \xd0\xbc\xd0\xb0\xd0\xb9\xd0\xb6\xd0\xb5 \xd1\x96\xd0\xb4\xd0\xb5\xd0\xb0\xd0\xbb\xd1\x8c\xd0\xbd\xd0\xb0 \xd1\x84\xd0\xbe\xd1\x80\xd0\xbc\xd1\x83\xd0\xbb\xd0\xb0 \xd1\x81\xd0\xbf\xd1\x96\xd0\xb2\xd1\x96\xd1\x81\xd0\xbd\xd1\x83\xd0\xb2\xd0\xb0\xd0\xbd\xd0\xbd\xd1\x8f \xd1\x83\xe2\x80\xa6 https://t.co/FfD3oM7Gu5'
#
# TWEET 2:
# 	b'RT @HumanProgress: Less than 50 years after the Kakapo, a large, nocturnal flightless bird, was thought to have been extinct, at least 75 c\xe2\x80\xa6'

# %% [markdown]
# Let's look at the whole data contained in one tweet. Note, the `tweepy` api has decoded the JSON and put it into a more pythonic object. So for example, we can access the message in the tweet via python attribute access.

# %%
import json

tweet = api.home_timeline()[0]
print (type(tweet), '\n')
print (tweet.text, '\n')
print (json.dumps(tweet._json))
# Out:
# <class 'tweepy.models.Status'>
#
# RT @R_by_Ryo: new #rstats 📝: Roundup of the 77th #TokyoR User Meetup: A special session for beginneR useRs!
#
# I took notes in English &amp; wro…
#
# {"created_at": "Wed Apr 24 13:44:58 +0000 2019", "id": 1121047379782844416, "id_str": "1121047379782844416", "text": "RT @R_by_Ryo: new #rstats \ud83d\udcdd: Roundup of the 77th #TokyoR User Meetup: A special session for beginneR useRs! \n\nI took notes in English &amp; wro\u2026", "truncated": false, "entities": {"hashtags": [{"text": "rstats", "indices": [18, 25]}, {"text": "TokyoR", "indices": [49, 56]}], "symbols": [], "user_mentions": [{"screen_name": "R_by_Ryo", "name": "\u26bd\ufe0fRyo Nakagawara\ud83d\udcca", "id": 923513734831755264, "id_str": "923513734831755264", "indices": [3, 12]}], "urls": []}, "source": "<a href=\"https://tapbots.com/software/tweetbot/mac\" rel=\"nofollow\">Tweetbot for Mac</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 69133574, "id_str": "69133574", "name": "Hadley Wickham", "screen_name": "hadleywickham", "location": "Houston, TX", "description": "R, data, visualisation.", "url": "https://t.co/DWqWlxbOKK", "entities": {"url": {"urls": [{"url": "https://t.co/DWqWlxbOKK", "expanded_url": "http://hadley.nz", "display_url": "hadley.nz", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 84131, "friends_count": 286, "listed_count": 2551, "created_at": "Wed Aug 26 23:34:46 +0000 2009", "favourites_count": 18493, "utc_offset": null, "time_zone": null, "geo_enabled": true, "verified": true, "statuses_count": 35675, "lang": "en", "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "022330", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png", "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/905186381995147264/7zKAG5sY_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/905186381995147264/7zKAG5sY_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/69133574/1404410942", "profile_link_color": "0084B4", "profile_sidebar_border_color": "A8C7F7", "profile_sidebar_fill_color": "C0DFEC", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": false, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": false, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "retweeted_status": {"created_at": "Wed Apr 24 13:21:48 +0000 2019", "id": 1121041552191574022, "id_str": "1121041552191574022", "text": "new #rstats \ud83d\udcdd: Roundup of the 77th #TokyoR User Meetup: A special session for beginneR useRs! \n\nI took notes in Eng\u2026 https://t.co/3SDbd4VfVJ", "truncated": true, "entities": {"hashtags": [{"text": "rstats", "indices": [4, 11]}, {"text": "TokyoR", "indices": [35, 42]}], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/3SDbd4VfVJ", "expanded_url": "https://twitter.com/i/web/status/1121041552191574022", "display_url": "twitter.com/i/web/status/1\u2026", "indices": [117, 140]}]}, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 923513734831755264, "id_str": "923513734831755264", "name": "\u26bd\ufe0fRyo Nakagawara\ud83d\udcca", "screen_name": "R_by_Ryo", "location": "Tokyo-to, Japan", "description": "#rstats | MSc. Business Psychology (UCL) | \u26bd\ufe0f #LFC | Author: bulletchartr \ud83d\udce6 | Jr. Data Scientist @ ACDI/VOCA (international development NGO) \ud83d\udd0e", "url": "https://t.co/6aHIEB8y4y", "entities": {"url": {"urls": [{"url": "https://t.co/6aHIEB8y4y", "expanded_ ...

# %% [markdown]
# Let's see attributes associated with a Status object, which corresponds to any tweet.

# %%
tweet.__dict__.keys()
# Out:
# dict_keys(['_api', '_json', 'created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'source', 'source_url', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'author', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %% [markdown]
# ### 2.2: Get Twitter User Info

# %%
# We have chosen a random user
user = api.get_user(1088398616)
print ("User name:", user.name, '\n')
print (user)
# Out:
# User name: saimadhu
#
# User(_api=<tweepy.api.API object at 0x7f957da0c7f0>, _json={'id': 1088398616, 'id_str': '1088398616', 'name': 'saimadhu', 'screen_name': 'saimadhup', 'location': 'Bengaluru, India', 'profile_location': {'id': '1b8680cd52a711cb', 'url': 'https://api.twitter.com/1.1/geo/id/1b8680cd52a711cb.json', 'place_type': 'unknown', 'name': 'Bengaluru, India', 'full_name': 'Bengaluru, India', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, 'description': 'Data Scientist | Data Science Author | Founder of @dataaspirant', 'url': 'http://t.co/XWKZub79TD', 'entities': {'url': {'urls': [{'url': 'http://t.co/XWKZub79TD', 'expanded_url': 'http://dataaspirant.com', 'display_url': 'dataaspirant.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 262, 'friends_count': 132, 'listed_count': 16, 'created_at': 'Mon Jan 14 08:25:49 +0000 2013', 'favourites_count': 44, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 271, 'lang': 'en', 'status': {'created_at': 'Wed Apr 03 18:15:21 +0000 2019', 'id': 1113505282343071744, 'id_str': '1113505282343071744', 'text': '5 AM Love short story by Saimadhu-writings https://t.co/Gs38WR13iN', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Gs38WR13iN', 'expanded_url': 'https://medium.com/saimadhu-writings/5-am-love-e6ae96a76a88', 'display_url': 'medium.com/saimadhu-writi…', 'indices': [43, 66]}]}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 3, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/808001022081671168/vLU7EBkK_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/808001022081671168/vLU7EBkK_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1088398616/1428480377', 'profile_link_color': '3B94D9', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, id=1088398616, id_str='1088398616', name='saimadhu', screen_name='saimadhup', location='Bengaluru, India', profile_location={'id': '1b8680cd52a711cb', 'url': 'https://api.twitter.com/1.1/geo/id/1b8680cd52a711cb.json', 'place_type': 'unknown', 'name': 'Bengaluru, India', 'full_name': 'Bengaluru, India', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, description='Data Scientist | Data Science Author | Founder of @dataaspirant', url='http://t.co/XWKZub79TD', entities={'url': {'urls': [{'url': 'http://t.co/XWKZub79TD', 'expanded_url': 'http://dataaspirant.com', 'display_url': 'dataaspirant.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, protected=False, followers_count=262, friends_count=132, listed_count=16, created_at=datetime.datetime(2013, 1, 14, 8, 25, 49), favourites_count=44, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=271, lang='en', status=Status(_api=<tweepy.api.API objec ...

# %% [markdown]
# ### 2.3: Get a list of all your friends

# %%
for user in tweepy.Cursor(api.friends, screen_name="twitter").items():
    print (user.screen_name)
# Out:
# TwitterMiami
# TwitterBizJP
# TwitterTogether
# TwitterMediaJP
# TwitterSeguro
# AdsAPI
# pichette
# TwitterA11y
# TwitterComms
# TwitterSportsCA
# TwitterVideoIN
# TwitterREW
# TwitterAdsHelp
# TwitterMktgFR
# JoinTheFlockJP
# TwitterMktgBR
# TwitterSportsJP
# TwitterDevJP
# TwitterMedia
# PeriscopeHelp
# TwitterLifeline
# TwitterSportsAU
# TwitterNewsJP
# TwitterGovJP
# TwitterMusicJP
# TwitterMktgMENA
# momentsmena
# TwitterAsians
# TwitterMktgKR
# UKMoments
# CanadaMoments
# MomentsBrasil
# MomentsAU
# MomentsES
# MomentsJapan
# kayvz
# TwitterU
# JoinTheFlockEU
# verified
# TwitterStripes
# TwitterParents
# btaylor
# IamDebraLee
# Marthalanefox
# TwitterDetroit
# TwitterParis
# leslieberland
# TwitterPH
# TwitterVideo
# TwitterGaming
# omidkordestani
# TwitterMoments
# TwitterATL
# TwitterDUX
# TwitterWomen
# TwitterUK
# TwitterTurkiye
# TwitterEspana
# TwitterSG
# TwitterSeattle
# TwitterOpen
# TwitterMENA
# TwitterLA
# TwitterJP
# TwitterID
# TwitterFaith
# TwitterDublin
# TwitterCanada
# TwitterBoulder
# TwitterBoston
# TwitterAlas
# TwitterResearch
# PeriscopeCo
# NeighborNest
# mopub
# JoinNiche
# Gnip
# OfficialPartner
# Blackbirds
# mashable
# Marketingland
# Adweek
# adage
# TwitterFood
# TwitterData
# TwitterFashion
# TwitterMovies
# TwitterDev
# TwitterForGood
# TwitterTV
# Policy
# rosenblattdavid
# marjscar
# peterfenton
# vijaya
# TwitterIR
# anthonynoto
# TwitterDesign
# TwitterBrasil
# womeng
# TwitterOSS
# VineCreators
# arstechnica
# CNET
# FortuneTech
# FastCompany
# Gizmodo
# fttechnews
# engadget
# TwitterDC
# TwitterChicago
# TwitterNYC
# verge
# thenextweb
# TechCrunch
# TwitterKorea
# TwitterAU
# TwitterMusic
# TweetDeck
# TwitterBusiness
# TwitterMktg
# TwitterNews
# TwitterBooks
# TwitterSF
# TwitterGov
# TwitterSports
# TwitterEng
# TwitterSupport
# TwitterSafety
# Nonprofits
# TwitterLive
# TwitterIndia
# JoinTheFlock
# TwitterDE
# TwitterFrance
# TwitterLatAm
# TwitterAPI
# ev
# biz
# jack

# %% [markdown]
# ### 2.4: Search
#
# Search is implemented directly through `tweepy.api`. As before let's search for a single tweet about "luck", phrased as a question. But we don't need worry now about URL characters encoding ☺

# %%
results = api.search(q='luck?', count=1)
print (type(results))
print (u'Created at: {0}\n"{1}"\nby {2}'.format(results[0].created_at, results[0].text, results[0].author.name))
# Out:
# <class 'tweepy.models.SearchResults'>
# Created at: 2019-04-24 13:57:18
# "RT @DarkArchemist: 💙 Let us celebrate the Sunday with a Giveaway,
#
# This is going to have a Random Prize, 2.000 Artix Points / Heromart Item…"
# by Simon

# %% [markdown]
# You may create very specialized and more concrete queries. Let's find 5 tweets that contains the word "python" or "IPython" near London. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language).

# %%
for tweet in api.search(q='python OR ipython', count=5, show_user=False,
                        geocode='51.509865,-0.118092,20mi', lang='en'):
    print (tweet.created_at, '\n',  tweet.text, '\n')
# Out:
# 2019-04-24 13:05:01
#  @Needlefact OCRd that, cleaned it up and made a quick python 2 liner: https://t.co/geOC0cNBy9 insults all day long.
#
# 2019-04-24 13:01:13
#  RT @miekg: Wrote a tool that takes in (small) yaml and barfs out Grafana json, Like https://t.co/LZuncmgO7z but written in Go and doesn't f…
#
# 2019-04-24 12:44:43
#  RT @RyoIndie: The calm before the storm...     -Follow me for updates on my upcoming game #OperationValderon #python #towerdefense #towerde…
#
# 2019-04-24 12:39:58
#  RT @paoloardoino: Amazing H(M)oney Framework tutorial, now in Python too!  https://t.co/FkxwAVYjXt
#
# 2019-04-24 12:30:05
#  Get started with data science (including statistical / numerical methods &amp; Python) courtesy of @bsletten's 3-day wo… https://t.co/URCZRBUFpi

# %%
for tweet in api.search(q='#BBMAsTopSocial', count=10, show_user=False,
                        geocode='50.0,36.2,20mi', lang='ru'):
    print (tweet.created_at, '\n',  tweet.text, '\n')
# Out:
# 2019-04-24 14:01:55
#  RT @yla91300: @G0T7VotingTeam @GOT7Official А Я ТЕБЯ ПОЙМАЛА
# #BBMAsTopSocial​ GOT7 @GOT7Official https://t.co/NHqMsonsTN
#
# 2019-04-24 13:50:50
#  @G0T7VotingTeam @GOT7Official А Я ТЕБЯ ПОЙМАЛА
# #BBMAsTopSocial​ GOT7 @GOT7Official https://t.co/NHqMsonsTN
#
# 2019-04-24 13:32:22
#  RT @Sadmargot: Что за дорама пж напишите в ком
#
# #BBMAsTopSocial @BTS_twt
# https://t.co/CoqohqeTbG
#
# 2019-04-24 10:29:17
#  RT @Sadmargot: Что за дорама пж напишите в ком
#
# #BBMAsTopSocial @BTS_twt
# https://t.co/CoqohqeTbG
#
# 2019-04-24 10:18:03
#  RT @Sadmargot: Что за дорама пж напишите в ком
#
# #BBMAsTopSocial @BTS_twt
# https://t.co/CoqohqeTbG
#
# 2019-04-24 10:17:03
#  Что за дорама пж напишите в ком
#
# #BBMAsTopSocial @BTS_twt
# https://t.co/CoqohqeTbG
#
# 2019-04-24 10:12:00
#  RT @nexxussssss: просто бтс в 2017 сидят, скрестив пальцы, в надежде на победу в номинации биллборд. если не мотивация голосовать, то что?…
#
# 2019-04-24 09:59:04
#  - Я подумал, что должен поблагодарить дорогих мне людей через лирику
# - Я очень сильно сконцентрировался на лирике,… https://t.co/7bvNWtaogG
#
# 2019-04-24 09:57:11
#  RT @GL6V26U6763hFdV: Давайте любить!❤❤❤ #BBMAsTopSocial EXO  @weareoneEXO

# %% [markdown]
# ### 2.5: Finding what are in the trend somewhere
#
# According to the [tweepy API](http://tweepy.readthedocs.org/en/v3.5.0/api.html), we can return the top trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, London has a `WOEID` of 44418. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in New York

# %%
top_trends = api.trends_place(id=44418)
top_trends
# Out:
# [{'trends': [{'name': 'Liverpool',
#     'url': 'http://twitter.com/search?q=Liverpool',
#     'promoted_content': None,
#     'query': 'Liverpool',
#     'tweet_volume': 96855},
#    {'name': 'Eric Cantona',
#     'url': 'http://twitter.com/search?q=%22Eric+Cantona%22',
#     'promoted_content': None,
#     'query': '%22Eric+Cantona%22',
#     'tweet_volume': None},
#    {'name': '#indyref2',
#     'url': 'http://twitter.com/search?q=%23indyref2',
#     'promoted_content': None,
#     'query': '%23indyref2',
#     'tweet_volume': None},
#    {'name': '#WeStandWithLyra',
#     'url': 'http://twitter.com/search?q=%23WeStandWithLyra',
#     'promoted_content': None,
#     'query': '%23WeStandWithLyra',
#     'tweet_volume': None},
#    {'name': '#WednesdayWisdom',
#     'url': 'http://twitter.com/search?q=%23WednesdayWisdom',
#     'promoted_content': None,
#     'query': '%23WednesdayWisdom',
#     'tweet_volume': 52916},
#    {'name': 'Toby Young',
#     'url': 'http://twitter.com/search?q=%22Toby+Young%22',
#     'promoted_content': None,
#     'query': '%22Toby+Young%22',
#     'tweet_volume': None},
#    {'name': '#ManchesterDerby',
#     'url': 'http://twitter.com/search?q=%23ManchesterDerby',
#     'promoted_content': None,
#     'query': '%23ManchesterDerby',
#     'tweet_volume': 13796},
#    {'name': '#StopFoodWasteDay',
#     'url': 'http://twitter.com/search?q=%23StopFoodWasteDay',
#     'promoted_content': None,
#     'query': '%23StopFoodWasteDay',
#     'tweet_volume': None},
#    {'name': 'Nicola Sturgeon',
#     'url': 'http://twitter.com/search?q=%22Nicola+Sturgeon%22',
#     'promoted_content': None,
#     'query': '%22Nicola+Sturgeon%22',
#     'tweet_volume': None},
#    {'name': 'Ann Widdecombe',
#     'url': 'http://twitter.com/search?q=%22Ann+Widdecombe%22',
#     'promoted_content': None,
#     'query': '%22Ann+Widdecombe%22',
#     'tweet_volume': 33217},
#    {'name': 'Huawei',
#     'url': 'http://twitter.com/search?q=Huawei',
#     'promoted_content': None,
#     'query': 'Huawei',
#     'tweet_volume': 53385},
#    {'name': 'Jackson Carlaw',
#     'url': 'http://twitter.com/search?q=%22Jackson+Carlaw%22',
#     'promoted_content': None,
#     'query': '%22Jackson+Carlaw%22',
#     'tweet_volume': None},
#    {'name': 'Father Martin Magill',
#     'url': 'http://twitter.com/search?q=%22Father+Martin+Magill%22',
#     'promoted_content': None,
#     'query': '%22Father+Martin+Magill%22',
#     'tweet_volume': None},
#    {'name': "Cantona's Instagram",
#     'url': 'http://twitter.com/search?q=%22Cantona%27s+Instagram%22',
#     'promoted_content': None,
#     'query': '%22Cantona%27s+Instagram%22',
#     'tweet_volume': None},
#    {'name': 'Persona 5 The Royal',
#     'url': 'http://twitter.com/search?q=%22Persona+5+The+Royal%22',
#     'promoted_content': None,
#     'query': '%22Persona+5+The+Royal%22',
#     'tweet_volume': 13777},
#    {'name': 'Persona 5 Royal',
#     'url': 'http://twitter.com/search?q=%22Persona+5+Royal%22',
#     'promoted_content': None,
#     'query': '%22Persona+5+Royal%22',
#     'tweet_volume': None},
#    {'name': 'David Lidington',
#     'url': 'http://twitter.com/search?q=%22David+Lidington%22',
#     'promoted_content': None,
#     'query': '%22David+Lidington%22',
#     'tweet_volume': None},
#    {'name': 'Section 30',
#     'url': 'http://twitter.com/search?q=%22Section+30%22',
#     'promoted_content': None,
#     'query': '%22Section+30%22',
#     'tweet_volume': None},
#    {'name': 'Cape Of Good Hope',
#     'url': 'http://twitter.com/search?q=%22Cape+Of+Good+Hope%22',
#     'promoted_content': None,
#     'query': '%22Cape+Of+Good+Hope%22',
#     'tweet_volume': None},
#    {'name': 'richard leonard',
#     'url': 'http://twitter.com/search?q=%22richard+leonard%22',
#     'promoted_content': None,
#     'query': '%22richard+leonard%22',
#     'tweet_volume': None},
#    {'name': 'Scottish Parliament',
#     'url': 'http://twitter.com/search?q=%22Scottish+Parliament%22',
#     'promoted_content': None,
#     'query': '%22Scottish+Parliament%22',
#     'tweet_volume': None},
#    {'name': "St Anne's Cathedral",
#     'url': 'http://twitter.com/search?q=%22St+Anne%27s+Cathedral%22',
#     'promoted_content': None,
#     'query': '%22St+Anne%27s+Cathedral%22',
#     'tweet_volume': None},
#    {'name': 'Stephen Lusty',
#     'url': 'http://twitter.com/search?q=%22Stephen+Lusty%22',
#     'promoted_content': None,
#     'query': '%22Stephen+Lusty%22',
#     'tweet_volume': None},
#    {'name': 'Just That Lord',
#     'url': 'http://twitter.com/search?q=%22Just+That+Lord%22',
#     'promoted_content': None,
#     'query': '%22Just+That+Lord%22',
#     'tweet_volume': None},
#    {'name': 'Citizens Assembly',
#     'url': 'http://twitter.com/search?q=%22Citizens+Assembly%22',
#     'promoted_content': None,
#     'query': '%22Citizens+Assembly%22',
#     'tweet_volume': None},
#    {'name': 'Epsom',
#     'url': 'http://twitter.com/search?q=Epsom',
#     'promoted_content': None,
#     'query': 'Epsom',
#     'tweet_volume': None},
#    {'name': 'Judd Trump',
#     'url': 'http://twitter.com/search?q=%22Judd+Trump%22',
#     'promoted_content': None,
#     'query': '%22Judd+Trump%22',
#     'tweet_volume': None},
#    {'name': 'Baron',
#     'url': 'http://twitter.com/search?q=Baron',
#     'promoted_content': None,
#     'query': 'Baron',
#     'tweet_volume': 12601},
#    {'name': 'Morgana',
#     'url': 'http://twitter.com/search?q=Morgana',
#     'promoted_content': None,
#     'query': 'Morgana',
#     'tweet_volume': None},
#    {'name': 'The Cliff',
#     'url': 'http://twitter.com/search?q=%22The+Cliff%22',
#     'promoted_content': None,
#     'query': '%22The+Cliff%22',
#     'tweet_volume': None},
#    {'name': 'Cap Francais',
#     'url': 'http://twitter.com/search?q=%22Cap+Francais%22',
#     'promoted_content': None,
#     'query': '%22Cap+Francais%22',
#     'tweet_volume': None},
#    {'name': 'willie rennie',
#     'url': 'http://twitter.com/search?q=%22willie+rennie%22',
#     'promoted_content': None,
#     'query': '%22willie+rennie%22',
#     'tweet_volume': None},
#    {'name': 'emily thornberry',
#     'url': 'http://twitter.com/search?q=%22emily+thornberry%22',
#     'promoted_content': None,
#     'query': '%22emily+thornberry%22',
#     'tweet_volume': None},
#    {'name': '5 Jobs',
#     'url': 'http://twitter.com/search?q=%225+Jobs%22',
#     'promoted_content': None,
#     'query': '%225+Jobs%22',
#     'tweet_volume': None},
#    {'name': 'The Westminster',
#     'url': 'http://twitter.com/search?q=%22The+Westminster%22',
#     'promoted_content': None,
#     'query': '%22The+Westminster%22',
#     'tweet_volume': None},
#    {'name': '#PMQs',
#     'url': 'http://twitter.com/search?q=%23PMQs',
#     'promoted_content': None,
#     'query': '%23PMQs',
#     'tweet_volume': None},
#    {'name': '#MUNMCI',
#     'url': 'http://twitter.com/search?q=%23MUNMCI',
#     'promoted_content': None,
#     'query': '%23MUNMCI',
#     'tweet_volume': 20721},
#    {'name': '#5jobsivehad',
#     'url': 'http://twitter.com/search?q=%235jobsivehad',
#     'promoted_content': None,
#     'query': '%235jobsivehad',
#     'tweet_volume': None},
#    {'name': '#WednesdayMotivation',
#     'url': 'http://twitter.com/search?q=%23WednesdayMotivation',
#     'promoted_content': None,
#     'query': '%23WednesdayMotivation',
#     'tweet_volume': 25058},
#    {'name': '#BOND25',
#     'url': 'http://twitter.com/search?q=%23BOND25',
#     'promoted_content': None,
#     'query': '%23BOND25',
#     'tweet_volume': None},
#    {'name': '#AvangersEndgame',
#     'url': 'http://twitter.com/search?q=%23AvangersEndgame',
#     'promoted_content': None,
#     'query': '%23AvangersEndgame',
#     'tweet_volume': 62470},
#    {'name': '#PoliticsLive',
#     'url': 'http://twitter.com/search?q=%23PoliticsLive',
#     'promoted_content': None,
#     'query': '%23PoliticsLive',
#     'tweet_volume': None},
#    {'name': '#OPPOReno',
#     'url': 'http://twitter.com/search?q=%23OPPOReno',
#     'promoted_content': None,
#     'query': '%23OPPOReno',
#     'tweet_volume': None},
#    {'name': '#ValuingHarmony',
#     'url': 'http://twitter.com/search?q=%23ValuingHarmony',
#     'promoted_content': None,
#     'query': '%23ValuingHarmony',
#     'tweet_volume': None},
#    {'name': '#CYBERUK19',
#     'url': 'http://twitter.com/search?q=%23CYBERUK19',
#     'promoted_content': None,
#     'query': '%23CYBERUK19',
#     'tweet_volume': None},
#    {'name': '#WorldMeningitisDay',
#     'url': 'http://twitter.com/search?q=%23WorldMeningitisDay',
#     'promoted_content': None,
#     'query': '%23WorldMeningitisDay',
#     'tweet_volume': None},
#    {'name': '#lilac19',
#     'url': 'http://twitter.com/search?q=%23lilac19',
#     'promoted_content': None,
#     'query': '%23lilac19',
#     'tweet_volume': None},
#    {'name': '#EIE19',
#     'url': 'http://twitter.com/search?q=%23EIE19',
#     'promoted_content': None,
#     'query': '%23EIE19',
#     'tweet_volume': None},
#    {'name': '#fiveJobsIveHad',
#     'url': 'http://twitter.com/search?q=%23fiveJobsIveHad',
#     'promoted_content': None,
#     'query': '%23fiveJobsIveHad',
#     'tweet_volume': None},
#    {'name': '#FUTREurope',
#     'url': 'http://twitter.com/search?q=%23FUTREurope',
#     'promoted_content': None,
#     'query': '%23FUTREurope',
#     'tweet_volume': None}],
#   'as_of': '2019-04-24T13:58:23Z',
#   'created_at': '2019-04-24T13:56:06Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %% [markdown]
# As you can see, there's alot of metadata that goes into even a simple tweet. Let's slightly prettify the output data

# %%
print (10, "trends")#len(top_trends[0]['trends']), "trends"
for i, trend in enumerate(top_trends[0]['trends'][:10]):
    print (i, '-', trend['name'], trend['url'])
# Out:
# 10 trends
# 0 - Liverpool http://twitter.com/search?q=Liverpool
# 1 - Eric Cantona http://twitter.com/search?q=%22Eric+Cantona%22
# 2 - #indyref2 http://twitter.com/search?q=%23indyref2
# 3 - #WeStandWithLyra http://twitter.com/search?q=%23WeStandWithLyra
# 4 - #WednesdayWisdom http://twitter.com/search?q=%23WednesdayWisdom
# 5 - Toby Young http://twitter.com/search?q=%22Toby+Young%22
# 6 - #ManchesterDerby http://twitter.com/search?q=%23ManchesterDerby
# 7 - #StopFoodWasteDay http://twitter.com/search?q=%23StopFoodWasteDay
# 8 - Nicola Sturgeon http://twitter.com/search?q=%22Nicola+Sturgeon%22
# 9 - Ann Widdecombe http://twitter.com/search?q=%22Ann+Widdecombe%22

# %% [markdown]
# ### 2.6: Streaming
#
# Like before, in case we want to "keep the connection open", and gather all the upcoming tweets, the streaming API is what we need. We need to extend the `StreamListener()` to customise the way we process the incoming data. Depending on the search term, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#iphone_ and _#android_ hashtag:

# %%
#This cell doesn't have limits and doesn't stop automatically. You need to interrupt it by yourself.

import time

from tweepy.streaming import StreamListener
from tweepy import Stream

class MyListener(StreamListener):
     
    def __init__(self):
        self.counter = 0
        self.begin_time = time.time()
        
    def on_data(self, data):
        try:
            self.counter += 1
            data = json.loads(data)
            # we will cut the tweet text
            print ("Tweet #{0}: Created at {1} \n {2} \nTime elapsed from the beginning: {3} sec \n".\
                  format(self.counter, data['created_at'], data['text'][:100].encode('utf-8'), time.time()-self.begin_time))
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#iphone', '#android'])
# Out:
#  b'RT @Iphone_R_UBE: \xe3\x80\x90\xe5\xae\x9a\xe6\x9c\x9f\xe3\x80\x91\n\xe7\x9a\x86\xe6\xa7\x98\xe3\x81\xae\xe3\x81\x82\xe3\x81\x84\xe3\x81\xb5\xe3\x81\x89\xe3\x82\x93\xe3\x81\xae\xe3\x81\x93\xe3\x81\xa8\xe3\x81\x8c\xe5\xbf\x83\xe9\x85\x8d\xe3\x81\xa7\n\xe6\x9c\x9d\xe3\x82\x82\xe8\xb5\xb7\xe3\x81\x8d\xe3\x82\x8c\xe3\x81\xbe\xe3\x81\x9b\xe3\x82\x93\xe2\x80\xa6\n\n\xe3\x80\x80\xef\xbc\x9c\xe2\x8c\x92\xef\xbc\x8f\xe3\x83\xbd-\xef\xbd\xa4_\xef\xbc\xbf_\n\xef\xbc\x8f\xef\xbc\x9c_/\xef\xbc\xbf\xef\xbc\xbf\xef\xbc\xbf\xef\xbc\xbf\xef\xbc\x8f\n\xef\xbf\xa3\xef\xbf\xa3\xef\xbf\xa3\xef\xbf\xa3\xef\xbf\xa3\xef\xbf\xa3\xef\xbf\xa3\n\xef\xbc\x88\xe5\xa4\x9c\xe3\x81\xaf\xe7\x9c\xa0\xe3\x82\x8c\xe3\x81\xbe\xe3\x81\x99\xe2\x99\xac\xef\xbc\x89\n\n#iPhone #\xe4\xbf\xae'
# Time elapsed from the beginning: 24.818190097808838 sec
#
# Tweet #13: Created at Wed Apr 24 14:08:26 +0000 2019
#  b'RT @EsensConsulting: .@riggaroo introduces us to #Lottie, an awesome #iOS, #Android, and #React Nati'
# Time elapsed from the beginning: 25.269503355026245 sec
#
# Tweet #14: Created at Wed Apr 24 14:08:27 +0000 2019
#  b'RT @ludovicroland: .@jdatour and @Tuffaisquoi will now speak about using #kotlin from the server to '
# Time elapsed from the beginning: 25.723470211029053 sec
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/.local/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/.local/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-517c6c40c003> in <module>
#      28
#      29 twitter_stream = Stream(auth, MyListener())
# ---> 30 twitter_stream.filter(track=['#iphone', '#android'])
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/.local/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/.local/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /usr/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     581
#     582                 if len(mvb) <= chunk_left:
# --> 583                     n = self._safe_readinto(mvb)
#     584                     self.chunk_left = chunk_left - n
#     585                     return total_bytes + n
#
# /usr/lib/python3.6/http/client.py in _safe_readinto(self, b)
#     626                 n = self.fp.readinto(temp_mvb)
#     627             else:
# --> 628                 n = self.fp.readinto(mvb)
#     629             if not n:
#     630                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/.local/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# > ### Exercise 1.4:
#
# > Using `tweepy` Python library find when [Bill Gates](https://twitter.com/BillGates?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor) created his twitter account and what text had his last tweet.
# Write the date and tweet text to the `result` dictionary containing keys `created_at` and `last_tweet_text`.

# %%
# type your code here
user = api.get_user(screen_name='BillGates')
print(user)
l1 =[1,2]
l1 = ["Wed Jun 24 18:44:10 +0000 2009",user.status.text.encode("utf-8")]

l2 = ["created_at","last_tweet_text"]
result = dict(zip(l2,l1))
result
# Out:
# User(_api=<tweepy.api.API object at 0x7f957da0c7f0>, _json={'id': 50393960, 'id_str': '50393960', 'name': 'Bill Gates', 'screen_name': 'BillGates', 'location': 'Seattle, WA', 'profile_location': {'id': '300bcc6e23a88361', 'url': 'https://api.twitter.com/1.1/geo/id/300bcc6e23a88361.json', 'place_type': 'unknown', 'name': 'Seattle, WA', 'full_name': 'Seattle, WA', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, 'description': "Sharing things I'm learning through my foundation work and other interests.", 'url': 'https://t.co/AITfIziPWQ', 'entities': {'url': {'urls': [{'url': 'https://t.co/AITfIziPWQ', 'expanded_url': 'http://www.gatesnotes.com/', 'display_url': 'gatesnotes.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 47081884, 'friends_count': 196, 'listed_count': 122272, 'created_at': 'Wed Jun 24 18:44:10 +0000 2009', 'favourites_count': 108, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 3045, 'lang': 'en', 'status': {'created_at': 'Wed Apr 24 11:54:00 +0000 2019', 'id': 1121019454857474050, 'id_str': '1121019454857474050', 'text': "Stories like this one from Kenya remind me of why Melinda and I started our foundation. I'm optimistic we will cont… https://t.co/XAm4jQgsVA", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XAm4jQgsVA', 'expanded_url': 'https://twitter.com/i/web/status/1121019454857474050', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 533, 'favorite_count': 2689, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50393960/1555262956', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, id=50393960, id_str='50393960', name='Bill Gates', screen_name='BillGates', location='Seattle, WA', profile_location={'id': '300bcc6e23a88361', 'url': 'https://api.twitter.com/1.1/geo/id/300bcc6e23a88361.json', 'place_type': 'unknown', 'name': 'Seattle, WA', 'full_name': 'Seattle, WA', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, description="Sharing things I'm learning through my foundation work and other interests.", url='https://t.co/AITfIziPWQ', entities={'url': {'urls': [{'url': 'https://t.co/AITfIziPWQ', 'expanded_url': 'http://www.gatesnotes.com/', 'display_url': 'gatesnotes.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=47081884, friends_count=196, listed_count=122272, created_at=datetime.datetime(2009, 6, 24, 18, 44, 10), favourites_count=108, utc_offset=None, time_zone=None, geo_en ...
# {'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#  'last_tweet_text': b"Stories like this one from Kenya remind me of why Melinda and I started our foundation. I'm optimistic we will cont\xe2\x80\xa6 https://t.co/XAm4jQgsVA"}

# %%
Test.twitterBillGates(result, api, 'Incorrect query', "Exercise 1.4 is successful")
# Out:
# 1 test failed. Incorrect query

# %% [markdown]
# <center><h3>Presented by <a target="_blank" rel="noopener noreferrer nofollow" href="http://datascience-school.com">datascience-school.com</a></h3></center>
