# %% [markdown]
# ---
# <center><h1> Lesson 8.1 - Work with Twitter API in Python</center></h1>
#
# ---

# %% [markdown]
# A Web API is an *application programming interface* (**API**). It helps easely to entaract with program programs and web services.
#
# Today many services provide its API for developers (such as Facebook, Google, Twitter, etc). API helps to en to interact with their services and to access data in a programmatic way. With help of API, you can create your own application.
#
# API is a set of subroutine definitions, protocols, and tools for building application software. In general terms, it is a set of clearly defined methods of communication between various software components. A good API makes it easier to develop a computer program by providing all the building blocks, which are then put together by the programmer. An API may be for a web-based system, operating system, database system, computer hardware or software library.
#
# The current lesson is devoted to Twitter API. We will consider both approaches of getting access to Twitter API - main Python tools such as `request` library and specific Python libraries such as `tweepy`.

# %% [markdown]
# <img src="images/Python_Twitter.jpg" width="512px" height="288px">
#
# One of the reasons that Twitter is so popular, and become what it is today, is due to the huge number of developers who have built apps over the years. Why so many developers? Basically because Twitter has been very easy to work with. Twitter uses the OAuth protocol for secure application development.
#
# In this lesson, you will create an application integrated with Twitter. Registering the application is the first step in developing an application that is integrated into its users' social graph.

# %% [markdown]
# ## Register a new application
# All Twitter users are potentially Twitter application developers. Visit https://apps.twitter.com and and press "Create New App".
#
# <img src="images/twitter_01.jpg">
#
# After that fill Aplication Detals (Name, Description and Website), read and agree to the Twitter Developer Agreement. Press "Create your Twitter application".
# (Note that you must add your mobile phone to your Twitter profile before creating an application. Please read [here](https://support.twitter.com/articles/110250-adding-your-mobile-number-to-your-account-via-web) for more information.)
#
# <img src="images/twitter_02.jpg">
# After Captcha challenge click "Create your Twitter application" to complete the form and go to the application settings page.
#
# We now need to authorise the Twitter app for your Twitter account. To do this you should select "Key and Access Tokens" menu button and create your access token. This **access token** will allow your Twitter application to read Twitter information. You’ll be able to get data of your tweets, mentions, lists and more.
#
# <img src="images/twitter_03.jpg">
#
# In the opened window you’ll then be presented with lots of information. The main fields to note are **_Consumer key_** and **_Consumer secret_**. These values are your application’s credentials for Twitter. You need them to do almost anything with Twitter, including going through the OAuth authorization flow and working with Twitter’s REST API. But we’re not quite done yet.
#
# As a result you will see the window with consumer and token keys for your application
#
# <img src="images/twitter_04.jpg">
#
# Above the four fields are highlighted. You will need these long horrible strings of characters for your Twitter app.

# %% [markdown]
# ---
# ## 1. Getting access to Twitter APIs using main Python tools
# ---

# %% [markdown]
# Many web services including Twitter require authentication, and there are many different types.
#
# Python library `requests` provides a pythonic way to make complex HTTP requests, and handles difficult tasks like authentication.
#
# A common form of authentication for several web APIs is OAuth. The `requests-oauthlib` library allows `requests`'s users to easily make OAuth authenticated requests.

# %%
import requests
from requests_oauthlib import OAuth1

import json

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
consumer_key = 'o7ApzFDk58YKYoCXR7au2Qa8o'
consumer_secret = 'sCruk5UCcQpuyL7NWPizcgfDHeJEG5CEioG43j6iNOmUymJsVa'

access_token = '1437963396-DdboBDabBE3KyUqHd8Zz3sr8MxVpKDwVRJRUjiC'
access_secret = 'R4GmIhhjx2doAZFam1EMrgFuxFe5u7zXRBR7dLEgGjqSp'

# You will authenticate yourself using OAuth1 object
auth = OAuth1(consumer_key, consumer_secret, access_token, access_secret)
print auth
# Out:
# <requests_oauthlib.oauth1_auth.OAuth1 object at 0x7fda282eae50>

# %%
# If the authentication was successful, you should see the name of the account print out
url_0 = 'https://api.twitter.com/1.1/account/verify_credentials.json'
res = requests.get(url_0, auth=auth)

print "My name is", res.json()['name']
# Out:
# My name is Dmitriy Kisil

# %% [markdown]
# ### 1.1: Read Tweets from Your Homepage
#
# The list of all available Twitter API you can find here https://developer.twitter.com/en/docs/api-reference-index. Let's use `home_timeline` that returns a collection of the most recent tweets and retweets posted by the authenticating user and the users they follow.

# %%
url_1 = 'https://api.twitter.com/1.1/statuses/home_timeline.json'
res = requests.get(url_1, auth=auth, params={"count": 3})

# The res object encapsulates the "response" of the server. Notice the status code that is displayed. 
# Code 200 means that things went fine
# Code 403 means that the server understood the request, but is refusing to fulfill it
# Code 404 means that the URL was not found
# Codes 5xx mean that something went wrong

print res, "Status code:", res.status_code
# Let's see how looks the url
print res.url
print "Content type:", res.headers['content-type'], '\n'

tweets = res.json()
if res.status_code == 200:
    for tweet in tweets:
        print tweet['text']
else:   # You have no tweets
    print tweets
# Out:
# <Response [200]> Status code: 200
# https://api.twitter.com/1.1/statuses/home_timeline.json?count=3
# Content type: application/json;charset=utf-8
#
# RT @PleaseBeGneiss: Stranger asks you what time it is = kinda annoying
#
# Stranger asks you what year it is = pretty concerning
#
# Stranger as…
# RT @AshleyS89102847: I'm beyond excited and proud to say I did my first coding project with @freeCodeCamp!!!! The feeling of accomplishment…
# PM дайджест #16: разбираемся с OKR, как вернуть Scrum-команде вдохновение, метрики в разработке… https://t.co/t6QrF63bTU

# %% [markdown]
# ### 1.2: Search tweets by key words
#
# Twitter employs a special query language.  For example, the query _"luck?"_ will return tweets that contain the word "luck" and are phrased as a question OR the query _"winter"_ will return the word "winter" with a positive attitude. [Check out more examples here](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets).
#
# We can mine tweets using either **_search_** or **_stream_**.
#
# >The key difference between **_stream_** and **_search_** is that **_stream_** provides new data as it comes in, while **_search_** can be used to query old data. The **_search_** API is more powerful for queries, and provides faster access to a wide-range of data.
#
# Let's search for a single tweet about "luck?", phrased as a question. Note if request phrase contains URI characters you should [encode](https://en.wikipedia.org/wiki/Percent-encoding) these queries before making the request, because these characters can play role of keys in an URL. Particularly, the question mark "?" is encoded as "%3F".

# %%
url_2 = 'https://api.twitter.com/1.1/search/tweets.json?q=luck%3F'
res = requests.get(url_2, auth=auth)

print res, res.status_code, res.headers['content-type']
print res.url

tweets = res.json()
tweets
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=luck%3F
# {u'search_metadata': {u'completed_in': 0.043,
#   u'count': 15,
#   u'max_id': 1089114579689398272,
#   u'max_id_str': u'1089114579689398272',
#   u'next_results': u'?max_id=1089114254366584831&q=luck%3F&include_entities=1',
#   u'query': u'luck%3F',
#   u'refresh_url': u'?since_id=1089114579689398272&q=luck%3F&include_entities=1',
#   u'since_id': 0,
#   u'since_id_str': u'0'},
#  u'statuses': [{u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:25 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 765224958138077184,
#       u'id_str': u'765224958138077184',
#       u'indices': [0, 10],
#       u'name': u'Vulva Whisperer',
#       u'screen_name': u'brobro___'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114579689398272,
#    u'id_str': u'1089114579689398272',
#    u'in_reply_to_screen_name': u'brobro___',
#    u'in_reply_to_status_id': 1089111965899714560,
#    u'in_reply_to_status_id_str': u'1089111965899714560',
#    u'in_reply_to_user_id': 765224958138077184,
#    u'in_reply_to_user_id_str': u'765224958138077184',
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u'@brobro___ oh, ini kamu yang sekarang, pribadi yang merasa lebih hanya karna punya uang? good luck ya :)',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Thu Jun 28 04:40:03 +0000 2018',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Si respiciens eram ad te respiciens ad me, ut revertar ad vos quaeritis me',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 10,
#     u'follow_request_sent': False,
#     u'followers_count': 24,
#     u'following': False,
#     u'friends_count': 156,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 1012193887555686406,
#     u'id_str': u'1012193887555686406',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 0,
#     u'location': u'Hindia Belanda',
#     u'name': u'mo chuisle',
#     u'notifications': False,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': None,
#     u'profile_background_image_url_https': None,
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1012193887555686406/1548496386',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088984181110059008/Jqd5S6gb_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088984181110059008/Jqd5S6gb_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Inheemsch',
#     u'statuses_count': 2030,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:23 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 2842292502,
#       u'id_str': u'2842292502',
#       u'indices': [3, 15],
#       u'name': u'dhea//GA\U0001f4cc',
#       u'screen_name': u'Luljongin88'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114574014410753,
#    u'id_str': u'1089114574014410753',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 742,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 06:10:07 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1089042783422185472',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/MrFUduvvIV'}],
#      u'user_mentions': []},
#     u'favorite_count': 726,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089042783422185472,
#     u'id_str': u'1089042783422185472',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 742,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Da\u2026 https://t.co/MrFUduvvIV',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Mon Oct 06 12:37:36 +0000 2014',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'\u2022 Live a happy life, that\u2019s how you can repay the people in your life \u2022',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 20773,
#      u'follow_request_sent': False,
#      u'followers_count': 3143,
#      u'following': False,
#      u'friends_count': 1053,
#      u'geo_enabled': True,
#      u'has_extended_profile': True,
#      u'id': 2842292502,
#      u'id_str': u'2842292502',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 12,
#      u'location': u'',
#      u'name': u'dhea//GA\U0001f4cc',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': True,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2842292502/1546450835',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_link_color': u'0084B4',
#      u'profile_sidebar_border_color': u'FFFFFF',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'Luljongin88',
#      u'statuses_count': 48575,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'RT @Luljongin88: GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Sep 14 08:50:38 +0000 2011',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'why u sad? idk nan molla',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 172,
#     u'follow_request_sent': False,
#     u'followers_count': 124,
#     u'following': False,
#     u'friends_count': 110,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 373269639,
#     u'id_str': u'373269639',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'Indonesia',
#     u'name': u'hani',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/373269639/1534095925',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1035555524954091520/6GiCqxEh_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1035555524954091520/6GiCqxEh_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'haihani911',
#     u'statuses_count': 856,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:19 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 2842292502,
#       u'id_str': u'2842292502',
#       u'indices': [3, 15],
#       u'name': u'dhea//GA\U0001f4cc',
#       u'screen_name': u'Luljongin88'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114557652451328,
#    u'id_str': u'1089114557652451328',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 742,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 06:10:07 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1089042783422185472',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/MrFUduvvIV'}],
#      u'user_mentions': []},
#     u'favorite_count': 726,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089042783422185472,
#     u'id_str': u'1089042783422185472',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 742,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Da\u2026 https://t.co/MrFUduvvIV',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Mon Oct 06 12:37:36 +0000 2014',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'\u2022 Live a happy life, that\u2019s how you can repay the people in your life \u2022',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 20773,
#      u'follow_request_sent': False,
#      u'followers_count': 3143,
#      u'following': False,
#      u'friends_count': 1053,
#      u'geo_enabled': True,
#      u'has_extended_profile': True,
#      u'id': 2842292502,
#      u'id_str': u'2842292502',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 12,
#      u'location': u'',
#      u'name': u'dhea//GA\U0001f4cc',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': True,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2842292502/1546450835',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_link_color': u'0084B4',
#      u'profile_sidebar_border_color': u'FFFFFF',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'Luljongin88',
#      u'statuses_count': 48575,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'RT @Luljongin88: GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Jan 15 14:15:31 +0000 2018',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'\u2022\xb0\u2022\xb0\u2022\xb0\u2022',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 5050,
#     u'follow_request_sent': False,
#     u'followers_count': 217,
#     u'following': False,
#     u'friends_count': 329,
#     u'geo_enabled': False,
#     u'has_extended_profile': True,
#     u'id': 952907099444412416,
#     u'id_str': u'952907099444412416',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'Batu, Indonesia',
#     u'name': u'ciww \U0001f4ab',
#     u'notifications': False,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': None,
#     u'profile_background_image_url_https': None,
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/952907099444412416/1548402962',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088706478590967809/W1oP1mZw_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088706478590967809/W1oP1mZw_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'MeiliaDwi3',
#     u'statuses_count': 2429,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:11 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 2842292502,
#       u'id_str': u'2842292502',
#       u'indices': [3, 15],
#       u'name': u'dhea//GA\U0001f4cc',
#       u'screen_name': u'Luljongin88'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114521061416960,
#    u'id_str': u'1089114521061416960',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 742,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 06:10:07 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1089042783422185472',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/MrFUduvvIV'}],
#      u'user_mentions': []},
#     u'favorite_count': 726,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089042783422185472,
#     u'id_str': u'1089042783422185472',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 742,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Da\u2026 https://t.co/MrFUduvvIV',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Mon Oct 06 12:37:36 +0000 2014',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'\u2022 Live a happy life, that\u2019s how you can repay the people in your life \u2022',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 20773,
#      u'follow_request_sent': False,
#      u'followers_count': 3143,
#      u'following': False,
#      u'friends_count': 1053,
#      u'geo_enabled': True,
#      u'has_extended_profile': True,
#      u'id': 2842292502,
#      u'id_str': u'2842292502',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 12,
#      u'location': u'',
#      u'name': u'dhea//GA\U0001f4cc',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': True,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2842292502/1546450835',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088673265290100736/Q-LGihDz_normal.jpg',
#      u'profile_link_color': u'0084B4',
#      u'profile_sidebar_border_color': u'FFFFFF',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'Luljongin88',
#      u'statuses_count': 48575,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'RT @Luljongin88: GIVEAWAY INA ONLY\U0001f4e3\U0001f4e3\U0001f4e3\n\nAku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Apr 04 04:03:54 +0000 2014',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'ice',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 1596,
#     u'follow_request_sent': False,
#     u'followers_count': 299,
#     u'following': False,
#     u'friends_count': 205,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 2426633089,
#     u'id_str': u'2426633089',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'yogyakarta',
#     u'name': u'pakyu',
#     u'notifications': False,
#     u'profile_background_color': u'F5ABB5',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2426633089/1525195670',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1084664051563585536/WkK6xhkf_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1084664051563585536/WkK6xhkf_normal.jpg',
#     u'profile_link_color': u'F5ABB5',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'_jevinsa',
#     u'statuses_count': 3805,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:08 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 597487653,
#       u'id_str': u'597487653',
#       u'indices': [3, 18],
#       u'name': u'Sumayyah \xae',
#       u'screen_name': u'topislamictwit'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114510256857088,
#    u'id_str': u'1089114510256857088',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 401,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 05:03:22 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': []},
#     u'favorite_count': 534,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089025985968832514,
#     u'id_str': u'1089025985968832514',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'retweet_count': 401,
#     u'retweeted': False,
#     u'source': u'<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#     u'text': u'"Gantikan ucapan good luck kepada."\n\n"Allah yuftah alaikum."\n\n"Maksudnya?"\n\n"Semoga Allah membuka jalan kepada kamu."\n\n"Insya Allah."',
#     u'truncated': False,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Sat Jun 02 13:20:55 +0000 2012',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'Without love - we feel nothing. Without dreams - we accomplish nothing. Without Allah - we are nothing. | Please RT and Follow',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 45015,
#      u'follow_request_sent': False,
#      u'followers_count': 106406,
#      u'following': False,
#      u'friends_count': 14067,
#      u'geo_enabled': False,
#      u'has_extended_profile': True,
#      u'id': 597487653,
#      u'id_str': u'597487653',
#      u'is_translation_enabled': False,
#      u'is_translator': True,
#      u'lang': u'tr',
#      u'listed_count': 296,
#      u'location': u'Ankara/Turkey',
#      u'name': u'Sumayyah \xae',
#      u'notifications': False,
#      u'profile_background_color': u'C0DEED',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#      u'profile_background_tile': True,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/597487653/1516878036',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/873391721123647489/k3LxdmAe_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/873391721123647489/k3LxdmAe_normal.jpg',
#      u'profile_link_color': u'E81C4F',
#      u'profile_sidebar_border_color': u'000000',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'topislamictwit',
#      u'statuses_count': 38498,
#      u'time_zone': None,
#      u'translator_type': u'badged',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    u'text': u'RT @topislamictwit: "Gantikan ucapan good luck kepada."\n\n"Allah yuftah alaikum."\n\n"Maksudnya?"\n\n"Semoga Allah membuka jalan kepada kamu."\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Apr 04 07:13:36 +0000 2014',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Face the reality  \U0001f44a',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 1292,
#     u'follow_request_sent': False,
#     u'followers_count': 50,
#     u'following': False,
#     u'friends_count': 35,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 2426838966,
#     u'id_str': u'2426838966',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 0,
#     u'location': u'',
#     u'name': u'Rushda Araf',
#     u'notifications': False,
#     u'profile_background_color': u'89C9FA',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2426838966/1537507246',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1079301803236196353/fzPOtXTn_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1079301803236196353/fzPOtXTn_normal.jpg',
#     u'profile_link_color': u'981CEB',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Rushda_00',
#     u'statuses_count': 238,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:55:04 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 811941728,
#       u'id_str': u'811941728',
#       u'indices': [3, 15],
#       u'name': u'FashionNova',
#       u'screen_name': u'FashionNova'},
#      {u'id': 811941728,
#       u'id_str': u'811941728',
#       u'indices': [97, 109],
#       u'name': u'FashionNova',
#       u'screen_name': u'FashionNova'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114493341368320,
#    u'id_str': u'1089114493341368320',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 1000,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 17:04:17 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1088845021187518464',
#        u'indices': [116, 139],
#        u'url': u'https://t.co/B97vWhierF'}],
#      u'user_mentions': [{u'id': 811941728,
#        u'id_str': u'811941728',
#        u'indices': [80, 92],
#        u'name': u'FashionNova',
#        u'screen_name': u'FashionNova'}]},
#     u'favorite_count': 556,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088845021187518464,
#     u'id_str': u'1088845021187518464',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#     u'place': None,
#     u'retweet_count': 1000,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"\U0001f6a8Contest\U0001f6a8 Do you want to win a $200 FN gift card?! \U0001f911 \U0001f6cd\U0001f64c\n\nHere's how:\n\n1. Follow @FashionNova on Twitter\n2. RT this\u2026 https://t.co/B97vWhierF",
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Sun Sep 09 00:03:09 +0000 2012',
#      u'default_profile': False,
#      u'default_profile_image': False,
#      u'description': u'Global Fashion Brand \U0001f30e #NovaBabe \U0001f6cd\ufe0f For all customer service inquiries, direct message us at @FashionNovaHelp! xoxo',
#      u'entities': {u'description': {u'urls': []},
#       u'url': {u'urls': [{u'display_url': u'FashionNova.com',
#          u'expanded_url': u'http://www.FashionNova.com',
#          u'indices': [0, 23],
#          u'url': u'https://t.co/tlenc86N5R'}]}},
#      u'favourites_count': 38544,
#      u'follow_request_sent': False,
#      u'followers_count': 109484,
#      u'following': False,
#      u'friends_count': 2,
#      u'geo_enabled': True,
#      u'has_extended_profile': False,
#      u'id': 811941728,
#      u'id_str': u'811941728',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 207,
#      u'location': u'',
#      u'name': u'FashionNova',
#      u'notifications': False,
#      u'profile_background_color': u'131516',
#      u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      u'profile_background_tile': True,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/811941728/1547831801',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/955994323803258890/hZKRX6kt_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/955994323803258890/hZKRX6kt_normal.jpg',
#      u'profile_link_color': u'F58EA8',
#      u'profile_sidebar_border_color': u'EEEEEE',
#      u'profile_sidebar_fill_color': u'EFEFEF',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'FashionNova',
#      u'statuses_count': 35544,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': u'https://t.co/tlenc86N5R',
#      u'utc_offset': None,
#      u'verified': True}},
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"RT @FashionNova: \U0001f6a8Contest\U0001f6a8 Do you want to win a $200 FN gift card?! \U0001f911 \U0001f6cd\U0001f64c\n\nHere's how:\n\n1. Follow @FashionNova on Twitter\n2. RT this post!\n3\u2026",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Jul 15 01:41:08 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Beat maker, Rhyme Sayer, word player, breath taker https://t.co/xZBtpflbM3 snapchat kgpbeats MMMM #surrealgang gang gang gang',
#     u'entities': {u'description': {u'urls': [{u'display_url': u'traktrain.com/ramajerockgp',
#         u'expanded_url': u'http://traktrain.com/ramajerockgp',
#         u'indices': [51, 74],
#         u'url': u'https://t.co/xZBtpflbM3'}]},
#      u'url': {u'urls': [{u'display_url': u'soundcloud.com/kaysharnea',
#         u'expanded_url': u'http://www.soundcloud.com/kaysharnea',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/h1gAETJ13n'}]}},
#     u'favourites_count': 2632,
#     u'follow_request_sent': False,
#     u'followers_count': 973,
#     u'following': False,
#     u'friends_count': 1196,
#     u'geo_enabled': False,
#     u'has_extended_profile': True,
#     u'id': 335665783,
#     u'id_str': u'335665783',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 20,
#     u'location': u'South Los Angeles, Los Angeles',
#     u'name': u'KaySharnea',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/335665783/1360732211',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/805409945462198272/x8TJMBBT_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/805409945462198272/x8TJMBBT_normal.jpg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'KaySharnea',
#     u'statuses_count': 1824,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'https://t.co/h1gAETJ13n',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:54 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/1089114451616387072',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/DJF5Q349Y6'}],
#     u'user_mentions': [{u'id': 27844464,
#       u'id_str': u'27844464',
#       u'indices': [0, 14],
#       u'name': u'Sunderland AFC',
#       u'screen_name': u'SunderlandAFC'},
#      {u'id': 2508653736,
#       u'id_str': u'2508653736',
#       u'indices': [15, 24],
#       u'name': u'Josh Maja',
#       u'screen_name': u'joshmaja'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114451616387072,
#    u'id_str': u'1089114451616387072',
#    u'in_reply_to_screen_name': u'SunderlandAFC',
#    u'in_reply_to_status_id': 1089102671800340480,
#    u'in_reply_to_status_id_str': u'1089102671800340480',
#    u'in_reply_to_user_id': 27844464,
#    u'in_reply_to_user_id_str': u'27844464',
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'@SunderlandAFC @joshmaja I don\u2019t get why everyone is slagging the kid off? If you got offered a promotion at work w\u2026 https://t.co/DJF5Q349Y6',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Oct 18 21:36:57 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'-DURHAM --- MUSIC --- FAMILY -',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 2532,
#     u'follow_request_sent': False,
#     u'followers_count': 614,
#     u'following': False,
#     u'friends_count': 1028,
#     u'geo_enabled': True,
#     u'has_extended_profile': True,
#     u'id': 204513245,
#     u'id_str': u'204513245',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 7,
#     u'location': u'Durham, England ',
#     u'name': u'Simon T',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/204513245/1505558619',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/909004842244481024/xdlrihQR_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/909004842244481024/xdlrihQR_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'siethomp',
#     u'statuses_count': 8243,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:44 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 905753208424808448,
#       u'id_str': u'905753208424808448',
#       u'indices': [3, 13],
#       u'name': u'H. | Giveaway on Pinned.',
#       u'screen_name': u'ebusehdeh'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114410168152064,
#    u'id_str': u'1089114410168152064',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 106,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 07:04:09 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1089056380718178304',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/3Sbr9ynWYT'}],
#      u'user_mentions': []},
#     u'favorite_count': 98,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089056380718178304,
#     u'id_str': u'1089056380718178304',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 106,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     u'text': u'[Second Giveaway]\n\nMau hibahin skincare aja daripada ga kepake kan?\nSyaratnya:\n1. Retweet dan like tweet ini\n2. Fol\u2026 https://t.co/3Sbr9ynWYT',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Thu Sep 07 11:22:47 +0000 2017',
#      u'default_profile': True,
#      u'default_profile_image': False,
#      u'description': u'ini akun gado-gado bisa ca, fg, ba (bacot account)',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 615,
#      u'follow_request_sent': False,
#      u'followers_count': 147,
#      u'following': False,
#      u'friends_count': 218,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 905753208424808448,
#      u'id_str': u'905753208424808448',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 0,
#      u'location': u'bts x w1',
#      u'name': u'H. | Giveaway on Pinned.',
#      u'notifications': False,
#      u'profile_background_color': u'F5F8FA',
#      u'profile_background_image_url': None,
#      u'profile_background_image_url_https': None,
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/905753208424808448/1548458050',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1089072673156550656/LME0bmDb_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1089072673156550656/LME0bmDb_normal.jpg',
#      u'profile_link_color': u'1DA1F2',
#      u'profile_sidebar_border_color': u'C0DEED',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'ebusehdeh',
#      u'statuses_count': 5014,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'RT @ebusehdeh: [Second Giveaway]\n\nMau hibahin skincare aja daripada ga kepake kan?\nSyaratnya:\n1. Retweet dan like tweet ini\n2. Follow me (o\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Feb 15 13:27:54 +0000 2013',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414\U0001f414',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'instagram.com/j_niais',
#         u'expanded_url': u'http://www.instagram.com/j_niais',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/seK0D5AgSX'}]}},
#     u'favourites_count': 46803,
#     u'follow_request_sent': False,
#     u'followers_count': 163,
#     u'following': False,
#     u'friends_count': 163,
#     u'geo_enabled': False,
#     u'has_extended_profile': True,
#     u'id': 1182571860,
#     u'id_str': u'1182571860',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'YG STAN + MYDAY',
#     u'name': u'Twins Jae\U0001f3b8| STREAM\U0001f534DAY6 - DAYS GONE BY\U0001f3bc',
#     u'notifications': False,
#     u'profile_background_color': u'131516',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1182571860/1548346240',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/982898409425141764/YPNHsup9_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/982898409425141764/YPNHsup9_normal.jpg',
#     u'profile_link_color': u'19CF86',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'j_niais',
#     u'statuses_count': 12010,
#     u'time_zone': None,
#     u'translator_type': u'regular',
#     u'url': u'https://t.co/seK0D5AgSX',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:43 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 1027151391662325760,
#       u'id_str': u'1027151391662325760',
#       u'indices': [0, 9],
#       u'name': u'didit \u221e',
#       u'screen_name': u'wuanable'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114405516632064,
#    u'id_str': u'1089114405516632064',
#    u'in_reply_to_screen_name': u'wuanable',
#    u'in_reply_to_status_id': 1089099934169624576,
#    u'in_reply_to_status_id_str': u'1089099934169624576',
#    u'in_reply_to_user_id': 1027151391662325760,
#    u'in_reply_to_user_id_str': u'1027151391662325760',
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'@wuanable Wishh me luck! Ayoo bermutual? Followback jangan lupaaa ^^',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Feb 09 00:27:11 +0000 2016',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'A panwink supremacist, dedicated maynabble, full time seulginator.',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 150,
#     u'follow_request_sent': False,
#     u'followers_count': 87,
#     u'following': False,
#     u'friends_count': 113,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 4880392512,
#     u'id_str': u'4880392512',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 1,
#     u'location': u'',
#     u'name': u'Re',
#     u'notifications': False,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': None,
#     u'profile_background_image_url_https': None,
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/4880392512/1548412078',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1088104147038068737/rtUdgiUE_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1088104147038068737/rtUdgiUE_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'maynabble',
#     u'statuses_count': 1006,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:40 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/1089114392774332417',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/sXFvueYAwg'}],
#     u'user_mentions': [{u'id': 2372004222,
#       u'id_str': u'2372004222',
#       u'indices': [0, 9],
#       u'name': u'USE [tanyarl]',
#       u'screen_name': u'tanya2rl'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114392774332417,
#    u'id_str': u'1089114392774332417',
#    u'in_reply_to_screen_name': u'tanya2rl',
#    u'in_reply_to_status_id': 1089113280591740928,
# ...
#    u'id': 1089114364089647106,
#    u'id_str': u'1089114364089647106',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'Travelling to Killarney today for the Tyrone game tomorrow? If so get yourself along to Dr Crokes and get behind th\u2026 https://t.co/qIeXa3g86I',
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Wed Apr 21 21:41:14 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u"Twitter account of Ardboe O'Donovan Rossa GFC",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'ardboegfc.com',
#         u'expanded_url': u'http://www.ardboegfc.com',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/NfSrWTdWJW'}]}},
#     u'favourites_count': 145,
#     u'follow_request_sent': False,
#     u'followers_count': 2996,
#     u'following': False,
#     u'friends_count': 467,
#     u'geo_enabled': False,
#     u'has_extended_profile': False,
#     u'id': 135635730,
#     u'id_str': u'135635730',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 17,
#     u'location': u'Ardboe, Co. Tyrone',
#     u'name': u'Ard B\xf3',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/135635730/1452018831',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/628286523813818370/07mkZ_Xo_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/628286523813818370/07mkZ_Xo_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'ardboegfc',
#     u'statuses_count': 3593,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'https://t.co/NfSrWTdWJW',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:22 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/1089114317268504576',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/AnYxlMLpIj'}],
#     u'user_mentions': [{u'id': 3375838634,
#       u'id_str': u'3375838634',
#       u'indices': [0, 11],
#       u'name': u'Fuka Shiraishi.',
#       u'screen_name': u'CherNaveen'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114317268504576,
#    u'id_str': u'1089114317268504576',
#    u'in_reply_to_screen_name': u'hana_tsumabuki',
#    u'in_reply_to_status_id': 1089114294212485120,
#    u'in_reply_to_status_id_str': u'1089114294212485120',
#    u'in_reply_to_user_id': 942265839297761281,
#    u'in_reply_to_user_id_str': u'942265839297761281',
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    u'text': u"@CherNaveen -- street, remember? And luck for today, the lights turn into green when she's already reached the road\u2026 https://t.co/AnYxlMLpIj",
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Dec 17 05:30:57 +0000 2017',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"\u300e But this is how I look..  \u300fRP purpose only OCRP2D \u2022\xb0 Editor in 'Throw Magz' \u2022\xb0 All pics belong to the artist \u2022\xb0 Link on bio \u2022\xb0 Ava by Aera on FB",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'hanasan.carrd.co',
#         u'expanded_url': u'https://hanasan.carrd.co/',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/OVFcLXetC2'}]}},
#     u'favourites_count': 26,
#     u'follow_request_sent': False,
#     u'followers_count': 86,
#     u'following': False,
#     u'friends_count': 71,
#     u'geo_enabled': False,
#     u'has_extended_profile': True,
#     u'id': 942265839297761281,
#     u'id_str': u'942265839297761281',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'',
#     u'name': u'Hana',
#     u'notifications': False,
#     u'profile_background_color': u'000000',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/942265839297761281/1537547575',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1087697878187880448/UTJduE80_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1087697878187880448/UTJduE80_normal.jpg',
#     u'profile_link_color': u'F58EA8',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'000000',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': False,
#     u'protected': False,
#     u'screen_name': u'hana_tsumabuki',
#     u'statuses_count': 2251,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'https://t.co/OVFcLXetC2',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': {u'coordinates': [-2.729673, 53.342078], u'type': u'Point'},
#    u'created_at': u'Sat Jan 26 10:54:16 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#       u'expanded_url': u'https://twitter.com/i/web/status/1089114289720291328',
#       u'indices': [117, 140],
#       u'url': u'https://t.co/OJeWE4f82y'}],
#     u'user_mentions': []},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': {u'coordinates': [53.342078, -2.729673], u'type': u'Point'},
#    u'id': 1089114289720291328,
#    u'id_str': u'1089114289720291328',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': {u'attributes': {},
#     u'bounding_box': {u'coordinates': [[[-2.761929, 53.305809],
#        [-2.670996, 53.305809],
#        [-2.670996, 53.350151],
#        [-2.761929, 53.350151]]],
#      u'type': u'Polygon'},
#     u'contained_within': [],
#     u'country': u'United Kingdom',
#     u'country_code': u'GB',
#     u'full_name': u'Runcorn, England',
#     u'id': u'6bbcd311fdb99c3b',
#     u'name': u'Runcorn',
#     u'place_type': u'city',
#     u'url': u'https://api.twitter.com/1.1/geo/id/6bbcd311fdb99c3b.json'},
#    u'retweet_count': 0,
#    u'retweeted': False,
#    u'source': u'<a href="https://www.careerarc.com" rel="nofollow">CareerArc 2.0</a>',
#    u'text': u"Looking to score a job at Thermo Fisher Scientific? You're in luck. Click the link in our bio for the job descripti\u2026 https://t.co/OJeWE4f82y",
#    u'truncated': True,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Mar 08 23:06:43 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Follow this account for geo-targeted Engineering job tweets in Manchester, UK. Need help? Tweet us at @CareerArc!',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'bit.ly/2G7gv6n',
#         u'expanded_url': u'http://bit.ly/2G7gv6n',
#         u'indices': [0, 23],
#         u'url': u'https://t.co/meevVyzNE9'}]}},
#     u'favourites_count': 0,
#     u'follow_request_sent': False,
#     u'followers_count': 272,
#     u'following': False,
#     u'friends_count': 231,
#     u'geo_enabled': True,
#     u'has_extended_profile': False,
#     u'id': 23368024,
#     u'id_str': u'23368024',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 33,
#     u'location': u'Manchester, UK',
#     u'name': u'TMJ-UKM Engin. Jobs',
#     u'notifications': False,
#     u'profile_background_color': u'253956',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/23368024/1450902141',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/679758959092187136/BTaGduBH_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/679758959092187136/BTaGduBH_normal.jpg',
#     u'profile_link_color': u'4A913C',
#     u'profile_sidebar_border_color': u'000000',
#     u'profile_sidebar_fill_color': u'407DB0',
#     u'profile_text_color': u'000000',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'tmj_ukm_eng',
#     u'statuses_count': 221,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': u'https://t.co/meevVyzNE9',
#     u'utc_offset': None,
#     u'verified': False}},
#   {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Sat Jan 26 10:54:07 +0000 2019',
#    u'entities': {u'hashtags': [],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': [{u'id': 905753208424808448,
#       u'id_str': u'905753208424808448',
#       u'indices': [3, 13],
#       u'name': u'H. | Giveaway on Pinned.',
#       u'screen_name': u'ebusehdeh'}]},
#    u'favorite_count': 0,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 1089114254366584832,
#    u'id_str': u'1089114254366584832',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'is_quote_status': False,
#    u'lang': u'in',
#    u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 106,
#    u'retweeted': False,
#    u'retweeted_status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 07:04:09 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1089056380718178304',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/3Sbr9ynWYT'}],
#      u'user_mentions': []},
#     u'favorite_count': 98,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089056380718178304,
#     u'id_str': u'1089056380718178304',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'in',
#     u'metadata': {u'iso_language_code': u'in', u'result_type': u'recent'},
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 106,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     u'text': u'[Second Giveaway]\n\nMau hibahin skincare aja daripada ga kepake kan?\nSyaratnya:\n1. Retweet dan like tweet ini\n2. Fol\u2026 https://t.co/3Sbr9ynWYT',
#     u'truncated': True,
#     u'user': {u'contributors_enabled': False,
#      u'created_at': u'Thu Sep 07 11:22:47 +0000 2017',
#      u'default_profile': True,
#      u'default_profile_image': False,
#      u'description': u'ini akun gado-gado bisa ca, fg, ba (bacot account)',
#      u'entities': {u'description': {u'urls': []}},
#      u'favourites_count': 615,
#      u'follow_request_sent': False,
#      u'followers_count': 147,
#      u'following': False,
#      u'friends_count': 218,
#      u'geo_enabled': False,
#      u'has_extended_profile': False,
#      u'id': 905753208424808448,
#      u'id_str': u'905753208424808448',
#      u'is_translation_enabled': False,
#      u'is_translator': False,
#      u'lang': u'en',
#      u'listed_count': 0,
#      u'location': u'bts x w1',
#      u'name': u'H. | Giveaway on Pinned.',
#      u'notifications': False,
#      u'profile_background_color': u'F5F8FA',
#      u'profile_background_image_url': None,
#      u'profile_background_image_url_https': None,
#      u'profile_background_tile': False,
#      u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/905753208424808448/1548458050',
#      u'profile_image_url': u'http://pbs.twimg.com/profile_images/1089072673156550656/LME0bmDb_normal.jpg',
#      u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1089072673156550656/LME0bmDb_normal.jpg',
#      u'profile_link_color': u'1DA1F2',
#      u'profile_sidebar_border_color': u'C0DEED',
#      u'profile_sidebar_fill_color': u'DDEEF6',
#      u'profile_text_color': u'333333',
#      u'profile_use_background_image': True,
#      u'protected': False,
#      u'screen_name': u'ebusehdeh',
#      u'statuses_count': 5014,
#      u'time_zone': None,
#      u'translator_type': u'none',
#      u'url': None,
#      u'utc_offset': None,
#      u'verified': False}},
#    u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    u'text': u'RT @ebusehdeh: [Second Giveaway]\n\nMau hibahin skincare aja daripada ga kepake kan?\nSyaratnya:\n1. Retweet dan like tweet ini\n2. Follow me (o\u2026',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sat Sep 01 08:36:47 +0000 2018',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'camaba yuenpat Aamiin\U0001f343',
#     u'entities': {u'description': {u'urls': []}},
#     u'favourites_count': 4455,
#     u'follow_request_sent': False,
#     u'followers_count': 566,
#     u'following': False,
#     u'friends_count': 913,
#     u'geo_enabled': False,
#     u'has_extended_profile': True,
#     u'id': 1035808675774980096,
#     u'id_str': u'1035808675774980096',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'id',
#     u'listed_count': 0,
#     u'location': u'ca pa',
#     u'name': u'Vita calon orang sukses dunia akhirat',
#     u'notifications': False,
#     u'profile_background_color': u'F5F8FA',
#     u'profile_background_image_url': None,
#     u'profile_background_image_url_https': None,
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1035808675774980096/1535801552',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/1086879873161777152/eVXx65zl_normal.jpg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1086879873161777152/eVXx65zl_normal.jpg',
#     u'profile_link_color': u'1DA1F2',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'penyukamtk',
#     u'statuses_count': 5512,
#     u'time_zone': None,
#     u'translator_type': u'none',
#     u'url': None,
#     u'utc_offset': None,
#     u'verified': False}}]}

# %% [markdown]
# Please pay your attention how many information each tweet contains.

# %%
# And let's see tweets text directly
for num, tweet in enumerate(tweets['statuses']):
    print 'Tweet #{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8"))
# Out:
# Tweet #1	Sat Jan 26 10:55:25 +0000 2019
# @brobro___ oh, ini kamu yang sekarang, pribadi yang merasa lebih hanya karna punya uang? good luck ya :)
#
# Tweet #2	Sat Jan 26 10:55:23 +0000 2019
# RT @Luljongin88: GIVEAWAY INA ONLY📣📣📣
#
# Aku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r…
#
# Tweet #3	Sat Jan 26 10:55:19 +0000 2019
# RT @Luljongin88: GIVEAWAY INA ONLY📣📣📣
#
# Aku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r…
#
# Tweet #4	Sat Jan 26 10:55:11 +0000 2019
# RT @Luljongin88: GIVEAWAY INA ONLY📣📣📣
#
# Aku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r…
#
# Tweet #5	Sat Jan 26 10:55:08 +0000 2019
# RT @topislamictwit: "Gantikan ucapan good luck kepada."
#
# "Allah yuftah alaikum."
#
# "Maksudnya?"
#
# "Semoga Allah membuka jalan kepada kamu."…
#
# Tweet #6	Sat Jan 26 10:55:04 +0000 2019
# RT @FashionNova: 🚨Contest🚨 Do you want to win a $200 FN gift card?! 🤑 🛍🙌
#
# Here's how:
#
# 1. Follow @FashionNova on Twitter
# 2. RT this post!
# 3…
#
# Tweet #7	Sat Jan 26 10:54:54 +0000 2019
# @SunderlandAFC @joshmaja I don’t get why everyone is slagging the kid off? If you got offered a promotion at work w… https://t.co/DJF5Q349Y6
#
# Tweet #8	Sat Jan 26 10:54:44 +0000 2019
# RT @ebusehdeh: [Second Giveaway]
#
# Mau hibahin skincare aja daripada ga kepake kan?
# Syaratnya:
# 1. Retweet dan like tweet ini
# 2. Follow me (o…
#
# Tweet #9	Sat Jan 26 10:54:43 +0000 2019
# @wuanable Wishh me luck! Ayoo bermutual? Followback jangan lupaaa ^^
#
# Tweet #10	Sat Jan 26 10:54:40 +0000 2019
# @tanya2rl Gapapa itu artinya Tuhan sayang sm kamu, ngasih tau kalo dia bukan org yg tepat buat kamu. Menghargai ker… https://t.co/sXFvueYAwg
#
# Tweet #11	Sat Jan 26 10:54:39 +0000 2019
# RT @Luljongin88: GIVEAWAY INA ONLY📣📣📣
#
# Aku adain giveaway ini karena Januari ngepasin Kyungsoo, Jongin dan Aku ulangtahun nih.... Dan ada r…
#
# Tweet #12	Sat Jan 26 10:54:33 +0000 2019
# Travelling to Killarney today for the Tyrone game tomorrow? If so get yourself along to Dr Crokes and get behind th… https://t.co/qIeXa3g86I
#
# Tweet #13	Sat Jan 26 10:54:22 +0000 2019
# @CherNaveen -- street, remember? And luck for today, the lights turn into green when she's already reached the road… https://t.co/AnYxlMLpIj
#
# Tweet #14	Sat Jan 26 10:54:16 +0000 2019
# Looking to score a job at Thermo Fisher Scientific? You're in luck. Click the link in our bio for the job descripti… https://t.co/OJeWE4f82y
#
# Tweet #15	Sat Jan 26 10:54:07 +0000 2019
# RT @ebusehdeh: [Second Giveaway]
#
# Mau hibahin skincare aja daripada ga kepake kan?
# Syaratnya:
# 1. Retweet dan like tweet ini
# 2. Follow me (o…

# %% [markdown]
# You may create very specialized and more concrete queries.
#
# Let's find 5 tweets that contains the word "python" or "IPython" near London. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language). Additional parameters allows build very complicated search requests.

# %%
url_2_2 = 'https://api.twitter.com/1.1/search/tweets.json?'

params = {
    "q": 'python OR IPython',
    "count": 5, 
    "show_user": False,
    "geocode": '51.509865,-0.118092,20mi',
    "lang": 'en'
}

res = requests.get(url_2_2, auth=auth, params=params)

print res, res.status_code, res.headers['content-type']
print res.url

tweets = res.json()
for num, tweet in enumerate(tweets['statuses']):
    print 'Tweet #{0}\t{1}\n{2}\n'.format(num+1, tweet['created_at'], tweet['text'].encode("utf-8"))
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/search/tweets.json?q=python+OR+IPython&count=5&geocode=51.509865%2C-0.118092%2C20mi&lang=en&show_user=False
# Tweet #1	Sat Jan 26 10:55:37 +0000 2019
# RT @BAFTA: We're here to sprinkle a bit of fun over your weekend as we look back at Monty Python's hilarious Outstanding Contribution To Br…
#
# Tweet #2	Sat Jan 26 10:53:05 +0000 2019
# RT @RyoIndie: Making a game isn't easy. Composing is a key part of it! #composing #coding #python #pygame #programming #sounddesign #music…
#
# Tweet #3	Sat Jan 26 10:52:20 +0000 2019
# RT @LoomiAssistant: Old vs New (well old with #AI)
#
# #Machinelearning #java #python #ArtificialIntelligence
# #programming #DataScience @Kirk…
#
# Tweet #4	Sat Jan 26 10:45:28 +0000 2019
# RT @BAFTA: We're here to sprinkle a bit of fun over your weekend as we look back at Monty Python's hilarious Outstanding Contribution To Br…
#
# Tweet #5	Sat Jan 26 10:33:06 +0000 2019
# Just like a Monty Python sketch.. or should that be Alias Smith and Jones 🤔 https://t.co/dNDubF30YQ

# %% [markdown]
# ### 1.3: Get a list of all your followers
#
# Twitter GET request `friends/list` returns a cursored collection of user objects for every user the specified user is following (otherwise known as their “friends”).

# %%
url_3 = 'https://api.twitter.com/1.1/friends/list.json'
res = requests.get(url_3, auth=auth)

print res, res.status_code, res.headers['content-type']
print res.url

friends = res.json()
friends
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/friends/list.json
# {u'next_cursor': 1590300932417656656,
#  u'next_cursor_str': u'1590300932417656656',
#  u'previous_cursor': 0,
#  u'previous_cursor_str': u'0',
#  u'total_count': None,
#  u'users': [{u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Wed Jan 10 23:40:13 +0000 2018',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Democratizing AI, one meme at the time! OC unless specified otherwise. Ran by @Aleksa_C_',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/artificialinte\u2026',
#        u'expanded_url': u'https://www.facebook.com/artificialintelligencememes/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/OdUkErt5Tf'}]}},
#    u'favourites_count': 320,
#    u'follow_request_sent': False,
#    u'followers_count': 5224,
#    u'following': True,
#    u'friends_count': 24,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 951237270044069888,
#    u'id_str': u'951237270044069888',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 44,
#    u'live_following': False,
#    u'location': u'',
#    u'muting': False,
#    u'name': u'AI Memes for Artificially Intelligent Teens',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/951238874570870784/1DdUfmqr_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/951238874570870784/1DdUfmqr_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'ai_memes',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Thu Jan 17 13:21:09 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 1021312806,
#        u'id_str': u'1021312806',
#        u'indices': [0, 11],
#        u'name': u'2nOrderEDO',
#        u'screen_name': u'2norderEDO'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1085889763591290880,
#     u'id_str': u'1085889763591290880',
#     u'in_reply_to_screen_name': u'2norderEDO',
#     u'in_reply_to_status_id': 1085823117744848896,
#     u'in_reply_to_status_id_str': u'1085823117744848896',
#     u'in_reply_to_user_id': 1021312806,
#     u'in_reply_to_user_id_str': u'1021312806',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'@2norderEDO I will if I find appropriate image, I also  have a few other improvements',
#     u'truncated': False},
#    u'statuses_count': 281,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/OdUkErt5Tf',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Mon May 05 15:00:00 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Husband, father, & Catholic enjoying life with my family. Working @ Microsoft. Disney fanatic, web and mobile developer, speaker, & author',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'johnpapa.net',
#        u'expanded_url': u'http://johnpapa.net',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/5WYl881ol0'}]}},
#    u'favourites_count': 3539,
#    u'follow_request_sent': False,
#    u'followers_count': 79836,
#    u'following': True,
#    u'friends_count': 1049,
#    u'geo_enabled': False,
#    u'has_extended_profile': True,
#    u'id': 14660297,
#    u'id_str': u'14660297',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 2257,
#    u'live_following': False,
#    u'location': u'Orlando, FL',
#    u'muting': False,
#    u'name': u'John Papa',
#    u'notifications': False,
#    u'profile_background_color': u'3B94D9',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/14660297/1354078568',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/888397702391902208/CupdIngs_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/888397702391902208/CupdIngs_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'E76240',
#    u'profile_sidebar_fill_color': u'F57C38',
#    u'profile_text_color': u'F6DD03',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'John_Papa',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 21:28:24 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 14660297,
#        u'id_str': u'14660297',
#        u'indices': [3, 13],
#        u'name': u'John Papa',
#        u'screen_name': u'John_Papa'},
#       {u'id': 1566463268,
#        u'id_str': u'1566463268',
#        u'indices': [95, 103],
#        u'name': u'React',
#        u'screen_name': u'reactjs'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088911490239877121,
#     u'id_str': u'1088911490239877121',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 19,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Fri Jan 25 14:39:31 +0000 2019',
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1088808590364692480',
#         u'indices': [117, 140],
#         u'url': u'https://t.co/3ZftoMCBVR'}],
#       u'user_mentions': [{u'id': 1566463268,
#         u'id_str': u'1566463268',
#         u'indices': [80, 88],
#         u'name': u'React',
#         u'screen_name': u'reactjs'}]},
#      u'favorite_count': 65,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1088808590364692480,
#      u'id_str': u'1088808590364692480',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': False,
#      u'lang': u'en',
#      u'place': None,
#      u'possibly_sensitive': False,
#      u'retweet_count': 19,
#      u'retweeted': False,
#      u'source': u'<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#      u'text': u"How can you benefit from creating a style guide for the apps you're building in @Reactjs? Find out on ep 16 of Real\u2026 https://t.co/3ZftoMCBVR",
#      u'truncated': True},
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"RT @John_Papa: How can you benefit from creating a style guide for the apps you're building in @Reactjs? Find out on ep 16 of Real Talk Jav\u2026",
#     u'truncated': False},
#    u'statuses_count': 41395,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/5WYl881ol0',
#    u'utc_offset': None,
#    u'verified': True},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Tue Feb 20 14:35:54 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'What\u2019s happening?!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'about.twitter.com',
#        u'expanded_url': u'https://about.twitter.com/',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/TAXQpsHa5X'}]}},
#    u'favourites_count': 5594,
#    u'follow_request_sent': False,
#    u'followers_count': 55911206,
#    u'following': True,
#    u'friends_count': 140,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 783214,
#    u'id_str': u'783214',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 91374,
#    u'live_following': False,
#    u'location': u'Everywhere',
#    u'muting': False,
#    u'name': u'Twitter',
#    u'notifications': False,
#    u'profile_background_color': u'ACDED6',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/783214/1537558537',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1013798240683266048/zRim1x6M_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1013798240683266048/zRim1x6M_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'F6F6F6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Twitter',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 21:57:33 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 334988605,
#        u'id_str': u'334988605',
#        u'indices': [0, 9],
#        u'name': u'Trill Withers',
#        u'screen_name': u'TylerIAm'}]},
#     u'favorite_count': 12,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088918824244662273,
#     u'id_str': u'1088918824244662273',
#     u'in_reply_to_screen_name': u'TylerIAm',
#     u'in_reply_to_status_id': 1088891181810008064,
#     u'in_reply_to_status_id_str': u'1088891181810008064',
#     u'in_reply_to_user_id': 334988605,
#     u'in_reply_to_user_id_str': u'334988605',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'@TylerIAm Without a screen time limit',
#     u'truncated': False},
#    u'statuses_count': 8758,
#    u'time_zone': None,
#    u'translator_type': u'regular',
#    u'url': u'https://t.co/TAXQpsHa5X',
#    u'utc_offset': None,
#    u'verified': True},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Thu Jul 19 15:20:15 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Data science (AKA statistics). Likes conditioning on the data (AKA Bayes). Works at King entertainment (of Candy Crush fame).',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'sumsar.net',
#        u'expanded_url': u'http://sumsar.net',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/8xZq66xDEA'}]}},
#    u'favourites_count': 2066,
#    u'follow_request_sent': False,
#    u'followers_count': 4185,
#    u'following': True,
#    u'friends_count': 317,
#    u'geo_enabled': False,
#    u'has_extended_profile': True,
#    u'id': 705253482,
#    u'id_str': u'705253482',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 181,
#    u'live_following': False,
#    u'location': u'Lund, Sweden',
#    u'muting': False,
#    u'name': u'Rasmus B\xe5\xe5th',
#    u'notifications': False,
#    u'profile_background_color': u'9AE4E8',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/705253482/1409777734',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/690549092100018176/2XVFSqwi_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/690549092100018176/2XVFSqwi_normal.jpg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'BDDCAD',
#    u'profile_sidebar_fill_color': u'DDFFCC',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'rabaath',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Wed Jan 23 10:17:48 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1088017952237109253',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/wrf4xKTRAg'}],
#      u'user_mentions': [{u'id': 2879642556,
#        u'id_str': u'2879642556',
#        u'indices': [0, 12],
#        u'name': u'Richard McElreath',
#        u'screen_name': u'rlmcelreath'},
#       {u'id': 1376401838,
#        u'id_str': u'1376401838',
#        u'indices': [13, 24],
#        u'name': u'Iyad Rahwan',
#        u'screen_name': u'iyadrahwan'}]},
#     u'favorite_count': 2,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088017952237109253,
#     u'id_str': u'1088017952237109253',
#     u'in_reply_to_screen_name': u'rlmcelreath',
#     u'in_reply_to_status_id': 1088002414240780289,
#     u'in_reply_to_status_id_str': u'1088002414240780289',
#     u'in_reply_to_user_id': 2879642556,
#     u'in_reply_to_user_id_str': u'2879642556',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'@rlmcelreath @iyadrahwan I look forward to when self driving cars are so common that there are comedy YouTube accou\u2026 https://t.co/wrf4xKTRAg',
#     u'truncated': True},
#    u'statuses_count': 1502,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/8xZq66xDEA',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Thu Oct 27 22:18:52 +0000 2016',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Azeroth Millionaire | Trade Prince Extraordinaire | https://t.co/OI4yOJRBLh | https://t.co/zCPGzMSMys',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'twitch.tv/lazygoldmaker',
#        u'expanded_url': u'http://twitch.tv/lazygoldmaker',
#        u'indices': [52, 75],
#        u'url': u'https://t.co/OI4yOJRBLh'},
#       {u'display_url': u'patreon.com/thelazygoldmak\u2026',
#        u'expanded_url': u'http://www.patreon.com/thelazygoldmaker',
#        u'indices': [78, 101],
#        u'url': u'https://t.co/zCPGzMSMys'}]},
#     u'url': {u'urls': [{u'display_url': u'thelazygoldmaker.com',
#        u'expanded_url': u'http://www.thelazygoldmaker.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/EQKNM83LzU'}]}},
#    u'favourites_count': 2447,
#    u'follow_request_sent': False,
#    u'followers_count': 2563,
#    u'following': True,
#    u'friends_count': 156,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 791766138539610116,
#    u'id_str': u'791766138539610116',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 24,
#    u'live_following': False,
#    u'location': u'',
#    u'muting': False,
#    u'name': u'The Lazy Goldmaker',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/791766138539610116/1508174879',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/919977513211891714/VsT9_hMp_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/919977513211891714/VsT9_hMp_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'lazygoldmaker',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 05:50:05 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1088675354376654848',
#        u'indices': [116, 139],
#        u'url': u'https://t.co/ixKOvWrkFL'}],
#      u'user_mentions': []},
#     u'favorite_count': 4,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088675354376654848,
#     u'id_str': u'1088675354376654848',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     u'text': u"This week has been very busy. I haven't even logged into the game since my stream on Monday. \n\nHopefully I can get\u2026 https://t.co/ixKOvWrkFL",
#     u'truncated': True},
#    u'statuses_count': 2031,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/EQKNM83LzU',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Thu Jul 12 16:29:43 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Twitch Partner, Founder and Co-owner @Methodgg | sco@method.gg for business inquiries',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'twitch.tv/sco',
#        u'expanded_url': u'http://www.twitch.tv/sco',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/J1UhuHpCGl'}]}},
#    u'favourites_count': 13540,
#    u'follow_request_sent': False,
#    u'followers_count': 67410,
#    u'following': True,
#    u'friends_count': 1359,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 633859328,
#    u'id_str': u'633859328',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 153,
#    u'live_following': False,
#    u'location': u'Scotland',
#    u'muting': False,
#    u'name': u'Scott McMillan',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/633859328/1546967921',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1001870222738051073/kXadVvBb_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1001870222738051073/kXadVvBb_normal.jpg',
#    u'profile_link_color': u'3B94D9',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'Methodsco',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 20:29:39 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'media': [{u'display_url': u'pic.twitter.com/aoruIldCRk',
#        u'expanded_url': u'https://twitter.com/Methodsco/status/1088896702696820736/photo/1',
#        u'id': 1088896630886146048,
#        u'id_str': u'1088896630886146048',
#        u'indices': [31, 54],
#        u'media_url': u'http://pbs.twimg.com/media/DxyJt3EWoAA10b5.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DxyJt3EWoAA10b5.jpg',
#        u'sizes': {u'large': {u'h': 1152, u'resize': u'fit', u'w': 2048},
#         u'medium': {u'h': 675, u'resize': u'fit', u'w': 1200},
#         u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/aoruIldCRk'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitch.tv/sco',
#        u'expanded_url': u'http://www.twitch.tv/sco',
#        u'indices': [7, 30],
#        u'url': u'https://t.co/miAtj5F7Tr'}],
#      u'user_mentions': []},
#     u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/aoruIldCRk',
#        u'expanded_url': u'https://twitter.com/Methodsco/status/1088896702696820736/photo/1',
#        u'id': 1088896630886146048,
#        u'id_str': u'1088896630886146048',
#        u'indices': [31, 54],
#        u'media_url': u'http://pbs.twimg.com/media/DxyJt3EWoAA10b5.jpg',
#        u'media_url_https': u'https://pbs.twimg.com/media/DxyJt3EWoAA10b5.jpg',
#        u'sizes': {u'large': {u'h': 1152, u'resize': u'fit', u'w': 2048},
#         u'medium': {u'h': 675, u'resize': u'fit', u'w': 1200},
#         u'small': {u'h': 383, u'resize': u'fit', u'w': 680},
#         u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#        u'type': u'photo',
#        u'url': u'https://t.co/aoruIldCRk'}]},
#     u'favorite_count': 23,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088896702696820736,
#     u'id_str': u'1088896702696820736',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'LIVE - https://t.co/miAtj5F7Tr https://t.co/aoruIldCRk',
#     u'truncated': False},
#    u'statuses_count': 13299,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/J1UhuHpCGl',
#    u'utc_offset': None,
#    u'verified': True},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Sat Jan 28 23:33:37 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'The official Twitter account of esports organization Method. #MethodWay   Business Inquires: management@method.gg',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'method.gg',
#        u'expanded_url': u'http://www.method.gg',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/irYoZKwx3I'}]}},
#    u'favourites_count': 11966,
#    u'follow_request_sent': False,
#    u'followers_count': 114474,
#    u'following': True,
#    u'friends_count': 829,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 477213534,
#    u'id_str': u'477213534',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 299,
#    u'live_following': False,
#    u'location': u'United Kingdom',
#    u'muting': False,
#    u'name': u'Method',
#    u'notifications': False,
#    u'profile_background_color': u'FFFFFF',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/477213534/1546892546',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/1005438934191656961/AOeHvdP7_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/1005438934191656961/AOeHvdP7_normal.jpg',
#    u'profile_link_color': u'FA743E',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'EFEFEF',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Methodgg',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 07:01:54 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 34955221,
#        u'id_str': u'34955221',
#        u'indices': [3, 13],
#        u'name': u'MSI Gaming',
#        u'screen_name': u'msitweets'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089055815527329792,
#     u'id_str': u'1089055815527329792',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 12,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Sat Jan 26 07:00:30 +0000 2019',
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1089055460659994624',
#         u'indices': [116, 139],
#         u'url': u'https://t.co/MyAYOLYjPC'}],
#       u'user_mentions': []},
#      u'favorite_count': 72,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1089055460659994624,
#      u'id_str': u'1089055460659994624',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': False,
#      u'lang': u'en',
#      u'place': None,
#      u'possibly_sensitive': False,
#      u'retweet_count': 12,
#      u'retweeted': False,
#      u'source': u'<a href="https://www.later.com" rel="nofollow">LaterMedia</a>',
#      u'text': u'MSI has launched its brand new gaming laptop lineups, equipped with NVDIA\xae GeForce RTX\u2122 20 series graphics at CES.\u2026 https://t.co/MyAYOLYjPC',
#      u'truncated': True},
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'RT @msitweets: MSI has launched its brand new gaming laptop lineups, equipped with NVDIA\xae GeForce RTX\u2122 20 series graphics at CES. With all\u2026',
#     u'truncated': False},
#    u'statuses_count': 12014,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/irYoZKwx3I',
#    u'utc_offset': None,
#    u'verified': True},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Sat Sep 13 16:56:32 +0000 2008',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"Python, software, typography, juggling, Boston, sometimes autism. Laughing at the world doesn't mean I don't take it seriously. He/him.",
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'nedbatchelder.com',
#        u'expanded_url': u'http://nedbatchelder.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/j9QcJdtRnb'}]}},
#    u'favourites_count': 361,
#    u'follow_request_sent': False,
#    u'followers_count': 8408,
#    u'following': True,
#    u'friends_count': 135,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 16273417,
#    u'id_str': u'16273417',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 398,
#    u'live_following': False,
#    u'location': u'Boston',
#    u'muting': False,
#    u'name': u'Ned Batchelder',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/16273417/1404474153',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/60300066/face-jr-square_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/60300066/face-jr-square_normal.jpg',
#    u'profile_link_color': u'1B95E0',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'nedbat',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 10:47:16 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 830468488967843840,
#        u'id_str': u'830468488967843840',
#        u'indices': [3, 18],
#        u'name': u'clean slate',
#        u'screen_name': u'PleaseBeGneiss'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089112528091824129,
#     u'id_str': u'1089112528091824129',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 1296,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Thu Jan 24 22:03:04 +0000 2019',
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1088557826211864576',
#         u'indices': [117, 140],
#         u'url': u'https://t.co/ZvKjxQlP4s'}],
#       u'user_mentions': []},
#      u'favorite_count': 5642,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1088557826211864576,
#      u'id_str': u'1088557826211864576',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': False,
#      u'lang': u'en',
#      u'place': None,
#      u'retweet_count': 1296,
#      u'retweeted': False,
#      u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      u'text': u'Stranger asks you what time it is = kinda annoying\n\nStranger asks you what year it is = pretty concerning \n\nStrange\u2026 https://t.co/ZvKjxQlP4s',
#      u'truncated': True},
#     u'source': u'<a href="https://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>',
#     u'text': u'RT @PleaseBeGneiss: Stranger asks you what time it is = kinda annoying\n\nStranger asks you what year it is = pretty concerning \n\nStranger as\u2026',
#     u'truncated': False},
#    u'statuses_count': 6592,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'http://t.co/j9QcJdtRnb',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Fri Oct 26 03:48:53 +0000 2007',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'software engineer, app entrepreneur, photographer, traveler, tech lead. \u2615\ufe0f \U0001f36a',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'youtube.com/techlead',
#        u'expanded_url': u'http://youtube.com/techlead',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/WaIRbhQ6Nz'}]}},
#    u'favourites_count': 322,
#    u'follow_request_sent': False,
#    u'followers_count': 6658,
#    u'following': True,
#    u'friends_count': 11,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 9701462,
#    u'id_str': u'9701462',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 36,
#    u'live_following': False,
#    u'location': u'Bay Area, CA',
#    u'muting': False,
#    u'name': u'Patrick Shyu',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/9701462/1518050553',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/965076243728105472/lqBFQwo6_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/965076243728105472/lqBFQwo6_normal.jpg',
#    u'profile_link_color': u'0088AA',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'PatrickShyu',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 19:07:56 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 2212731194,
#        u'id_str': u'2212731194',
#        u'indices': [0, 7],
#        u'name': u'\u0287\u0287\u0131\u028d u\u0250\u026f\u0287l\u0250 uos\u0131\u0279\u0279\u0250\u0265',
#        u'screen_name': u'hwitt2'}]},
#     u'favorite_count': 10,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088876137344712704,
#     u'id_str': u'1088876137344712704',
#     u'in_reply_to_screen_name': u'hwitt2',
#     u'in_reply_to_status_id': 1088874910091526146,
#     u'in_reply_to_status_id_str': u'1088874910091526146',
#     u'in_reply_to_user_id': 2212731194,
#     u'in_reply_to_user_id_str': u'2212731194',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"@hwitt2 My weakness is that I have no weaknesses.  I'm too perfect.",
#     u'truncated': False},
#    u'statuses_count': 509,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/WaIRbhQ6Nz',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Tue Apr 27 20:14:05 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"I draw sometimes. Freelance Illustrator. I also like that #CriticalRole show. If you're at all interested in buying some prints, check my pinned tweet!",
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'artstation.com/artist/idrawba\u2026',
#        u'expanded_url': u'https://www.artstation.com/artist/idrawbagman',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/m1YSQnciNs'}]}},
#    u'favourites_count': 9295,
#    u'follow_request_sent': False,
#    u'followers_count': 9766,
#    u'following': True,
#    u'friends_count': 281,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 137799737,
#    u'id_str': u'137799737',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 85,
#    u'live_following': False,
#    u'location': u'United States',
#    u'muting': False,
#    u'name': u'Kent Davis',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/137799737/1548137264',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/947722814076932096/lae0XAEr_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/947722814076932096/lae0XAEr_normal.jpg',
#    u'profile_link_color': u'3B94D9',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'iDrawBagman',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Sat Jan 26 04:43:48 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 206696421,
#        u'id_str': u'206696421',
#        u'indices': [0, 14],
#        u'name': u'Matt Buttacavoli',
#        u'screen_name': u'deathmatt2002'},
#       {u'id': 24630350,
#        u'id_str': u'24630350',
#        u'indices': [15, 29],
#        u'name': u'Matthew Mercer',
#        u'screen_name': u'matthewmercer'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1089021060983472128,
#     u'id_str': u'1089021060983472128',
#     u'in_reply_to_screen_name': u'deathmatt2002',
#     u'in_reply_to_status_id': 1089013371607801856,
#     u'in_reply_to_status_id_str': u'1089013371607801856',
#     u'in_reply_to_user_id': 206696421,
#     u'in_reply_to_user_id_str': u'206696421',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     u'text': u'@deathmatt2002 @matthewmercer I wouldn\u2019t even be mad tbh',
#     u'truncated': False},
#    u'statuses_count': 1747,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/m1YSQnciNs',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Sat Dec 27 17:12:00 +0000 2014',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'student @ stanford | makes art & games | swe intern @NianticLabs, prev @zynga | https://t.co/lR6Gz3OY2o | https://t.co/pWI1s8sd0W',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'ko-fi.com/J3J6DIQC',
#        u'expanded_url': u'https://ko-fi.com/J3J6DIQC',
#        u'indices': [80, 103],
#        u'url': u'https://t.co/lR6Gz3OY2o'},
#       {u'display_url': u'society6.com/zephyo',
#        u'expanded_url': u'https://society6.com/zephyo',
#        u'indices': [106, 129],
#        u'url': u'https://t.co/pWI1s8sd0W'}]},
#     u'url': {u'urls': [{u'display_url': u'zephyo.github.io',
#        u'expanded_url': u'https://zephyo.github.io',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/GBiVkpJp5g'}]}},
#    u'favourites_count': 1156,
#    u'follow_request_sent': False,
#    u'followers_count': 11261,
#    u'following': True,
#    u'friends_count': 124,
#    u'geo_enabled': False,
#    u'has_extended_profile': False,
#    u'id': 2944066131,
#    u'id_str': u'2944066131',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 102,
#    u'live_following': False,
#    u'location': u'sleeping',
#    u'muting': False,
#    u'name': u'angela he',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2944066131/1505032713',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/979423607796334593/pTpjJ2LM_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/979423607796334593/pTpjJ2LM_normal.jpg',
#    u'profile_link_color': u'FA743E',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'zephybite',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Thu Jan 24 21:29:00 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1088549252869963776',
#        u'indices': [113, 136],
#        u'url': u'https://t.co/qJMBejIWuh'}],
#      u'user_mentions': [{u'id': 81200968,
#        u'id_str': u'81200968',
#        u'indices': [0, 15],
#        u'name': u'Lucy Blundell',
#        u'screen_name': u'GamesByKinmoku'},
#       {u'id': 3259113656,
#        u'id_str': u'3259113656',
#        u'indices': [16, 27],
#        u'name': u'Bri-Cade \U0001f33b',
#        u'screen_name': u'TheBriCade'},
#       {u'id': 265593408,
#        u'id_str': u'265593408',
#        u'indices': [28, 37],
#        u'name': u'Brie Code',
#        u'screen_name': u'briecode'},
#       {u'id': 19118110,
#        u'id_str': u'19118110',
#        u'indices': [38, 52],
#        u'name': u'Lauren Clare',
#        u'screen_name': u'IndigoWolfiee'},
#       {u'id': 26759295,
#        u'id_str': u'26759295',
#        u'indices': [53, 59],
#        u'name': u'Lydia',
#        u'screen_name': u'lkmad'},
#       {u'id': 1485309631,
#        u'id_str': u'1485309631',
#        u'indices': [60, 69],
#        u'name': u'Nina Kiel',
#        u'screen_name': u'Beurkeek'},
#       {u'id': 14379485,
#        u'id_str': u'14379485',
#        u'indices': [70, 86],
#        u'name': u'Carolyn Petit',
#        u'screen_name': u'carolynmichelle'},
#       {u'id': 65356121,
#        u'id_str': u'65356121',
#        u'indices': [87, 101],
#        u'name': u'Keza MacDonald',
#        u'screen_name': u'kezamacdonald'},
#       {u'id': 1191116311,
#        u'id_str': u'1191116311',
#        u'indices': [102, 111],
#        u'name': u'leighton gray',
#        u'screen_name': u'graylish'}]},
#     u'favorite_count': 3,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088549252869963776,
#     u'id_str': u'1088549252869963776',
#     u'in_reply_to_screen_name': u'GamesByKinmoku',
#     u'in_reply_to_status_id': 1088374886853234690,
#     u'in_reply_to_status_id_str': u'1088374886853234690',
#     u'in_reply_to_user_id': 81200968,
#     u'in_reply_to_user_id_str': u'81200968',
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'@GamesByKinmoku @TheBriCade @briecode @IndigoWolfiee @lkmad @Beurkeek @carolynmichelle @kezamacdonald @graylish\u2026 https://t.co/qJMBejIWuh',
#     u'truncated': True},
#    u'statuses_count': 695,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/GBiVkpJp5g',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Wed Aug 17 22:14:13 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"17yo Machine Learning Engineer // Kaggle Top 50, tech enthusiast, BTC trader and gamer. When I'm not doing homework I'm building servers or playing overwatch.",
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'mxbi.net',
#        u'expanded_url': u'http://mxbi.net',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/auc3Do7wAM'}]}},
#    u'favourites_count': 1887,
#    u'follow_request_sent': False,
#    u'followers_count': 4593,
#    u'following': True,
#    u'friends_count': 458,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 357134227,
#    u'id_str': u'357134227',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 89,
#    u'live_following': False,
#    u'location': u'Guildford, England',
#    u'muting': False,
#    u'name': u'Mikel Bober-Irizar',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/357134227/1429730506',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/835951192207339521/ZSO1KktW_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/835951192207339521/ZSO1KktW_normal.jpg',
#    u'profile_link_color': u'FF691F',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'mikb0b',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 06:48:41 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 892732157294030848,
#        u'id_str': u'892732157294030848',
#        u'indices': [0, 10],
#        u'name': u'tkasasagi',
#        u'screen_name': u'tkasasagi'}]},
#     u'favorite_count': 1,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088690099330711552,
#     u'id_str': u'1088690099330711552',
#     u'in_reply_to_screen_name': u'tkasasagi',
#     u'in_reply_to_status_id': 1088687539798474753,
#     u'in_reply_to_status_id_str': u'1088687539798474753',
#     u'in_reply_to_user_id': 892732157294030848,
#     u'in_reply_to_user_id_str': u'892732157294030848',
#     u'is_quote_status': False,
#     u'lang': u'und',
#     u'place': None,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     u'text': u'@tkasasagi \U0001f625',
#     u'truncated': False},
#    u'statuses_count': 576,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/auc3Do7wAM',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Tue Feb 26 07:50:26 +0000 2013',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Chief Creative Officer at @SecondDinner.\nPreviously Hearthstone Game Director @ Blizzard.',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 11757,
#    u'follow_request_sent': False,
#    u'followers_count': 168051,
#    u'following': True,
#    u'friends_count': 133,
#    u'geo_enabled': True,
#    u'has_extended_profile': False,
#    u'id': 1220791675,
#    u'id_str': u'1220791675',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 997,
#    u'live_following': False,
#    u'location': u'Orange County, CA',
#    u'muting': False,
#    u'name': u'Ben Brode',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1220791675/1534355423',
# ...
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': True,
#     u'lang': u'en',
#     u'place': None,
#     u'quoted_status_id': 1087743023100903426,
#     u'quoted_status_id_str': u'1087743023100903426',
#     u'retweet_count': 1,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Tue Jan 22 21:16:15 +0000 2019',
#      u'entities': {u'hashtags': [{u'indices': [39, 45], u'text': u'Chess'},
#        {u'indices': [52, 55], u'text': u'Go'},
#        {u'indices': [105, 115], u'text': u'StarCraft'}],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1087821268785786880',
#         u'indices': [117, 140],
#         u'url': u'https://t.co/tVxMcB4Mq2'}],
#       u'user_mentions': []},
#      u'favorite_count': 2,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1087821268785786880,
#      u'id_str': u'1087821268785786880',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': True,
#      u'lang': u'en',
#      u'place': {u'attributes': {},
#       u'bounding_box': {u'coordinates': [[[-95.823268, 29.522325],
#          [-95.069705, 29.522325],
#          [-95.069705, 30.1546646],
#          [-95.823268, 30.1546646]]],
#        u'type': u'Polygon'},
#       u'contained_within': [],
#       u'country': u'United States',
#       u'country_code': u'US',
#       u'full_name': u'Houston, TX',
#       u'id': u'1c69a67ad480e1b1',
#       u'name': u'Houston',
#       u'place_type': u'city',
#       u'url': u'https://api.twitter.com/1.1/geo/id/1c69a67ad480e1b1.json'},
#      u'possibly_sensitive': False,
#      u'quoted_status_id': 1087743023100903426,
#      u'quoted_status_id_str': u'1087743023100903426',
#      u'retweet_count': 1,
#      u'retweeted': False,
#      u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      u'text': u"Deep mind has conquered the boardgames #Chess \u265f and #Go \u26ab, and this year we'll see how well it does with #StarCraft\u2026 https://t.co/tVxMcB4Mq2",
#      u'truncated': True},
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u"RT @matthewipena: Deep mind has conquered the boardgames #Chess \u265f and #Go \u26ab, and this year we'll see how well it does with #StarCraft, argu\u2026",
#     u'truncated': False},
#    u'statuses_count': 1168,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/uozkmTFGmx',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Fri Mar 13 00:30:37 +0000 2009',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'tomaugspurger.github.io',
#        u'expanded_url': u'http://tomaugspurger.github.io',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/ddRckhr6n0'}]}},
#    u'favourites_count': 1739,
#    u'follow_request_sent': False,
#    u'followers_count': 3714,
#    u'following': True,
#    u'friends_count': 169,
#    u'geo_enabled': False,
#    u'has_extended_profile': True,
#    u'id': 24083751,
#    u'id_str': u'24083751',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 148,
#    u'live_following': False,
#    u'location': u'Des Moines, IA',
#    u'muting': False,
#    u'name': u'Tom Augspurger',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/24083751/1433991225',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/765552958368993283/-75PE-fq_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/765552958368993283/-75PE-fq_normal.jpg',
#    u'profile_link_color': u'3B94D9',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'TomAugspurger',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 22:33:59 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [],
#      u'user_mentions': [{u'id': 2885608548,
#        u'id_str': u'2885608548',
#        u'indices': [3, 15],
#        u'name': u'Joe Hamman',
#        u'screen_name': u'HammanHydro'},
#       {u'id': 1038181464431423488,
#        u'id_str': u'1038181464431423488',
#        u'indices': [74, 85],
#        u'name': u'@xarray_dev',
#        u'screen_name': u'xarray_dev'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088927993848832000,
#     u'id_str': u'1088927993848832000',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'retweet_count': 13,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Fri Jan 25 17:12:24 +0000 2019',
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1088847065973542912',
#         u'indices': [117, 140],
#         u'url': u'https://t.co/fENeilWF0U'}],
#       u'user_mentions': [{u'id': 1038181464431423488,
#         u'id_str': u'1038181464431423488',
#         u'indices': [57, 68],
#         u'name': u'@xarray_dev',
#         u'screen_name': u'xarray_dev'}]},
#      u'favorite_count': 64,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1088847065973542912,
#      u'id_str': u'1088847065973542912',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': False,
#      u'lang': u'en',
#      u'place': None,
#      u'possibly_sensitive': False,
#      u'retweet_count': 13,
#      u'retweeted': False,
#      u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#      u'text': u'We just removed the remaining Python2 compatibility from @xarray_dev. Good to be done with all those nasty py2/3 ha\u2026 https://t.co/fENeilWF0U',
#      u'truncated': True},
#     u'source': u'<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for i\u039fS</a>',
#     u'text': u'RT @HammanHydro: We just removed the remaining Python2 compatibility from @xarray_dev. Good to be done with all those nasty py2/3 hacks :)\u2026',
#     u'truncated': False},
#    u'statuses_count': 2057,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/ddRckhr6n0',
#    u'utc_offset': None,
#    u'verified': False},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Thu Feb 18 21:01:15 +0000 2010',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'Director of OSS not-for-profit https://t.co/YVn0VFqgj0 focused on @ApacheArrow. Created pandas, @IbisData. @ApacheParquet PMC. Wrote Python for Data Analysis.',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'ursalabs.org',
#        u'expanded_url': u'https://ursalabs.org/',
#        u'indices': [31, 54],
#        u'url': u'https://t.co/YVn0VFqgj0'}]},
#     u'url': {u'urls': [{u'display_url': u'wesmckinney.com',
#        u'expanded_url': u'http://wesmckinney.com',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/qJQDLJwSjr'}]}},
#    u'favourites_count': 3286,
#    u'follow_request_sent': False,
#    u'followers_count': 40780,
#    u'following': True,
#    u'friends_count': 813,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 115494880,
#    u'id_str': u'115494880',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 1405,
#    u'live_following': False,
#    u'location': u'Nashville, TN',
#    u'muting': False,
#    u'name': u'Wes McKinney',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/115494880/1469019836',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/819655749240553478/GSLUqOf9_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/819655749240553478/GSLUqOf9_normal.jpg',
#    u'profile_link_color': u'1DA1F2',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'wesmckinn',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jan 25 21:27:42 +0000 2019',
#     u'entities': {u'hashtags': [],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'pandas.pydata.org/pandas-docs/st\u2026',
#        u'expanded_url': u'http://pandas.pydata.org/pandas-docs/stable/whatsnew/v0.24.0.html#',
#        u'indices': [42, 65],
#        u'url': u'https://t.co/Vw7cxxaS8S'}],
#      u'user_mentions': [{u'id': 1015706109255053317,
#        u'id_str': u'1015706109255053317',
#        u'indices': [3, 14],
#        u'name': u'pandas_dev',
#        u'screen_name': u'pandas_dev'}]},
#     u'favorite_count': 0,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1088911311461851136,
#     u'id_str': u'1088911311461851136',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 61,
#     u'retweeted': False,
#     u'retweeted_status': {u'contributors': None,
#      u'coordinates': None,
#      u'created_at': u'Fri Jan 25 21:25:53 +0000 2019',
#      u'entities': {u'hashtags': [],
#       u'symbols': [],
#       u'urls': [{u'display_url': u'pandas.pydata.org/pandas-docs/st\u2026',
#         u'expanded_url': u'http://pandas.pydata.org/pandas-docs/stable/whatsnew/v0.24.0.html#',
#         u'indices': [26, 49],
#         u'url': u'https://t.co/Vw7cxxaS8S'},
#        {u'display_url': u'twitter.com/i/web/status/1\u2026',
#         u'expanded_url': u'https://twitter.com/i/web/status/1088910854462988288',
#         u'indices': [117, 140],
#         u'url': u'https://t.co/C0IRc8LWhg'}],
#       u'user_mentions': []},
#      u'favorite_count': 132,
#      u'favorited': False,
#      u'geo': None,
#      u'id': 1088910854462988288,
#      u'id_str': u'1088910854462988288',
#      u'in_reply_to_screen_name': None,
#      u'in_reply_to_status_id': None,
#      u'in_reply_to_status_id_str': None,
#      u'in_reply_to_user_id': None,
#      u'in_reply_to_user_id_str': None,
#      u'is_quote_status': False,
#      u'lang': u'en',
#      u'place': None,
#      u'possibly_sensitive': False,
#      u'retweet_count': 61,
#      u'retweeted': False,
#      u'source': u'<a href="https://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>',
#      u'text': u'Pandas 0.24.0 is now out! https://t.co/Vw7cxxaS8S\n\nRead the blog post introducing the pandas extension array interf\u2026 https://t.co/C0IRc8LWhg',
#      u'truncated': True},
#     u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     u'text': u'RT @pandas_dev: Pandas 0.24.0 is now out! https://t.co/Vw7cxxaS8S\n\nRead the blog post introducing the pandas extension array interface: htt\u2026',
#     u'truncated': False},
#    u'statuses_count': 8370,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/qJQDLJwSjr',
#    u'utc_offset': None,
#    u'verified': True},
#   {u'blocked_by': False,
#    u'blocking': False,
#    u'contributors_enabled': False,
#    u'created_at': u'Wed Dec 07 20:28:17 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Follow @AmazonNews for everything you want to know about Amazon!',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'amazon.jobs',
#        u'expanded_url': u'http://www.amazon.jobs',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/MfFK6mNrfI'}]}},
#    u'favourites_count': 512,
#    u'follow_request_sent': False,
#    u'followers_count': 13838,
#    u'following': True,
#    u'friends_count': 159,
#    u'geo_enabled': True,
#    u'has_extended_profile': True,
#    u'id': 431010071,
#    u'id_str': u'431010071',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 193,
#    u'live_following': False,
#    u'location': u'Seattle, Washington',
#    u'muting': False,
#    u'name': u'Inside Amazon',
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/431010071/1528761034',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/907358276257329152/r6PXihs8_normal.jpg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/907358276257329152/r6PXihs8_normal.jpg',
#    u'profile_link_color': u'ABB8C2',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'000000',
#    u'profile_text_color': u'000000',
#    u'profile_use_background_image': False,
#    u'protected': True,
#    u'screen_name': u'InsideAmazon',
#    u'status': {u'contributors': None,
#     u'coordinates': None,
#     u'created_at': u'Fri Jul 06 00:00:00 +0000 2018',
#     u'entities': {u'hashtags': [{u'indices': [72, 88],
#        u'text': u'MachineLearning'}],
#      u'symbols': [],
#      u'urls': [{u'display_url': u'twitter.com/i/web/status/1\u2026',
#        u'expanded_url': u'https://twitter.com/i/web/status/1015022516354600962',
#        u'indices': [117, 140],
#        u'url': u'https://t.co/WwJJkEkjoA'}],
#      u'user_mentions': [{u'id': 20793816,
#        u'id_str': u'20793816',
#        u'indices': [5, 12],
#        u'name': u'Amazon.com',
#        u'screen_name': u'amazon'}]},
#     u'favorite_count': 11,
#     u'favorited': False,
#     u'geo': None,
#     u'id': 1015022516354600962,
#     u'id_str': u'1015022516354600962',
#     u'in_reply_to_screen_name': None,
#     u'in_reply_to_status_id': None,
#     u'in_reply_to_status_id_str': None,
#     u'in_reply_to_user_id': None,
#     u'in_reply_to_user_id_str': None,
#     u'is_quote_status': False,
#     u'lang': u'en',
#     u'place': None,
#     u'possibly_sensitive': False,
#     u'retweet_count': 0,
#     u'retweeted': False,
#     u'source': u'<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     u'text': u'2018 @amazon Research Awards will go to academic researchers focused on #MachineLearning. Submission deadline is Se\u2026 https://t.co/WwJJkEkjoA',
#     u'truncated': True},
#    u'statuses_count': 10128,
#    u'time_zone': None,
#    u'translator_type': u'none',
#    u'url': u'https://t.co/MfFK6mNrfI',
#    u'utc_offset': None,
#    u'verified': True}]}

# %%
# And let's see only friends' name
for num, friends in enumerate(friends['users']):
    print 'My friend #{0}\t{1}'.format(num+1, friends['name'].encode("utf-8"))
# Out:
# My friend #1	AI Memes for Artificially Intelligent Teens
# My friend #2	John Papa
# My friend #3	Twitter
# My friend #4	Rasmus Bååth
# My friend #5	The Lazy Goldmaker
# My friend #6	Scott McMillan
# My friend #7	Method
# My friend #8	Ned Batchelder
# My friend #9	Patrick Shyu
# My friend #10	Kent Davis
# My friend #11	angela he
# My friend #12	Mikel Bober-Irizar
# My friend #13	Ben Brode
# My friend #14	+380991741601
# My friend #15	WACKO
# My friend #16	Andrej Karpathy
# My friend #17	Chad Gardner
# My friend #18	Tom Augspurger
# My friend #19	Wes McKinney
# My friend #20	Inside Amazon

# %% [markdown]
# ### 1.4:  Finding what are in the trend somewhere
#
# We can return the top 50 trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, London has a `WOEID` of 44418. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in London

# %%
url_4 = 'https://api.twitter.com/1.1/trends/place.json?id=44418'
res = requests.get(url_4, auth=auth)

print res, res.status_code, res.headers['content-type']
print res.url

top50_trends = res.json()
top50_trends
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/trends/place.json?id=44418
# [{u'as_of': u'2019-01-26T10:56:44Z',
#   u'created_at': u'2019-01-26T10:51:50Z',
#   u'locations': [{u'name': u'London', u'woeid': 44418}],
#   u'trends': [{u'name': u'#Caturday',
#     u'promoted_content': None,
#     u'query': u'%23Caturday',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23Caturday'},
#    {u'name': u'Osaka',
#     u'promoted_content': None,
#     u'query': u'Osaka',
#     u'tweet_volume': 70775,
#     u'url': u'http://twitter.com/search?q=Osaka'},
#    {u'name': u'#SaturdayMorning',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayMorning',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SaturdayMorning'},
#    {u'name': u'#AustraliaDay',
#     u'promoted_content': None,
#     u'query': u'%23AustraliaDay',
#     u'tweet_volume': 20529,
#     u'url': u'http://twitter.com/search?q=%23AustraliaDay'},
#    {u'name': u'Kvitova',
#     u'promoted_content': None,
#     u'query': u'Kvitova',
#     u'tweet_volume': 22267,
#     u'url': u'http://twitter.com/search?q=Kvitova'},
#    {u'name': u'#BigGardenBirdWatch',
#     u'promoted_content': None,
#     u'query': u'%23BigGardenBirdWatch',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BigGardenBirdWatch'},
#    {u'name': u'#SaturdayMotivation',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayMotivation',
#     u'tweet_volume': 13348,
#     u'url': u'http://twitter.com/search?q=%23SaturdayMotivation'},
#    {u'name': u'GAME DAY',
#     u'promoted_content': None,
#     u'query': u'%22GAME+DAY%22',
#     u'tweet_volume': 12680,
#     u'url': u'http://twitter.com/search?q=%22GAME+DAY%22'},
#    {u'name': u'Soccer AM',
#     u'promoted_content': None,
#     u'query': u'%22Soccer+AM%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Soccer+AM%22'},
#    {u'name': u'Michel Legrand',
#     u'promoted_content': None,
#     u'query': u'%22Michel+Legrand%22',
#     u'tweet_volume': 17361,
#     u'url': u'http://twitter.com/search?q=%22Michel+Legrand%22'},
#    {u'name': u'Match Day',
#     u'promoted_content': None,
#     u'query': u'%22Match+Day%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Match+Day%22'},
#    {u'name': u'Petra',
#     u'promoted_content': None,
#     u'query': u'Petra',
#     u'tweet_volume': 20402,
#     u'url': u'http://twitter.com/search?q=Petra'},
#    {u'name': u'Naomi',
#     u'promoted_content': None,
#     u'query': u'Naomi',
#     u'tweet_volume': 48618,
#     u'url': u'http://twitter.com/search?q=Naomi'},
#    {u'name': u'Melania Trump',
#     u'promoted_content': None,
#     u'query': u'%22Melania+Trump%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Melania+Trump%22'},
#    {u'name': u'John Humphrys',
#     u'promoted_content': None,
#     u'query': u'%22John+Humphrys%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22John+Humphrys%22'},
#    {u'name': u"IT'S MATCHDAY",
#     u'promoted_content': None,
#     u'query': u'%22IT%27S+MATCHDAY%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22IT%27S+MATCHDAY%22'},
#    {u'name': u'debbie mcgee',
#     u'promoted_content': None,
#     u'query': u'%22debbie+mcgee%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22debbie+mcgee%22'},
#    {u'name': u'2nd XV',
#     u'promoted_content': None,
#     u'query': u'%222nd+XV%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%222nd+XV%22'},
#    {u'name': u'Happy Australia',
#     u'promoted_content': None,
#     u'query': u'%22Happy+Australia%22',
#     u'tweet_volume': 18513,
#     u'url': u'http://twitter.com/search?q=%22Happy+Australia%22'},
#    {u'name': u'Down Under',
#     u'promoted_content': None,
#     u'query': u'%22Down+Under%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Down+Under%22'},
#    {u'name': u'Bomber Command Memorial',
#     u'promoted_content': None,
#     u'query': u'%22Bomber+Command+Memorial%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Bomber+Command+Memorial%22'},
#    {u'name': u'Fratton Park',
#     u'promoted_content': None,
#     u'query': u'%22Fratton+Park%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Fratton+Park%22'},
#    {u'name': u'Trevor Francis',
#     u'promoted_content': None,
#     u'query': u'%22Trevor+Francis%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Trevor+Francis%22'},
#    {u'name': u'The Specials',
#     u'promoted_content': None,
#     u'query': u'%22The+Specials%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22The+Specials%22'},
#    {u'name': u'Millwall v Everton',
#     u'promoted_content': None,
#     u'query': u'%22Millwall+v+Everton%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Millwall+v+Everton%22'},
#    {u'name': u'Division 1',
#     u'promoted_content': None,
#     u'query': u'%22Division+1%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Division+1%22'},
#    {u'name': u'Marina Hyde',
#     u'promoted_content': None,
#     u'query': u'%22Marina+Hyde%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Marina+Hyde%22'},
#    {u'name': u'#saturdaykitchen',
#     u'promoted_content': None,
#     u'query': u'%23saturdaykitchen',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23saturdaykitchen'},
#    {u'name': u'#WonderYears',
#     u'promoted_content': None,
#     u'query': u'%23WonderYears',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23WonderYears'},
#    {u'name': u'#UKGiftAM',
#     u'promoted_content': None,
#     u'query': u'%23UKGiftAM',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23UKGiftAM'},
#    {u'name': u'#UKGiftHour',
#     u'promoted_content': None,
#     u'query': u'%23UKGiftHour',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23UKGiftHour'},
#    {u'name': u'#socceram',
#     u'promoted_content': None,
#     u'query': u'%23socceram',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23socceram'},
#    {u'name': u'#AusOpenFinal',
#     u'promoted_content': None,
#     u'query': u'%23AusOpenFinal',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23AusOpenFinal'},
#    {u'name': u'#SaturdayThoughts',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayThoughts',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SaturdayThoughts'},
#    {u'name': u'#StrictlyRE',
#     u'promoted_content': None,
#     u'query': u'%23StrictlyRE',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23StrictlyRE'},
#    {u'name': u'#BBCSaturdayLive',
#     u'promoted_content': None,
#     u'query': u'%23BBCSaturdayLive',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BBCSaturdayLive'},
#    {u'name': u'#LoveYourselfinSeoulFilm',
#     u'promoted_content': None,
#     u'query': u'%23LoveYourselfinSeoulFilm',
#     u'tweet_volume': 135536,
#     u'url': u'http://twitter.com/search?q=%23LoveYourselfinSeoulFilm'},
#    {u'name': u'#ITVRacing',
#     u'promoted_content': None,
#     u'query': u'%23ITVRacing',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23ITVRacing'},
#    {u'name': u'#GameDay',
#     u'promoted_content': None,
#     u'query': u'%23GameDay',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23GameDay'},
#    {u'name': u'#RepublicDay2019',
#     u'promoted_content': None,
#     u'query': u'%23RepublicDay2019',
#     u'tweet_volume': 173850,
#     u'url': u'http://twitter.com/search?q=%23RepublicDay2019'},
#    {u'name': u'#MakeAShowOrMovieCold',
#     u'promoted_content': None,
#     u'query': u'%23MakeAShowOrMovieCold',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23MakeAShowOrMovieCold'},
#    {u'name': u'#PORQPR',
#     u'promoted_content': None,
#     u'query': u'%23PORQPR',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23PORQPR'},
#    {u'name': u'#NationalStorytellingWeek',
#     u'promoted_content': None,
#     u'query': u'%23NationalStorytellingWeek',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23NationalStorytellingWeek'},
#    {u'name': u'#WeekendWisdom',
#     u'promoted_content': None,
#     u'query': u'%23WeekendWisdom',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23WeekendWisdom'},
#    {u'name': u'#RepublicDayIndia',
#     u'promoted_content': None,
#     u'query': u'%23RepublicDayIndia',
#     u'tweet_volume': 72010,
#     u'url': u'http://twitter.com/search?q=%23RepublicDayIndia'},
#    {u'name': u'#bttr',
#     u'promoted_content': None,
#     u'query': u'%23bttr',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23bttr'},
#    {u'name': u'#TrumpCaved',
#     u'promoted_content': None,
#     u'query': u'%23TrumpCaved',
#     u'tweet_volume': 191360,
#     u'url': u'http://twitter.com/search?q=%23TrumpCaved'},
#    {u'name': u'#JDWelshCup',
#     u'promoted_content': None,
#     u'query': u'%23JDWelshCup',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23JDWelshCup'},
#    {u'name': u'#PPA2019',
#     u'promoted_content': None,
#     u'query': u'%23PPA2019',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23PPA2019'},
#    {u'name': u'#D365SatSco',
#     u'promoted_content': None,
#     u'query': u'%23D365SatSco',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23D365SatSco'}]}]

# %%
# And let's see only the first 10 trends names and the respective URL
for i, trend in enumerate(top50_trends[0]['trends'][:10]):
    print '{0} - {1} - URL: {2}'.format(i+1, trend['name'], trend['url'])
# Out:
# 1 - #Caturday - URL: http://twitter.com/search?q=%23Caturday
# 2 - Osaka - URL: http://twitter.com/search?q=Osaka
# 3 - #SaturdayMorning - URL: http://twitter.com/search?q=%23SaturdayMorning
# 4 - #AustraliaDay - URL: http://twitter.com/search?q=%23AustraliaDay
# 5 - Kvitova - URL: http://twitter.com/search?q=Kvitova
# 6 - #BigGardenBirdWatch - URL: http://twitter.com/search?q=%23BigGardenBirdWatch
# 7 - #SaturdayMotivation - URL: http://twitter.com/search?q=%23SaturdayMotivation
# 8 - GAME DAY - URL: http://twitter.com/search?q=%22GAME+DAY%22
# 9 - Soccer AM - URL: http://twitter.com/search?q=%22Soccer+AM%22
# 10 - Michel Legrand - URL: http://twitter.com/search?q=%22Michel+Legrand%22

# %% [markdown]
# ### 1.5: Streaming
#
# Twitter offers a [Streaming API](https://dev.twitter.com/streaming/overview) to make it easier to query streams of tweets.  The Stream API encapsulates some pain points of REST access to ensure that Stream calls don't exceed the rate limit. These tool allows to get tweet data when it appears in real time. There are three stream types:
#
# - `Public Streams:` Streams of public data flowthing through Twitter. Suitable for followign specific users, topics or for data mining.
# - `User Streams:` Single-user streams. Containing roughly all of the data corresponding with a single user's view of Twitter.
# - `Site Streams:` The multi-user version of user streams.
#
# >Connecting to the streaming API requires keeping a persistent HTTP connection open. In many cases this involves thinking about your application differently than if you were interacting with the REST API. An app which connects to the Streaming APIs will not be able to establish a connection in response to a user request. Instead, the code for maintaining the Streaming connection is typically run in a process separate from the process which handles HTTP requests. The streaming process gets the input tweets and performs any parsing, filtering, and/or aggregation needed before storing the result to a data store. The HTTP handling process queries the data store for results in response to user requests. While this model is more complex than the first example, the benefits from having a realtime stream of tweet data make the integration worthwhile for many types of apps.
#
# With `requests.Response.iter_lines()` you can easily iterate over streaming APIs including the **Twitter Streaming API**. Simply set `stream` parameter to `True` and iterate over the response with `iter_lines()`.
#
# Depending on the search term/terms, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#android_ hashtag:

# %%
#This cell doesn't have limits and doesn't stop automatically. You need to interrupt it by yourself.
import time

url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=android'
res = requests.get(url_5, auth=auth, stream=True)

print res, res.status_code, res.headers['content-type']
print res.url, "\n"

# Let's measure the time elapsed after the start of streaming 
start = time.time()
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line)
        print "Elapsed:", time.time()-start, "sec", parsed_line["created_at"], "\n", parsed_line['text'].encode("utf-8"), "\n"
# Out:
# <Response [200]> 200 application/json
# https://stream.twitter.com/1.1/statuses/filter.json?track=android
#
# Elapsed: 0.870567083359 sec Fri Jan 25 16:27:35 +0000 2019
# Orion Labs Inc. Redesigns Its Push-to-Talk App on Android https://t.co/TDRQT8jEXc #news https://t.co/b4jBWRqJSU
#
# Elapsed: 1.0116751194 sec Fri Jan 25 16:27:35 +0000 2019
# モイ！Androidからキャス配信中 - https://t.co/KA8WUlstql
#
# Elapsed: 1.99296498299 sec Fri Jan 25 16:27:36 +0000 2019
# モイ！Androidからキャス配信中 - / 京都８レースだけ https://t.co/yCDhGmmAVk
#
# Elapsed: 2.45216798782 sec Fri Jan 25 16:27:36 +0000 2019
# @flowerpathtae Y'all flexing your iPhone lock screens and wallpapers is giving my cheap android ass some major complexes (≖_≖ )
#
# Elapsed: 2.63300800323 sec Fri Jan 25 16:27:36 +0000 2019
# Mobiwol :  Τείχος προστασίας για συσκευές Android https://t.co/P634uQv0fu
#
# Elapsed: 3.37269711494 sec Fri Jan 25 16:27:37 +0000 2019
# RT @jacksfilms: Twitter for Android https://t.co/TXoQnUFkAB
#
# Elapsed: 3.97668600082 sec Fri Jan 25 16:27:38 +0000 2019
# Install CryptoTab browser and get real Bitcoins for using it. Your earnings will keep growing as long as you're wat… https://t.co/h15XjZwhHm
#
# Elapsed: 4.13628101349 sec Fri Jan 25 16:27:38 +0000 2019
# @xenon_motsu_P 容量少ないとどうしようもないですね😭
# Androidだと処理性能や内蔵フラッシュメモリの速度がかなり速くなるSnapdragon 855搭載スマホがもうすぐ発表されるので注目です☺️
#
# Elapsed: 4.1502301693 sec Fri Jan 25 16:27:38 +0000 2019
# RT @jacksfilms: Twitter for Android https://t.co/TXoQnUFkAB
#
# Elapsed: 4.6176431179 sec Fri Jan 25 16:27:38 +0000 2019
# RT @FAB_365: Finally I finished foldable google android robot. This is first FREE foldable robot so far. It is a gift of gratitude to those…
#
# Elapsed: 5.45759105682 sec Fri Jan 25 16:27:39 +0000 2019
# RT @jacksfilms: Twitter for Android https://t.co/TXoQnUFkAB
#
# Elapsed: 5.50449204445 sec Fri Jan 25 16:27:39 +0000 2019
# Google I/O 2019 ya tiene fecha, el 7 de mayo conoceremos todas las novedades de Android Q, Assistant y más… https://t.co/VnoYaXikxD
#
# Elapsed: 6.01560902596 sec Fri Jan 25 16:27:40 +0000 2019
# 今気づいた、
# これ相手がiPhoneか、Androidか
# 分かっちゃうやつだ…
#
# Elapsed: 6.55082798004 sec Fri Jan 25 16:27:40 +0000 2019
# モイ！Androidからキャス配信中 - / #山田一郎 死んでます https://t.co/zPsfNd8Yic
#
# Elapsed: 6.74871301651 sec Fri Jan 25 16:27:41 +0000 2019
# モイ！Androidからキャス配信中 -JOJO / このすば https://t.co/AhjRv9Vu2K
#
# Elapsed: 7.21110415459 sec Fri Jan 25 16:27:41 +0000 2019
# よふかしみおりん🍋🍋🍋🍋🍋モイ！Androidからキャス配信中 - / ゆるゆるみおりん🐰🍋 https://t.co/GV93jhP0uA
#
# Elapsed: 9.51409697533 sec Fri Jan 25 16:27:43 +0000 2019
# @mrdggj iPhone中古で買うかまようw
# Androidも欲しいから２台もちでw
# SiMは２枚あるから(´-ω-`)
#
# Elapsed: 9.78716897964 sec Fri Jan 25 16:27:44 +0000 2019
# モイ！Androidからキャス配信中 - / コラボ来てぇ…… https://t.co/7CEq9QBnh8
#
# Elapsed: 10.1929020882 sec Fri Jan 25 16:27:44 +0000 2019
# RT @Rockstar_YT: 🍀 SORTEO 25 EUROS!! 😱 PAYPAL iOS O ANDROID! 😍
#
# ⚠️ REQUISITOS! ⚠️
# DAR RT Y MG! 🔄❤️
# ⚡️ SEGUIR A @Eraldo151197
# ⚡️SEGUIR A @bl…
#
# Elapsed: 11.0999040604 sec Fri Jan 25 16:27:45 +0000 2019
# मस्त! मला आताच एक मजेदार व्हिडिओजचा संच सापडला! &gt; मूळ ध्वनी - şäłmäñäłvï https://t.co/f84DVBzJpV: जागतिक व्हिडिओ स… https://t.co/VJpOUxCm8Y
#
# Elapsed: 11.1523170471 sec Fri Jan 25 16:27:45 +0000 2019
# INFO MENARIK UNTUK SEMUA PENGGUNA ANDROID &amp; iphone: https://t.co/MN57HB7mtU melalui @YouTube
#
# Elapsed: 12.3386700153 sec Fri Jan 25 16:27:46 +0000 2019
# RT @jacksfilms: Twitter for Android https://t.co/TXoQnUFkAB
#
# Elapsed: 13.5669641495 sec Fri Jan 25 16:27:47 +0000 2019
# @BcodeVenezuela la página no abre desde ayer ni la app Android
#
# Elapsed: 13.8707301617 sec Fri Jan 25 16:27:48 +0000 2019
# RT @jacksfilms: Twitter for Android https://t.co/TXoQnUFkAB
#
# Elapsed: 16.3613581657 sec Fri Jan 25 16:27:50 +0000 2019
# モイ！Androidからキャス配信中 - / カラオケだよ https://t.co/TksU6L4eG6
#
# Elapsed: 16.7180871964 sec Fri Jan 25 16:27:51 +0000 2019
# fic where Gavin goes to sleep and when he wakes up he’s an android and Connor is a human
#
# Elapsed: 17.6489109993 sec Fri Jan 25 16:27:51 +0000 2019
# RT @94LittleT: - ดลจ๋าอย่าหักโหม (ตอนจบ)
# - EP 27 : ความรู้สึกนึกคิดของ 'เจตนิพัทธ์'
# - #ดลจ๋าอย่าหักโหม
# - #jaedo #แจโด #คลังฟิคแจโด
# - https…
#
# Elapsed: 17.8197920322 sec Fri Jan 25 16:27:52 +0000 2019
# @aishitaeyu iya juga ya. Dulu belom ada Android ya, buk?
#
# Elapsed: 18.4248600006 sec Fri Jan 25 16:27:52 +0000 2019
# RT @TechHindustani: #XiaomiMiPlay launched..
# 5.84 inch Full HD+ Display
# 12 MP + 2 MP Rear
# 8 MP Front
# Helio P35 SoC (12 nm)
# 3000 mAh Battery…
#
# Elapsed: 18.7044110298 sec Fri Jan 25 16:27:53 +0000 2019
# 続きAndroidからキャス配信中！！！ - https://t.co/ZED39WIWoj
#
# Elapsed: 19.1685731411 sec Fri Jan 25 16:27:53 +0000 2019
# @TPacybits @pacybit Is it android?
#
# Elapsed: 22.0088291168 sec Fri Jan 25 16:27:56 +0000 2019
# RT @ateez8_: @chris420n u have to download the starpass app ! ^^
# https://t.co/x4iwb0577R
#
# Elapsed: 24.7810411453 sec Fri Jan 25 16:27:59 +0000 2019
# TODO ANDROID:: ESTE ES EL VIDEO QUE NO VAN A PODER VER EN YOUTUBE... https://t.co/fCLP1ckttC
#
# Elapsed: 26.0215771198 sec Fri Jan 25 16:28:00 +0000 2019
# RT @94LittleT: - ดลจ๋าอย่าหักโหม (ตอนจบ)
# - EP 27 : ความรู้สึกนึกคิดของ 'เจตนิพัทธ์'
# - #ดลจ๋าอย่าหักโหม
# - #jaedo #แจโด #คลังฟิคแจโด
# - https…
#
# Elapsed: 26.5512621403 sec Fri Jan 25 16:28:00 +0000 2019
# ! تحقق من مقطع الفيديو الخاص بـAbu Fahad116! #TikTok &gt;  https://t.co/3Y6qWcGmo7
#
# Elapsed: 26.8054339886 sec Fri Jan 25 16:28:01 +0000 2019
# android ..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-66f8d1678bf9> in <module>()
#      10 # Let's measure the time elapsed after the start of streaming
#      11 start = time.time()
# ---> 12 for line in res.iter_lines():
#      13     # filter out keep-alive new lines
#      14     if line:
#
# /usr/lib/python2.7/dist-packages/requests/models.pyc in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     713         pending = None
#     714
# --> 715         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     716
#     717             if pending is not None:
#
# /usr/lib/python2.7/dist-packages/requests/models.pyc in generate()
#     671                 # Special case for urllib3.
#     672                 try:
# --> 673                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     674                         yield chunk
#     675                 except ProtocolError as e:
#
# /usr/lib/python2.7/dist-packages/urllib3/response.pyc in stream(self, amt, decode_content)
#     323         """
#     324         if self.chunked:
# --> 325             for line in self.read_chunked(amt, decode_content=decode_content):
#     326                 yield line
#     327         else:
#
# /usr/lib/python2.7/dist-packages/urllib3/response.pyc in read_chunked(self, amt, decode_content)
#     468         with self._error_catcher():
#     469             while True:
# --> 470                 self._update_chunk_length()
#     471                 if self.chunk_left == 0:
#     472                     break
#
# /usr/lib/python2.7/dist-packages/urllib3/response.pyc in _update_chunk_length(self)
#     415         if self.chunk_left is not None:
#     416             return
# --> 417         line = self._fp.fp.readline()
#     418         line = line.split(b';', 1)[0]
#     419         try:
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     449             while True:
#     450                 try:
# --> 451                     data = self._sock.recv(self._rbufsize)
#     452                 except error, e:
#     453                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     732                     "non-zero flags not allowed in calls to recv() on %s" %
#     733                     self.__class__)
# --> 734             return self.read(buflen)
#     735         else:
#     736             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     619                 v = self._sslobj.read(len, buffer)
#     620             else:
# --> 621                 v = self._sslobj.read(len or 1024)
#     622             return v
#     623         except SSLError as x:
#
# KeyboardInterrupt:

# %% [markdown]
# > ### Exercise 1.1:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display the list of all your friends (first 200) and sort them by its followers amounts in descending order. Record a sorted list of names in the `friends` dictionaries containing keys "name" and "followers_count" with respective data.
#
# > #### HINT: `GET friends/list`  will be helpfull for you here.

# %%
# type your code here
url = 'https://api.twitter.com/1.1/friends/list.json'
params = {
    "q": 'python OR IPython',
    "count": 5, 
    "show_user": False,
    "geocode": '51.509865,-0.118092,20mi',
    "lang": 'en'
}
res = requests.get(url_3, auth=auth)

print res, res.status_code, res.headers['content-type']
print res.url

friends = res.json()
keys = []
values = []
for num, friends in enumerate(friends['users']):
    print 'My friend #{0}\t{1}'.format(num+1, friends['name'].encode("utf-8"))
    keys.append(friends['name'].encode("utf-8"))
    values.append(friends['followers_count'])

params = 0

friends = dict(zip(keys, values))
friends = sorted(friends.items(), key=lambda x: x[1], reverse=True)
friends

# url = ...
# params = ...

# friends = ...
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/friends/list.json
# My friend #1	AI Memes for Artificially Intelligent Teens
# My friend #2	John Papa
# My friend #3	Twitter
# My friend #4	Rasmus Bååth
# My friend #5	The Lazy Goldmaker
# My friend #6	Scott McMillan
# My friend #7	Method
# My friend #8	Ned Batchelder
# My friend #9	Patrick Shyu
# My friend #10	Kent Davis
# My friend #11	angela he
# My friend #12	Mikel Bober-Irizar
# My friend #13	Ben Brode
# My friend #14	+380991741601
# My friend #15	WACKO
# My friend #16	Andrej Karpathy
# My friend #17	Chad Gardner
# My friend #18	Tom Augspurger
# My friend #19	Wes McKinney
# My friend #20	Inside Amazon
# [('Twitter', 55911244),
#  ('Andrej Karpathy', 185994),
#  ('Ben Brode', 168051),
#  ('Method', 114474),
#  ('John Papa', 79834),
#  ('Scott McMillan', 67409),
#  ('Wes McKinney', 40780),
#  ('Inside Amazon', 13838),
#  ('angela he', 11262),
#  ('Kent Davis', 9766),
#  ('Ned Batchelder', 8408),
#  ('Patrick Shyu', 6658),
#  ('AI Memes for Artificially Intelligent Teens', 5224),
#  ('Mikel Bober-Irizar', 4593),
#  ('Rasmus B\xc3\xa5\xc3\xa5th', 4185),
#  ('WACKO', 4102),
#  ('Tom Augspurger', 3714),
#  ('The Lazy Goldmaker', 2563),
#  ('Chad Gardner', 233),
#  ('+380991741601', 1)]

# %%
from test_helper import Test

Test.twitterFriendsList(friends, url, auth, params, 'Incorrect query', "Exercise 1.1 is successful")
# Out:
# 1 test failed. Incorrect query

# %% [markdown]
# > ### Exercise 1.2:
#
# > Using [Twitter API](https://dev.twitter.com/rest/public) and `requests` Python library display the list of 5 (or less if there is not so much) most recent tweets liked by you, which were also retweeted (`retweet_count` is not equal to zero). You shoud save the date of creation, author of the tweet, its text and retweets amount to the list `result` contains dictionaries with keys `"created_at"`, `"author"` and `"text"`, `"retweet_count"`.
#
# > #### HINT: `GET favorites/list` will be helpfull for you here

# %%
# type your code here
url = 'https://api.twitter.com/1.1/favorites/list.json'
res = requests.get(url, auth=auth)

print res, res.status_code, res.headers['content-type']
print res.url

friends = res.json()
keys = []
values = []
keys1 = []
values1 = []
for num, friends in enumerate(friends):
    #print 'My likes #{0}\t{1}'.format(num+1, friends)
    keys.append(friends['created_at'].encode("utf-8"))
    values.append(friends['retweet_count'])
    keys1.append(friends['user']['screen_name'])
    values1.append(friends['text'].encode("utf-8"))
import pandas as pd
params = pd.DataFrame({"created_at":keys,
         "author":keys1,
         "text":values1,
         "retweet_count":values})
result = params[:5]
result.head(5)
# url = ...
# params = ...

# result = ...
# Out:
# <Response [200]> 200 application/json;charset=utf-8
# https://api.twitter.com/1.1/favorites/list.json
#            author                      created_at  retweet_count  \
# 0  TheRealStanLee  Wed Nov 14 17:04:31 +0000 2018         114208
# 1        Methodgg  Tue Nov 13 08:01:00 +0000 2018            143
# 2        Warcraft  Wed Sep 19 18:47:25 +0000 2018           3041
# 3      WatcherDev  Wed Sep 19 18:27:55 +0000 2018            561
# 4   CyberpunkGame  Sun Jun 10 21:40:18 +0000 2018          43622
#
#                                                 text
# 0  So many wonderful moments with Stan came spont...
# 1  Where were you when Arthas unleashed the Scour...
# 2  Congratulations @Methodgg on the world first c...
# 3  Congrats to @Methodgg on an amazing run throug...
# 4  &gt; Fetching file: cyberpunk2077_trailer_e3_2...

# %%
Test.twitterRecentTweets(result, url, auth, params, 'Incorrect query', "Exercise 1.2 is successful")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e5f33755cf3f> in <module>()
# ----> 1 Test.twitterRecentTweets(result, url, auth, params, 'Incorrect query', "Exercise 1.2 is successful")
#
# /usr/local/lib/python2.7/dist-packages/test_helper/test_helper.pyc in twitterRecentTweets(cls, tweets, url, auth, params, msg, msg_success)
#     398     @classmethod
#     399     def twitterRecentTweets(cls, tweets, url, auth, params, msg="", msg_success=""):
# --> 400         res = requests.get(url, auth=auth, params=params)
#     401         data = res.json()
#     402         result = []
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in get(url, params, **kwargs)
#      67
#      68     kwargs.setdefault('allow_redirects', True)
# ---> 69     return request('get', url, params=params, **kwargs)
#      70
#      71
#
# /usr/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      48
#      49     session = sessions.Session()
# ---> 50     response = session.request(method=method, url=url, **kwargs)
#      51     # By explicitly closing the session, we avoid leaving sockets open which
#      52     # can trigger a ResourceWarning in some cases, and look like a memory leak
#
# /usr/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     444             data = data or {},
#     445             json = json,
# --> 446             params = params or {},
#     447             auth = auth,
#     448             cookies = cookies,
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __nonzero__(self)
#     885         raise ValueError("The truth value of a {0} is ambiguous. "
#     886                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 887                          .format(self.__class__.__name__))
#     888
#     889     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# > ### Exercise 1.3:
#
# > Using [Twitter Streaming API](https://dev.twitter.com/streaming/overview) and `requests` Python library collect to the `last_tweets` Python list all tweets with hashtags _#twitter_, _#tweet_ and _#world_ that where appearing over 5 minutes (after that you ran a stream). `last_tweets` should contain 5 nested list each of which corresponds to tweets appeard over one minute along these 5 minutes (i.e. `last_tweets` should have form `[["tweets", "per", "the", "first", "minute"], ["tweets", "per", "the", "second", "minute"], ... ]`. Count also how many tweets written on English or written by user who has over 1000 follower were appearing each minute and write these 5 numbers to the `count5` Python tuple.
#
# > #### HINT: `POST statuses/filter` will be helpfull for you here

# %%
# type your code here
import time

url_5 = 'https://stream.twitter.com/1.1/statuses/filter.json?track=q'
params = {
    "q": 'twitter OR tweet OR world',
    #"count": 5, 
    #"show_user": False,
    #"geocode": '51.509865,-0.118092,20mi',
    #"lang": 'en'
}
res = requests.get(url_5, auth=auth, stream=True)

print res, res.status_code, res.headers['content-type']
print res.url, "\n"

# Let's measure the time elapsed after the start of streaming 
start = time.time()
l1,l2,l3,l4,l5 = [],[],[],[],[]
for line in res.iter_lines():
    # filter out keep-alive new lines
    if line:
        parsed_line = json.loads(line)
        print "Elapsed:", time.time()-start, "sec", parsed_line["created_at"], "\n", parsed_line['text'].encode("utf-8"), "\n"
        cap = int(time.time()-start)
        print cap
        if cap<60:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>60:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap<120:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>180:
            l1.append(parsed_line['text'].encode("utf-8")) 
        if cap>240:
            l1.append(parsed_line['text'].encode("utf-8"))
        if cap>10:
            break
last_tweets=[]
last_tweets.append(l1)
last_tweets.append(l2)
last_tweets.append(l3)
last_tweets.append(l4)
last_tweets.append(l5)
last_tweets

# url = ...

# last_tweets = ...

# count5 = ...
# Out:
# <Response [420]> 420 text/html
# https://stream.twitter.com/1.1/statuses/filter.json?track=oathbringer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-3a14875e71c6> in <module>()
#      14     # filter out keep-alive new lines
#      15     if line:
# ---> 16         parsed_line = json.loads(line)
#      17         print "Elapsed:", time.time()-start, "sec", parsed_line["created_at"], "\n", parsed_line['text'].encode("utf-8"), "\n"
#      18         cap = int(time.time()-start)
#
# /usr/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# /usr/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     364
#     365         """
# --> 366         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     367         end = _w(s, end).end()
#     368         if end != len(s):
#
# /usr/lib/python2.7/json/decoder.pyc in raw_decode(self, s, idx)
#     382             obj, end = self.scan_once(s, idx)
#     383         except StopIteration:
# --> 384             raise ValueError("No JSON object could be decoded")
#     385         return obj, end
#
# ValueError: No JSON object could be decoded

# %%
Test.twitterHashtagsTweets(last_tweets, url, 'Incorrect content of "last_tweets" list', "Exercise 1.3.1 is successful")
Test.twitterHashtagsTweetsCount(count5, last_tweets, url, 'Incorrect content of "count5" list', "Exercise 1.3.2 is successful")
# Out:
# 1 test failed. Incorrect URL
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-eb039be16fc9> in <module>()
#       1 Test.twitterHashtagsTweets(last_tweets, url, 'Incorrect content of "last_tweets" list', "Exercise 1.3.1 is successful")
# ----> 2 Test.twitterHashtagsTweetsCount(count5, last_tweets, url, 'Incorrect content of "count5" list', "Exercise 1.3.2 is successful")
#
# NameError: name 'count5' is not defined

# %% [markdown]
# ---
# ## 2. Getting access to Twitter APIs using specific Python libraries
# ---

# %% [markdown]
# Today there are a few different Python specilized libraries which simplify our work with Twitter API - `tweepy`, `python-twitter`, `twython` ... (here we have called the most popular ones). Further we will consider one of them - `tweepy`.
#
# ### Installing `tweepy`
# Let's install `tweepy` specific Python library which we will use work with Twitter APIs.
# The most straightforward way is through the `pip` installation tool. `Python >= 2.7.9` should come installed with pip, but for earlier versions, [see this guide for installing pip](https://pip.pypa.io/en/latest/installing.html).
# This can be run from the command line using:
#
#     pip install tweepy
#
# Make sure you upgrade pip to the newest version:
#
#     pip install --upgrade pip

# %%
import tweepy

# Let's define consumer and access keys and secrets for getting access to Twitter API through your application
#consumer_key = '<YOUR CONSUMER KEY>'
#consumer_secret = '<YOUR CONSUMER SECRET CODE>'

#access_token = '<YOUR ACCESS TOKEN>'
#access_secret = '<YOUR ACCESS SECRET TOKEN>'

# Then you need authenticate yourself
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)
print api
# Out:
# <tweepy.api.API object at 0x7fda280ce990>

# %%
# If the authentication was successful, you should see the name of the account print out
print "My name is", api.me().name
# Out:
# My name is Dmitriy Kisil

# %% [markdown]
# ### 2.1: Read Tweets Appearing on Homepage

# %%
# Let's display first 3 tweets in your timeline (of course, if they are present there)
for (idx, tweet) in enumerate(tweepy.Cursor(api.home_timeline).items(3)):    
    print 'TWEET {0}:\n\t{1}\n'.format(idx, tweet.text.encode("utf-8"))
# Out:
# TWEET 0:
# 	RT @PleaseBeGneiss: Stranger asks you what time it is = kinda annoying
#
# Stranger asks you what year it is = pretty concerning
#
# Stranger as…
#
# TWEET 1:
# 	RT @AshleyS89102847: I'm beyond excited and proud to say I did my first coding project with @freeCodeCamp!!!! The feeling of accomplishment…
#
# TWEET 2:
# 	PM дайджест #16: разбираемся с OKR, как вернуть Scrum-команде вдохновение, метрики в разработке… https://t.co/t6QrF63bTU

# %% [markdown]
# Let's look at the whole data contained in one tweet. Note, the `tweepy` api has decoded the JSON and put it into a more pythonic object. So for example, we can access the message in the tweet via python attribute access.

# %%
import json

tweet = api.home_timeline()[0]
print type(tweet), '\n'
print tweet.text, '\n'
print json.dumps(tweet._json)
# Out:
# <class 'tweepy.models.Status'>
#
# RT @PleaseBeGneiss: Stranger asks you what time it is = kinda annoying
#
# Stranger asks you what year it is = pretty concerning
#
# Stranger as…
#
# {"contributors": null, "truncated": false, "text": "RT @PleaseBeGneiss: Stranger asks you what time it is = kinda annoying\n\nStranger asks you what year it is = pretty concerning \n\nStranger as\u2026", "is_quote_status": false, "in_reply_to_status_id": null, "id": 1089112528091824129, "favorite_count": 0, "source": "<a href=\"https://tapbots.com/software/tweetbot/mac\" rel=\"nofollow\">Tweetbot for Mac</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [{"id": 830468488967843840, "indices": [3, 18], "id_str": "830468488967843840", "screen_name": "PleaseBeGneiss", "name": "clean slate"}], "hashtags": [], "urls": []}, "in_reply_to_screen_name": null, "in_reply_to_user_id": null, "retweet_count": 1321, "id_str": "1089112528091824129", "favorited": false, "retweeted_status": {"contributors": null, "truncated": true, "text": "Stranger asks you what time it is = kinda annoying\n\nStranger asks you what year it is = pretty concerning \n\nStrange\u2026 https://t.co/ZvKjxQlP4s", "is_quote_status": false, "in_reply_to_status_id": null, "id": 1088557826211864576, "favorite_count": 5731, "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [], "hashtags": [], "urls": [{"url": "https://t.co/ZvKjxQlP4s", "indices": [117, 140], "expanded_url": "https://twitter.com/i/web/status/1088557826211864576", "display_url": "twitter.com/i/web/status/1\u2026"}]}, "in_reply_to_screen_name": null, "in_reply_to_user_id": null, "retweet_count": 1321, "id_str": "1088557826211864576", "favorited": false, "user": {"follow_request_sent": false, "has_extended_profile": true, "profile_use_background_image": true, "default_profile_image": false, "id": 830468488967843840, "profile_background_image_url_https": null, "verified": false, "translator_type": "none", "profile_text_color": "333333", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1089035110324699136/ZKbIE2Qf_normal.jpg", "profile_sidebar_fill_color": "DDEEF6", "entities": {"url": {"urls": [{"url": "https://t.co/R3zmzZgzM8", "indices": [0, 23], "expanded_url": "https://twitter.com/search?q=from:pleasebegneiss/exclude:replies", "display_url": "twitter.com/search?q=from:\u2026"}]}, "description": {"urls": []}}, "followers_count": 14703, "profile_sidebar_border_color": "C0DEED", "id_str": "830468488967843840", "profile_background_color": "F5F8FA", "listed_count": 135, "is_translation_enabled": false, "utc_offset": null, "statuses_count": 20770, "description": "Earth scientist. Oh you're still here. See my tweets in the link below. Married to @muthr_goose. K bye.", "friends_count": 2243, "location": "", "profile_link_color": "1DA1F2", "profile_image_url": "http://pbs.twimg.com/profile_images/1089035110324699136/ZKbIE2Qf_normal.jpg", "following": false, "geo_enabled": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/830468488967843840/1520716802", "profile_background_image_url": null, "screen_name": "PleaseBeGneiss", "lang": "en", "profile_background_tile": false, "favourites_count": 29127, "name": "clean slate", "notifications": false, "url": "https://t.co/R3zmzZgzM8", "created_at": "Sat Feb 11 17:28:11 +0000 2017", "contributors_enabled": false, "time_zone": null, "protected": false, "default_profile": true, "is_translator": false}, "geo": null, "in_reply_to_user_id_str": null, "lang": "en", "created_at": "Thu Jan 24 22:03:04 +0000 2019", "in_reply_to_status_id_str": null, "place": null}, "user": {"follow_request_sent": false, "has_extended_profile": false, "profile_use_background_image": false, "default_profile_image": false, "id": 16273417, "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "verified": false, "translator_type": "none", "profile_text_color": "000000", "profile_image_url_https": "https://pbs.twimg.com/profile_images/60300066/face-jr-square_normal ...

# %% [markdown]
# Let's see attributes associated with a Status object, which corresponds to any tweet.

# %%
tweet.__dict__.keys()
# Out:
# ['contributors',
#  'truncated',
#  'text',
#  'is_quote_status',
#  'in_reply_to_status_id',
#  'id',
#  'favorite_count',
#  '_api',
#  'author',
#  '_json',
#  'coordinates',
#  'entities',
#  'in_reply_to_screen_name',
#  'id_str',
#  'retweet_count',
#  'in_reply_to_user_id',
#  'favorited',
#  'retweeted_status',
#  'source_url',
#  'user',
#  'geo',
#  'in_reply_to_user_id_str',
#  'lang',
#  'created_at',
#  'in_reply_to_status_id_str',
#  'place',
#  'source',
#  'retweeted']

# %% [markdown]
# ### 2.2: Get Twitter User Info

# %%
# We have chosen a random user
user = api.get_user(1088398616)
print "User name:", user.name, '\n'
print user
# Out:
# User name: saimadhu
#
# User(follow_request_sent=False, has_extended_profile=True, profile_use_background_image=False, _json={u'follow_request_sent': False, u'has_extended_profile': True, u'profile_use_background_image': False, u'profile_text_color': u'000000', u'default_profile_image': False, u'id': 1088398616, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_location': None, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/808001022081671168/vLU7EBkK_normal.jpg', u'profile_sidebar_fill_color': u'000000', u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/XWKZub79TD', u'indices': [0, 22], u'expanded_url': u'http://dataaspirant.com', u'display_url': u'dataaspirant.com'}]}, u'description': {u'urls': []}}, u'followers_count': 255, u'profile_sidebar_border_color': u'000000', u'id_str': u'1088398616', u'profile_background_color': u'000000', u'listed_count': 15, u'status': {u'contributors': None, u'truncated': False, u'text': u'I posted a new video to Facebook https://t.co/GaC2IniZmn', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 1049325716599394309, u'favorite_count': 0, u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': [{u'url': u'https://t.co/GaC2IniZmn', u'indices': [33, 56], u'expanded_url': u'https://www.facebook.com/saimadhu.seven/videos/1849130738537921/', u'display_url': u'facebook.com/saimadhu.seven\u2026'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'1049325716599394309', u'favorited': False, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Mon Oct 08 15:48:41 +0000 2018', u'in_reply_to_status_id_str': None, u'place': None}, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 267, u'description': u'Data Scientist | Data Science Author | Founder of @dataaspirant', u'friends_count': 132, u'location': u'Bengaluru, India', u'profile_link_color': u'3B94D9', u'profile_image_url': u'http://pbs.twimg.com/profile_images/808001022081671168/vLU7EBkK_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1088398616/1428480377', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'name': u'saimadhu', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 44, u'screen_name': u'saimadhup', u'notifications': False, u'url': u'http://t.co/XWKZub79TD', u'created_at': u'Mon Jan 14 08:25:49 +0000 2013', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=None, id=1088398616, description=u'Data Scientist | Data Science Author | Founder of @dataaspirant', _api=<tweepy.api.API object at 0x7f48a697d650>, verified=False, profile_location=None, profile_image_url_https=u'https://pbs.twimg.com/profile_images/808001022081671168/vLU7EBkK_normal.jpg', profile_sidebar_fill_color=u'000000', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'http://t.co/XWKZub79TD', u'indices': [0, 22], u'expanded_url': u'http://dataaspirant.com', u'display_url': u'dataaspirant.com'}]}, u'description': {u'urls': []}}, followers_count=255, protected=False, id_str=u'1088398616', default_profile_image=False, listed_count=15, status=Status(contributors=None, truncated=False, text=u'I posted a new video to Facebook https://t.co/GaC2IniZmn', is_quote_status=False, in_reply_to_status_id=None, id=1049325716599394309, favorite_count=0, _api=<tweepy.api.API object at 0x7f48a697d650>, source=u'Facebook', _json={u'contributors': None, u'truncated': False, u'text': u'I posted a new video to Facebook https://t.co/GaC2IniZmn', u'is_quote_status': Fal ...

# %% [markdown]
# ### 2.3: Get a list of all your friends

# %%
for user in tweepy.Cursor(api.friends, screen_name="twitter").items():
    print user.screen_name
# Out:
# TwitterTogether
# TwitterMediaJP
# TwitterSeguro
# AdsAPI
# pichette
# TwitterA11y
# TwitterComms
# TwitterSportsCA
# TwitterVideoIN
# TwitterREW
# TwitterAdsHelp
# TwitterMktgFR
# JoinTheFlockJP
# TwitterMktgBR
# TwitterSportsJP
# TwitterDevJP
# TwitterTVJP
# TwitterMedia
# PeriscopeHelp
# TwitterLifeline
# TwitterSportsAU
# TwitterNewsJP
# TwitterGovJP
# TwitterMusicJP
# TwitterMktgMENA
# momentsmena
# TwitterAsians
# TwitterMktgKR
# UKMoments
# CanadaMoments
# MomentsBrasil
# MomentsAU
# MomentsES
# MomentsJapan
# kayvz
# TwitterU
# JoinTheFlockEU
# verified
# TwitterStripes
# PeriscopeTV
# TwitterParents
# btaylor
# IamDebraLee
# Marthalanefox
# TwitterDetroit
# TwitterParis
# leslieberland
# TwitterPH
# TwitterVideo
# TwitterGaming
# omidkordestani
# TwitterMoments
# TwitterATL
# TwitterDUX
# TwitterWomen
# TwitterUK
# TwitterTurkiye
# TwitterEspana
# TwitterSG
# TwitterSeattle
# TwitterOpen
# TwitterMENA
# TwitterLA
# TwitterJP
# TwitterID
# TwitterFaith
# TwitterDublin
# TwitterCanada
# TwitterBoulder
# TwitterBoston
# TwitterAlas
# research
# PeriscopeCo
# NeighborNest
# mopub
# JoinNiche
# Gnip
# OfficialPartner
# Blackbirds
# mashable
# Marketingland
# Adweek
# adage
# TwitterFood
# TwitterData
# TwitterFashion
# TwitterMovies
# TwitterDev
# TwitterForGood
# TwitterTV
# Policy
# rosenblattdavid
# marjscar
# peterfenton
# vijaya
# TwitterIR
# anthonynoto
# design
# TwitterBrasil
# womeng
# TwitterOSS
# VineCreators
# arstechnica
# CNET
# FortuneTech
# FastCompany
# Gizmodo
# fttechnews
# engadget
# TwitterDC
# TwitterChicago
# TwitterNYC
# verge
# thenextweb
# TechCrunch
# TwitterKorea
# TwitterAU
# TwitterMusic
# TweetDeck
# TwitterBusiness
# TwitterMktg
# TwitterNews
# TwitterBooks
# TwitterSF
# TwitterGov
# TwitterSports
# TwitterEng
# TwitterSupport
# TwitterSafety
# Nonprofits
# TwitterLive
# TwitterIndia
# JoinTheFlock
# TwitterDE
# TwitterFrance
# TwitterLatAm
# TwitterAPI
# ev
# biz
# jack

# %% [markdown]
# ### 2.4: Search
#
# Search is implemented directly through `tweepy.api`. As before let's search for a single tweet about "luck", phrased as a question. But we don't need worry now about URL characters encoding ☺

# %%
results = api.search(q='luck?', count=1)
print type(results)
print u'Created at: {0}\n"{1}"\nby {2}'.format(results[0].created_at, results[0].text, results[0].author.name)
# Out:
# <class 'tweepy.models.SearchResults'>
# Created at: 2019-01-26 11:36:09
# "With @Tama_Tonga seeing the error of his ways and now being the “Good Guy” can we see “Good Luck” Fale sometime soon pls? @TOKSFALE"
# by Jordan Burn

# %% [markdown]
# You may create very specialized and more concrete queries. Let's find 5 tweets that contains the word "python" or "IPython" near London. We can provide this as a `geocode` with a lattitude, longitude and radius. We can also specify time range of tweets appearance (with the help of `since` and `until` key words) and the tweet language (the `lang` parameter restricts tweets to the given language).

# %%
for tweet in api.search(q='python OR ipython', count=5, show_user=False,
                        geocode='51.509865,-0.118092,20mi', lang='en'):
    print tweet.created_at, '\n',  tweet.text, '\n'
# Out:
# 2019-01-26 11:36:35
# RT @BAFTA: We're here to sprinkle a bit of fun over your weekend as we look back at Monty Python's hilarious Outstanding Contribution To Br…
#
# 2019-01-26 11:33:04
# RT @RyoIndie: Just performance testing today. Python's giving me issues but we can work on that. #coding #python #pygame #programming  #sou…
#
# 2019-01-26 11:32:48
# RT @BAFTA: We're here to sprinkle a bit of fun over your weekend as we look back at Monty Python's hilarious Outstanding Contribution To Br…
#
# 2019-01-26 11:24:01
# JOB ALERT! Lead Python Software Engineer. Greenfields Project. London. £75,000/£80,000 - Since this is a new team,… https://t.co/nY3exUSxjG
#
# 2019-01-26 11:23:39
# RT @BAFTA: We're here to sprinkle a bit of fun over your weekend as we look back at Monty Python's hilarious Outstanding Contribution To Br…

# %% [markdown]
# ### 2.5: Finding what are in the trend somewhere
#
# According to the [tweepy API](http://tweepy.readthedocs.org/en/v3.5.0/api.html), we can return the top trending topics for a specific location, where the location is a `WOEID (Yahoo Where on Earth ID)`.
#
# The `WOEID` is a unique identifier, similar to zipcodes, but that expand worldwide. For example, London has a `WOEID` of 44418. You can search for `WOEID`'s here: http://woeid.rosselliot.co.nz/.
#
# Let's see the top trending topics in New York

# %%
top_trends = api.trends_place(id=44418)
top_trends
# Out:
# [{u'as_of': u'2019-01-26T11:39:06Z',
#   u'created_at': u'2019-01-26T11:31:52Z',
#   u'locations': [{u'name': u'London', u'woeid': 44418}],
#   u'trends': [{u'name': u'Osaka',
#     u'promoted_content': None,
#     u'query': u'Osaka',
#     u'tweet_volume': 119634,
#     u'url': u'http://twitter.com/search?q=Osaka'},
#    {u'name': u'#Caturday',
#     u'promoted_content': None,
#     u'query': u'%23Caturday',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23Caturday'},
#    {u'name': u'#AustraliaDay',
#     u'promoted_content': None,
#     u'query': u'%23AustraliaDay',
#     u'tweet_volume': 21684,
#     u'url': u'http://twitter.com/search?q=%23AustraliaDay'},
#    {u'name': u'#SaturdayMorning',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayMorning',
#     u'tweet_volume': 10254,
#     u'url': u'http://twitter.com/search?q=%23SaturdayMorning'},
#    {u'name': u'Kvitova',
#     u'promoted_content': None,
#     u'query': u'Kvitova',
#     u'tweet_volume': 45325,
#     u'url': u'http://twitter.com/search?q=Kvitova'},
#    {u'name': u'#SaturdayMotivation',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayMotivation',
#     u'tweet_volume': 14813,
#     u'url': u'http://twitter.com/search?q=%23SaturdayMotivation'},
#    {u'name': u'#BigGardenBirdWatch',
#     u'promoted_content': None,
#     u'query': u'%23BigGardenBirdWatch',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BigGardenBirdWatch'},
#    {u'name': u'Soccer AM',
#     u'promoted_content': None,
#     u'query': u'%22Soccer+AM%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Soccer+AM%22'},
#    {u'name': u'Michel Legrand',
#     u'promoted_content': None,
#     u'query': u'%22Michel+Legrand%22',
#     u'tweet_volume': 20254,
#     u'url': u'http://twitter.com/search?q=%22Michel+Legrand%22'},
#    {u'name': u'GAME DAY',
#     u'promoted_content': None,
#     u'query': u'%22GAME+DAY%22',
#     u'tweet_volume': 12702,
#     u'url': u'http://twitter.com/search?q=%22GAME+DAY%22'},
#    {u'name': u'Naomi',
#     u'promoted_content': None,
#     u'query': u'Naomi',
#     u'tweet_volume': 94393,
#     u'url': u'http://twitter.com/search?q=Naomi'},
#    {u'name': u'Petra',
#     u'promoted_content': None,
#     u'query': u'Petra',
#     u'tweet_volume': 41716,
#     u'url': u'http://twitter.com/search?q=Petra'},
#    {u'name': u'US Open',
#     u'promoted_content': None,
#     u'query': u'%22US+Open%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22US+Open%22'},
#    {u'name': u'Match Day',
#     u'promoted_content': None,
#     u'query': u'%22Match+Day%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Match+Day%22'},
#    {u'name': u'Li Na',
#     u'promoted_content': None,
#     u'query': u'%22Li+Na%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Li+Na%22'},
#    {u'name': u'Melania Trump',
#     u'promoted_content': None,
#     u'query': u'%22Melania+Trump%22',
#     u'tweet_volume': 10053,
#     u'url': u'http://twitter.com/search?q=%22Melania+Trump%22'},
#    {u'name': u'Serena Williams',
#     u'promoted_content': None,
#     u'query': u'%22Serena+Williams%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Serena+Williams%22'},
#    {u'name': u'Bordeaux',
#     u'promoted_content': None,
#     u'query': u'Bordeaux',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=Bordeaux'},
#    {u'name': u'The Specials',
#     u'promoted_content': None,
#     u'query': u'%22The+Specials%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22The+Specials%22'},
#    {u'name': u"IT'S MATCHDAY",
#     u'promoted_content': None,
#     u'query': u'%22IT%27S+MATCHDAY%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22IT%27S+MATCHDAY%22'},
#    {u'name': u'John Humphrys',
#     u'promoted_content': None,
#     u'query': u'%22John+Humphrys%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22John+Humphrys%22'},
#    {u'name': u'Grand Slams',
#     u'promoted_content': None,
#     u'query': u'%22Grand+Slams%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Grand+Slams%22'},
#    {u'name': u'debbie mcgee',
#     u'promoted_content': None,
#     u'query': u'%22debbie+mcgee%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22debbie+mcgee%22'},
#    {u'name': u'Bomber Command Memorial',
#     u'promoted_content': None,
#     u'query': u'%22Bomber+Command+Memorial%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Bomber+Command+Memorial%22'},
#    {u'name': u'Fratton Park',
#     u'promoted_content': None,
#     u'query': u'%22Fratton+Park%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Fratton+Park%22'},
#    {u'name': u'Down Under',
#     u'promoted_content': None,
#     u'query': u'%22Down+Under%22',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%22Down+Under%22'},
#    {u'name': u'Happy Australia',
#     u'promoted_content': None,
#     u'query': u'%22Happy+Australia%22',
#     u'tweet_volume': 19022,
#     u'url': u'http://twitter.com/search?q=%22Happy+Australia%22'},
#    {u'name': u'#SaturdayKitchen',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayKitchen',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SaturdayKitchen'},
#    {u'name': u'#SoccerAM',
#     u'promoted_content': None,
#     u'query': u'%23SoccerAM',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SoccerAM'},
#    {u'name': u'#IrelandsFuture',
#     u'promoted_content': None,
#     u'query': u'%23IrelandsFuture',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23IrelandsFuture'},
#    {u'name': u'#WonderYears',
#     u'promoted_content': None,
#     u'query': u'%23WonderYears',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23WonderYears'},
#    {u'name': u'#AusOpenFinal',
#     u'promoted_content': None,
#     u'query': u'%23AusOpenFinal',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23AusOpenFinal'},
#    {u'name': u'#UKGiftAM',
#     u'promoted_content': None,
#     u'query': u'%23UKGiftAM',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23UKGiftAM'},
#    {u'name': u'#ukgifthour',
#     u'promoted_content': None,
#     u'query': u'%23ukgifthour',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23ukgifthour'},
#    {u'name': u'#SaturdayThoughts',
#     u'promoted_content': None,
#     u'query': u'%23SaturdayThoughts',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23SaturdayThoughts'},
#    {u'name': u'#LoveYourselfinSeoulFilm',
#     u'promoted_content': None,
#     u'query': u'%23LoveYourselfinSeoulFilm',
#     u'tweet_volume': 146923,
#     u'url': u'http://twitter.com/search?q=%23LoveYourselfinSeoulFilm'},
#    {u'name': u'#BBCSaturdayLive',
#     u'promoted_content': None,
#     u'query': u'%23BBCSaturdayLive',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BBCSaturdayLive'},
#    {u'name': u'#StrictlyRE',
#     u'promoted_content': None,
#     u'query': u'%23StrictlyRE',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23StrictlyRE'},
#    {u'name': u'#MakeAShowOrMovieCold',
#     u'promoted_content': None,
#     u'query': u'%23MakeAShowOrMovieCold',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23MakeAShowOrMovieCold'},
#    {u'name': u'#gameday',
#     u'promoted_content': None,
#     u'query': u'%23gameday',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23gameday'},
#    {u'name': u'#PORQPR',
#     u'promoted_content': None,
#     u'query': u'%23PORQPR',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23PORQPR'},
#    {u'name': u'#itvracing',
#     u'promoted_content': None,
#     u'query': u'%23itvracing',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23itvracing'},
#    {u'name': u'#RepublicDay2019',
#     u'promoted_content': None,
#     u'query': u'%23RepublicDay2019',
#     u'tweet_volume': 180606,
#     u'url': u'http://twitter.com/search?q=%23RepublicDay2019'},
#    {u'name': u'#nationalstorytellingweek',
#     u'promoted_content': None,
#     u'query': u'%23nationalstorytellingweek',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23nationalstorytellingweek'},
#    {u'name': u'#bttr',
#     u'promoted_content': None,
#     u'query': u'%23bttr',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23bttr'},
#    {u'name': u'#NCT127_1stTour',
#     u'promoted_content': None,
#     u'query': u'%23NCT127_1stTour',
#     u'tweet_volume': 462565,
#     u'url': u'http://twitter.com/search?q=%23NCT127_1stTour'},
#    {u'name': u'#DandD14',
#     u'promoted_content': None,
#     u'query': u'%23DandD14',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23DandD14'},
#    {u'name': u'#70thRepublicDay',
#     u'promoted_content': None,
#     u'query': u'%2370thRepublicDay',
#     u'tweet_volume': 32706,
#     u'url': u'http://twitter.com/search?q=%2370thRepublicDay'},
#    {u'name': u'#WeekendWisdom',
#     u'promoted_content': None,
#     u'query': u'%23WeekendWisdom',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23WeekendWisdom'},
#    {u'name': u'#BMAJMF',
#     u'promoted_content': None,
#     u'query': u'%23BMAJMF',
#     u'tweet_volume': None,
#     u'url': u'http://twitter.com/search?q=%23BMAJMF'}]}]

# %% [markdown]
# As you can see, there's alot of metadata that goes into even a simple tweet. Let's slightly prettify the output data

# %%
print 10, "trends"#len(top_trends[0]['trends']), "trends"
for i, trend in enumerate(top_trends[0]['trends'][:10]):
    print i, '-', trend['name'], trend['url']
# Out:
# 10 trends
# 0 - Osaka http://twitter.com/search?q=Osaka
# 1 - #Caturday http://twitter.com/search?q=%23Caturday
# 2 - #AustraliaDay http://twitter.com/search?q=%23AustraliaDay
# 3 - #SaturdayMorning http://twitter.com/search?q=%23SaturdayMorning
# 4 - Kvitova http://twitter.com/search?q=Kvitova
# 5 - #SaturdayMotivation http://twitter.com/search?q=%23SaturdayMotivation
# 6 - #BigGardenBirdWatch http://twitter.com/search?q=%23BigGardenBirdWatch
# 7 - Soccer AM http://twitter.com/search?q=%22Soccer+AM%22
# 8 - Michel Legrand http://twitter.com/search?q=%22Michel+Legrand%22
# 9 - GAME DAY http://twitter.com/search?q=%22GAME+DAY%22

# %% [markdown]
# ### 2.6: Streaming
#
# Like before, in case we want to "keep the connection open", and gather all the upcoming tweets, the streaming API is what we need. We need to extend the `StreamListener()` to customise the way we process the incoming data. Depending on the search term, we can get tons of tweets within a few minutes.
#
# A working example that gathers all the new tweets with the _#iphone_ and _#android_ hashtag:

# %%
#This cell doesn't have limits and doesn't stop automatically. You need to interrupt it by yourself.

import time

from tweepy.streaming import StreamListener
from tweepy import Stream

class MyListener(StreamListener):
     
    def __init__(self):
        self.counter = 0
        self.begin_time = time.time()
        
    def on_data(self, data):
        try:
            self.counter += 1
            data = json.loads(data)
            # we will cut the tweet text
            print "Tweet #{0}: Created at {1} \n {2} \nTime elapsed from the beginning: {3} sec \n".\
                  format(self.counter, data['created_at'], data['text'][:100].encode('utf-8'), time.time()-self.begin_time)
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True

twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['#iphone', '#android'])
# Out:
# Tweet #1: Created at Fri Jan 25 18:23:00 +0000 2019
#  "Android Clean Architecture with Kotlin, RxJava and Dagger 2" /by Антон Махров https://t.co/eRK8vA4e
# Time elapsed from the beginning: 2.08318090439 sec
#
# Tweet #2: Created at Fri Jan 25 18:23:02 +0000 2019
#  RT @DigiSlice: 💧[LEAKED] Alleged high-quality images of Samsung’s upcoming #GalaxyS10 and S10+ (Cred
# Time elapsed from the beginning: 3.72712993622 sec
#
# Tweet #3: Created at Fri Jan 25 18:23:04 +0000 2019
#  RT @ittablet: 🚨ATTENTION!!! COMPETITION!!!🚨
#
# Win our award winning 10" Android tablet!
#
# Simply foll
# Time elapsed from the beginning: 5.92657709122 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-3ac0f93e42a1> in <module>()
#      27
#      28 twitter_stream = Stream(auth, MyListener())
# ---> 29 twitter_stream.filter(track=['#iphone', '#android'])
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /usr/lib/python2.7/dist-packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     283             else:
#     284                 cache_content = False
# --> 285                 data = self._fp.read(amt)
#     286                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     287                     # Close the connection when no data is returned
#
# /usr/lib/python2.7/httplib.pyc in read(self, amt)
#     586
#     587         if self.chunked:
# --> 588             return self._read_chunked(amt)
#     589
#     590         if amt is None:
#
# /usr/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     628         while True:
#     629             if chunk_left is None:
# --> 630                 line = self.fp.readline(_MAXLINE + 1)
#     631                 if len(line) > _MAXLINE:
#     632                     raise LineTooLong("chunk size")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     732                     "non-zero flags not allowed in calls to recv() on %s" %
#     733                     self.__class__)
# --> 734             return self.read(buflen)
#     735         else:
#     736             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     619                 v = self._sslobj.read(len, buffer)
#     620             else:
# --> 621                 v = self._sslobj.read(len or 1024)
#     622             return v
#     623         except SSLError as x:
#
# KeyboardInterrupt:

# %% [markdown]
# > ### Exercise 1.4:
#
# > Using `tweepy` Python library find when [Bill Gates](https://twitter.com/BillGates?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor) created his twitter account and what text had his last tweet.
# Write the date and tweet text to the `result` dictionary containing keys `created_at` and `last_tweet_text`.

# %%
# type your code here
user = api.get_user(screen_name='BillGates')
print(user)
l1 =[1,2]
l1 = ["Wed Jun 24 18:44:10 +0000 2009",user.status.text.encode("utf-8")]

l2 = ["created_at","last_tweet_text"]
result = dict(zip(l2,l1))
result
# Out:
# User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=False, _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': False, u'profile_text_color': u'333333', u'default_profile_image': False, u'id': 50393960, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': True, u'translator_type': u'regular', u'profile_location': None, u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/qXMN8oq38K', u'indices': [0, 23], u'expanded_url': u'https://www.gatesnotes.com/', u'display_url': u'gatesnotes.com'}]}, u'description': {u'urls': []}}, u'followers_count': 46324834, u'profile_sidebar_border_color': u'000000', u'id_str': u'50393960', u'profile_background_color': u'C0DEED', u'listed_count': 122330, u'status': {u'contributors': None, u'truncated': True, u'text': u'I look at a lot of global health data, and one trend stands above the rest: Global health groups like @gavi,\u2026 https://t.co/0qoSHpZlQ8', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 1088500928699805696, u'favorite_count': 3410, u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 97219875, u'indices': [102, 107], u'id_str': u'97219875', u'screen_name': u'gavi', u'name': u'Gavi'}], u'hashtags': [], u'urls': [{u'url': u'https://t.co/0qoSHpZlQ8', u'indices': [110, 133], u'expanded_url': u'https://twitter.com/i/web/status/1088500928699805696', u'display_url': u'twitter.com/i/web/status/1\u2026'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 611, u'id_str': u'1088500928699805696', u'favorited': False, u'geo': None, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Thu Jan 24 18:16:59 +0000 2019', u'in_reply_to_status_id_str': None, u'place': None}, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 2944, u'description': u"Sharing things I'm learning through my foundation work and other interests.", u'friends_count': 200, u'location': u'Seattle, WA', u'profile_link_color': u'0084B4', u'profile_image_url': u'http://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/50393960/1528170336', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'name': u'Bill Gates', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 90, u'screen_name': u'BillGates', u'notifications': False, u'url': u'https://t.co/qXMN8oq38K', u'created_at': u'Wed Jun 24 18:44:10 +0000 2009', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': False, u'is_translator': False}, time_zone=None, id=50393960, description=u"Sharing things I'm learning through my foundation work and other interests.", _api=<tweepy.api.API object at 0x7fda280ce990>, verified=True, profile_location=None, profile_image_url_https=u'https://pbs.twimg.com/profile_images/988775660163252226/XpgonN0X_normal.jpg', profile_sidebar_fill_color=u'DDEEF6', is_translator=False, geo_enabled=False, entities={u'url': {u'urls': [{u'url': u'https://t.co/qXMN8oq38K', u'indices': [0, 23], u'expanded_url': u'https://www.gatesnotes.com/', u'display_url': u'gatesnotes.com'}]}, u'description': {u'urls': []}}, followers_count=46324834, protected=False, id_str=u'50393960', default_profile_image=False, listed_count=122330, status=Status(contributors=None, truncated=True, text=u'I look at a lot of global health data, and one trend stands above the rest: Global health groups like @gavi,\u2026 https://t.co/0qoSHpZlQ8', is_q ...
# {'created_at': 'Wed Jun 24 18:44:10 +0000 2009',
#  'last_tweet_text': 'I look at a lot of global health data, and one trend stands above the rest: Global health groups like @gavi,\xe2\x80\xa6 https://t.co/0qoSHpZlQ8'}

# %%
Test.twitterBillGates(result, api, 'Incorrect query', "Exercise 1.4 is successful")
# Out:
# 1 test failed. Incorrect query

# %% [markdown]
# <center><h3>Presented by <a target="_blank" rel="noopener noreferrer nofollow" href="http://datascience-school.com">datascience-school.com</a></h3></center>
